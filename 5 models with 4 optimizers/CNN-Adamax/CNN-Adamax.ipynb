# %%
# -*- coding: utf-8 -*-
"""cnn_enh_adamax.ipynb
Automatically generated by Colab.
"""

from google.colab import drive
drive.mount('/content/drive')

import zipfile, os

zip_path = "/content/drive/MyDrive/d.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3  # 🔄 Changed from ResNet152 to InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

train_dir = "/content/dataset/d/train"
val_dir = "/content/dataset/d/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# === Data generators ===
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(
    rescale=1./255
)

# === Load image data ===
train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(128, 128),  # ✅ Changed to smaller size (better for CNN)
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(128, 128),  # ✅ Match input size for CNN
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

# === Simple CNN architecture ===
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(128, 128, 3)),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),

    Flatten(),

    Dense(256, activation='relu'),
    Dropout(0.5),
    BatchNormalization(),

    Dense(5, activation='softmax')  # ✅ 5 classes (adjust if needed)
])

# ----- UPDATED: Use Adamax optimizer -----
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Define Adamax optimizer (tweak learning_rate as you like)
optimizer = Adamax(learning_rate=0.002, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# ✅ Updated input shape for CNN
model.build((None, 128, 128, 3))

# ✅ Updated checkpoint filename (adamax)
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_cnn_model_adamax.keras",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# Train the model
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=51,
    callbacks=[checkpoint, lr_scheduler]
)

import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results_adamax"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained model (Adamax run) ===
model_path = "/content/drive/MyDrive/best_cnn_model_adamax.keras"
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results_adamax"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))

import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
n_classes = 5
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = graph_dir  # using same folder

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class (Adamax)')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")

# === Save final trained model (Adamax run) ===
model.save("/content/drive/MyDrive/final_cnn_model_adamax.keras")
print("✅ Model saved successfully at /content/drive/MyDrive/final_cnn_model_adamax.keras")
# Out:
# Mounted at /content/drive
#  Dataset extracted.
# Found 2637 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.6688 - loss: 1.3781
# Epoch 1: val_loss improved from inf to 2.62524, saving model to /content/drive/MyDrive/best_cnn_model_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 294ms/step - accuracy: 0.6695 - loss: 1.3745 - val_accuracy: 0.5455 - val_loss: 2.6252 - learning_rate: 0.0020
# Epoch 2/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.7855 - loss: 0.7255
# Epoch 2: val_loss did not improve from 2.62524
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s 212ms/step - accuracy: 0.7856 - loss: 0.7249 - val_accuracy: 0.5455 - val_loss: 2.8317 - learning_rate: 0.0020
# Epoch 3/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.7901 - loss: 0.5955
# Epoch 3: val_loss improved from 2.62524 to 1.89454, saving model to /content/drive/MyDrive/best_cnn_model_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 20s 210ms/step - accuracy: 0.7903 - loss: 0.5949 - val_accuracy: 0.5455 - val_loss: 1.8945 - learning_rate: 0.0020
# Epoch 4/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8010 - loss: 0.5110
# Epoch 4: val_loss improved from 1.89454 to 1.03347, saving model to /content/drive/MyDrive/best_cnn_model_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 20s 246ms/step - accuracy: 0.8011 - loss: 0.5106 - val_accuracy: 0.5879 - val_loss: 1.0335 - learning_rate: 0.0020
# Epoch 5/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.8145 - loss: 0.4521
# Epoch 5: val_loss improved from 1.03347 to 0.57090, saving model to /content/drive/MyDrive/best_cnn_model_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 20s 240ms/step - accuracy: 0.8144 - loss: 0.4521 - val_accuracy: 0.7242 - val_loss: 0.5709 - learning_rate: 0.0020
# Epoch 6/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.8013 - loss: 0.4650
# Epoch 6: val_loss improved from 0.57090 to 0.45153, saving model to /content/drive/MyDrive/best_cnn_model_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 20s 246ms/step - accuracy: 0.8014 - loss: 0.4647 - val_accuracy: 0.7909 - val_loss: 0.4515 - learning_rate: 0.0020
# Epoch 7/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8033 - loss: 0.4505
# Epoch 7: val_loss improved from 0.45153 to 0.38237, saving model to /content/drive/MyDrive/best_cnn_model_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 222ms/step - accuracy: 0.8034 - loss: 0.4499 - val_accuracy: 0.8182 - val_loss: 0.3824 - learning_rate: 0.0020
# Epoch 8/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.8108 - loss: 0.4084
# Epoch 8: val_loss improved from 0.38237 to 0.37593, saving model to /content/drive/MyDrive/best_cnn_model_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 230ms/step - accuracy: 0.8109 - loss: 0.4082 - val_accuracy: 0.8288 - val_loss: 0.3759 - learning_rate: 0.0020
# Epoch 9/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8273 - loss: 0.3725
# Epoch 9: val_loss did not improve from 0.37593
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.8272 - loss: 0.3729 - val_accuracy: 0.6909 - val_loss: 0.8535 - learning_rate: 0.0020
# Epoch 10/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.8223 - loss: 0.3773
# Epoch 10: val_loss did not improve from 0.37593
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 203ms/step - accuracy: 0.8224 - loss: 0.3772 - val_accuracy: 0.7985 - val_loss: 0.4214 - learning_rate: 0.0020
# Epoch 11/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8368 - loss: 0.3632
# Epoch 11: val_loss improved from 0.37593 to 0.32797, saving model to /content/drive/MyDrive/best_cnn_model_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 227ms/step - accuracy: 0.8368 - loss: 0.3632 - val_accuracy: 0.8470 - val_loss: 0.3280 - learning_rate: 6.0000e-04
# Epoch 12/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.8292 - loss: 0.3629
# Epoch 12: val_loss improved from 0.32797 to 0.30556, saving model to /content/drive/MyDrive/best_cnn_model_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 21s 229ms/step - accuracy: 0.8293 - loss: 0.3628 - val_accuracy: 0.8667 - val_loss: 0.3056 - learning_rate: 6.0000e-04
# Epoch 13/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.8461 - loss: 0.3467
# Epoch 13: val_loss did not improve from 0.30556
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 21s 232ms/step - accuracy: 0.8460 - loss: 0.3467 - val_accuracy: 0.8621 - val_loss: 0.3056 - learning_rate: 6.0000e-04
# Epoch 14/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8613 - loss: 0.3146
# Epoch 14: val_loss did not improve from 0.30556
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00018000000854954124.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 205ms/step - accuracy: 0.8612 - loss: 0.3146 - val_accuracy: 0.8621 - val_loss: 0.3096 - learning_rate: 6.0000e-04
# Epoch 15/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8384 - loss: 0.3258
# Epoch 15: val_loss did not improve from 0.30556
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 204ms/step - accuracy: 0.8384 - loss: 0.3258 - val_accuracy: 0.8667 - val_loss: 0.3074 - learning_rate: 1.8000e-04
# Epoch 16/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.8427 - loss: 0.3337
# Epoch 16: val_loss improved from 0.30556 to 0.30148, saving model to /content/drive/MyDrive/best_cnn_model_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step - accuracy: 0.8427 - loss: 0.3337 - val_accuracy: 0.8682 - val_loss: 0.3015 - learning_rate: 1.8000e-04
# Epoch 17/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.8590 - loss: 0.3023
# Epoch 17: val_loss did not improve from 0.30148
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 21s 224ms/step - accuracy: 0.8589 - loss: 0.3026 - val_accuracy: 0.8606 - val_loss: 0.3018 - learning_rate: 1.8000e-04
# Epoch 18/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8518 - loss: 0.3153
# Epoch 18: val_loss did not improve from 0.30148
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 5.400000081863254e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 204ms/step - accuracy: 0.8518 - loss: 0.3153 - val_accuracy: 0.8697 - val_loss: 0.3038 - learning_rate: 1.8000e-04
# Epoch 19/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8491 - loss: 0.3373
# Epoch 19: val_loss improved from 0.30148 to 0.29862, saving model to /content/drive/MyDrive/best_cnn_model_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s 220ms/step - accuracy: 0.8491 - loss: 0.3371 - val_accuracy: 0.8712 - val_loss: 0.2986 - learning_rate: 5.4000e-05
# Epoch 20/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.8583 - loss: 0.3041
# Epoch 20: val_loss improved from 0.29862 to 0.29841, saving model to /content/drive/MyDrive/best_cnn_model_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 21s 229ms/step - accuracy: 0.8584 - loss: 0.3042 - val_accuracy: 0.8742 - val_loss: 0.2984 - learning_rate: 5.4000e-05
# Epoch 21/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.8677 - loss: 0.3120
# Epoch 21: val_loss did not improve from 0.29841
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 233ms/step - accuracy: 0.8676 - loss: 0.3122 - val_accuracy: 0.8697 - val_loss: 0.2989 - learning_rate: 5.4000e-05
# Epoch 22/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.8403 - loss: 0.3278
# Epoch 22: val_loss did not improve from 0.29841
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.6200000027311033e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 204ms/step - accuracy: 0.8404 - loss: 0.3278 - val_accuracy: 0.8742 - val_loss: 0.3010 - learning_rate: 5.4000e-05
# Epoch 23/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8497 - loss: 0.3450
# Epoch 23: val_loss did not improve from 0.29841
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 203ms/step - accuracy: 0.8497 - loss: 0.3448 - val_accuracy: 0.8742 - val_loss: 0.2987 - learning_rate: 1.6200e-05
# Epoch 24/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8489 - loss: 0.3297
# Epoch 24: val_loss improved from 0.29841 to 0.29818, saving model to /content/drive/MyDrive/best_cnn_model_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 225ms/step - accuracy: 0.8488 - loss: 0.3298 - val_accuracy: 0.8773 - val_loss: 0.2982 - learning_rate: 1.6200e-05
# Epoch 25/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8577 - loss: 0.3301
# Epoch 25: val_loss did not improve from 0.29818
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s 219ms/step - accuracy: 0.8577 - loss: 0.3301 - val_accuracy: 0.8727 - val_loss: 0.2984 - learning_rate: 1.6200e-05
# Epoch 26/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8449 - loss: 0.3083
# Epoch 26: val_loss did not improve from 0.29818
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.859999899053946e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 201ms/step - accuracy: 0.8449 - loss: 0.3085 - val_accuracy: 0.8712 - val_loss: 0.2984 - learning_rate: 1.6200e-05
# Epoch 27/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.8616 - loss: 0.3219
# Epoch 27: val_loss did not improve from 0.29818
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s 216ms/step - accuracy: 0.8614 - loss: 0.3220 - val_accuracy: 0.8712 - val_loss: 0.2993 - learning_rate: 4.8600e-06
# Epoch 28/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8505 - loss: 0.3265
# Epoch 28: val_loss did not improve from 0.29818
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.4579999970010249e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 206ms/step - accuracy: 0.8505 - loss: 0.3263 - val_accuracy: 0.8742 - val_loss: 0.2991 - learning_rate: 4.8600e-06
# Epoch 29/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8408 - loss: 0.3367
# Epoch 29: val_loss did not improve from 0.29818
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 201ms/step - accuracy: 0.8409 - loss: 0.3365 - val_accuracy: 0.8712 - val_loss: 0.2989 - learning_rate: 1.4580e-06
# Epoch 30/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8415 - loss: 0.3513
# Epoch 30: val_loss did not improve from 0.29818
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 201ms/step - accuracy: 0.8415 - loss: 0.3510 - val_accuracy: 0.8697 - val_loss: 0.2995 - learning_rate: 1.4580e-06
# Epoch 31/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8415 - loss: 0.3307
# Epoch 31: val_loss did not improve from 0.29818
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s 213ms/step - accuracy: 0.8415 - loss: 0.3306 - val_accuracy: 0.8727 - val_loss: 0.2991 - learning_rate: 1.0000e-06
# Epoch 32/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.8611 - loss: 0.3132
# Epoch 32: val_loss improved from 0.29818 to 0.29817, saving model to /content/drive/MyDrive/best_cnn_model_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 209ms/step - accuracy: 0.8610 - loss: 0.3133 - val_accuracy: 0.8727 - val_loss: 0.2982 - learning_rate: 1.0000e-06
# Epoch 33/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.8456 - loss: 0.3307
# Epoch 33: val_loss improved from 0.29817 to 0.29782, saving model to /content/drive/MyDrive/best_cnn_model_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 23s 236ms/step - accuracy: 0.8457 - loss: 0.3306 - val_accuracy: 0.8742 - val_loss: 0.2978 - learning_rate: 1.0000e-06
# Epoch 34/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8581 - loss: 0.3275
# Epoch 34: val_loss did not improve from 0.29782
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 218ms/step - accuracy: 0.8581 - loss: 0.3275 - val_accuracy: 0.8727 - val_loss: 0.2987 - learning_rate: 1.0000e-06
# Epoch 35/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.8526 - loss: 0.3105
# Epoch 35: val_loss did not improve from 0.29782
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 200ms/step - accuracy: 0.8527 - loss: 0.3105 - val_accuracy: 0.8727 - val_loss: 0.2984 - learning_rate: 1.0000e-06
# Epoch 36/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8365 - loss: 0.3380
# Epoch 36: val_loss did not improve from 0.29782
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s 217ms/step - accuracy: 0.8366 - loss: 0.3378 - val_accuracy: 0.8742 - val_loss: 0.2988 - learning_rate: 1.0000e-06
# Epoch 37/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.8757 - loss: 0.3035
# Epoch 37: val_loss did not improve from 0.29782
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 209ms/step - accuracy: 0.8755 - loss: 0.3036 - val_accuracy: 0.8727 - val_loss: 0.2987 - learning_rate: 1.0000e-06
# Epoch 38/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8543 - loss: 0.3124
# Epoch 38: val_loss did not improve from 0.29782
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 205ms/step - accuracy: 0.8543 - loss: 0.3126 - val_accuracy: 0.8727 - val_loss: 0.2987 - learning_rate: 1.0000e-06
# Epoch 39/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.8478 - loss: 0.3212
# Epoch 39: val_loss did not improve from 0.29782
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 229ms/step - accuracy: 0.8478 - loss: 0.3213 - val_accuracy: 0.8727 - val_loss: 0.2984 - learning_rate: 1.0000e-06
# Epoch 40/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.8627 - loss: 0.2948
# Epoch 40: val_loss did not improve from 0.29782
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 203ms/step - accuracy: 0.8627 - loss: 0.2950 - val_accuracy: 0.8727 - val_loss: 0.2994 - learning_rate: 1.0000e-06
# Epoch 41/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8567 - loss: 0.3126
# Epoch 41: val_loss did not improve from 0.29782
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 200ms/step - accuracy: 0.8567 - loss: 0.3127 - val_accuracy: 0.8712 - val_loss: 0.2987 - learning_rate: 1.0000e-06
# Epoch 42/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8577 - loss: 0.3225
# Epoch 42: val_loss did not improve from 0.29782
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 19s 225ms/step - accuracy: 0.8576 - loss: 0.3224 - val_accuracy: 0.8727 - val_loss: 0.2989 - learning_rate: 1.0000e-06
# Epoch 43/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8646 - loss: 0.3075
# Epoch 43: val_loss did not improve from 0.29782
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 200ms/step - accuracy: 0.8646 - loss: 0.3076 - val_accuracy: 0.8727 - val_loss: 0.2988 - learning_rate: 1.0000e-06
# Epoch 44/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8660 - loss: 0.3100
# Epoch 44: val_loss did not improve from 0.29782
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 205ms/step - accuracy: 0.8658 - loss: 0.3103 - val_accuracy: 0.8712 - val_loss: 0.2983 - learning_rate: 1.0000e-06
# Epoch 45/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8490 - loss: 0.3259
# Epoch 45: val_loss did not improve from 0.29782
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 204ms/step - accuracy: 0.8490 - loss: 0.3259 - val_accuracy: 0.8727 - val_loss: 0.2980 - learning_rate: 1.0000e-06
# Epoch 46/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.8522 - loss: 0.3255
# Epoch 46: val_loss did not improve from 0.29782
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s 217ms/step - accuracy: 0.8522 - loss: 0.3254 - val_accuracy: 0.8727 - val_loss: 0.2979 - learning_rate: 1.0000e-06
# Epoch 47/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8493 - loss: 0.3230
# Epoch 47: val_loss did not improve from 0.29782
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 201ms/step - accuracy: 0.8493 - loss: 0.3231 - val_accuracy: 0.8727 - val_loss: 0.2981 - learning_rate: 1.0000e-06
# Epoch 48/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8587 - loss: 0.3102
# Epoch 48: val_loss did not improve from 0.29782
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 201ms/step - accuracy: 0.8587 - loss: 0.3103 - val_accuracy: 0.8727 - val_loss: 0.2985 - learning_rate: 1.0000e-06
# Epoch 49/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8595 - loss: 0.3175
# Epoch 49: val_loss did not improve from 0.29782
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 18s 216ms/step - accuracy: 0.8595 - loss: 0.3175 - val_accuracy: 0.8727 - val_loss: 0.2981 - learning_rate: 1.0000e-06
# Epoch 50/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8492 - loss: 0.3204
# Epoch 50: val_loss did not improve from 0.29782
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 201ms/step - accuracy: 0.8492 - loss: 0.3205 - val_accuracy: 0.8727 - val_loss: 0.2981 - learning_rate: 1.0000e-06
# Epoch 51/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8399 - loss: 0.3400
# Epoch 51: val_loss did not improve from 0.29782
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 17s 206ms/step - accuracy: 0.8399 - loss: 0.3399 - val_accuracy: 0.8727 - val_loss: 0.2983 - learning_rate: 1.0000e-06
# ✅ Model loaded from: /content/drive/MyDrive/best_cnn_model_adamax.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1]
# Valid labels: [0, 1]
# Target names: ['benign', 'malignant']
#
# Predicted sample count per class:
# benign: 341
# malignant: 319
#
# ✅ Overall Validation Accuracy: 87.42%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       benign       0.91      0.86      0.88       360
#    malignant       0.84      0.89      0.87       300
#
#     accuracy                           0.87       660
#    macro avg       0.87      0.88      0.87       660
# weighted avg       0.88      0.87      0.87       660
#
# ⚠️ Skipping ROC curve for Class 2 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 3 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 4 — no positive samples in y_true.
# Skipped ROC for classes with no positive samples: Class 2, Class 3, Class 4
# ✅ ROC curve saved to: /content/drive/MyDrive/diabetic_eye_results_adamax/roc_curve.png
# ✅ Model saved successfully at /content/drive/MyDrive/final_cnn_model_adamax.keras
