# %%
# -*- coding: utf-8 -*-
"""efficientnetB0_binary_nadam.ipynb"""

from google.colab import drive
drive.mount('/content/drive')

import zipfile, os

# === Dataset Extraction ===
zip_path = "/content/drive/MyDrive/d.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print("✅ Dataset extracted.")

# === Imports ===
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
import collections

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Nadam   # ✅ changed here

# === Dataset Paths ===
train_dir = "/content/dataset/d/train"
val_dir = "/content/dataset/d/val"

# === Data Generators ===
train_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)

# === Model Definition ===
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze first 100 layers
for layer in base_model.layers[:100]:
    layer.trainable = False
for layer in base_model.layers[100:]:
    layer.trainable = True

# Custom head
x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(2, activation='softmax')(x)   # ✅ 2 classes

model = Model(inputs=base_model.input, outputs=output)

# === Optimizer Nadam ===
optimizer = Nadam(
    learning_rate=1e-4,   # good starting point
    epsilon=1e-07
)

model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.build((None, 224, 224, 3))

# === Callbacks ===
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_efficientnetb0_binary_nadam.keras",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    verbose=1,
    min_lr=1e-6
)

# === Training ===
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=51,
    callbacks=[checkpoint, lr_scheduler]
)

# === Save Accuracy & Loss Plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

# === Load Best Model for Evaluation ===
model_path = "/content/drive/MyDrive/best_efficientnetb0_binary_nadam.keras"
model = tf.keras.models.load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Predictions ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

print("\n✅ Overall Validation Accuracy: {:.2f}%".format(accuracy_score(y_true, y_pred) * 100))

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# Classification Report
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0
))

# === ROC Curve (binary) ===
n_classes = 2
labels = target_names
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

fpr, tpr, roc_auc = {}, {}, {}

for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(7, 6))
for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.savefig(f"{graph_dir}/roc_curve.png")
plt.show()

# === Save Final Model ===
model.save("/content/drive/MyDrive/final_efficientnetb0_binary_nadam.keras")
print("✅ Final model saved.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Dataset extracted.
# Found 2637 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 833ms/step - accuracy: 0.6488 - loss: 0.7828
# Epoch 1: val_loss improved from inf to 0.50830, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_nadam.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.6497 - loss: 0.7811 - val_accuracy: 0.7545 - val_loss: 0.5083 - learning_rate: 1.0000e-04
# Epoch 2/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.7958 - loss: 0.5135
# Epoch 2: val_loss improved from 0.50830 to 0.37754, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_nadam.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 42s 507ms/step - accuracy: 0.7961 - loss: 0.5128 - val_accuracy: 0.8106 - val_loss: 0.3775 - learning_rate: 1.0000e-04
# Epoch 3/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.8219 - loss: 0.4402
# Epoch 3: val_loss improved from 0.37754 to 0.31338, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_nadam.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 43s 519ms/step - accuracy: 0.8219 - loss: 0.4398 - val_accuracy: 0.8576 - val_loss: 0.3134 - learning_rate: 1.0000e-04
# Epoch 4/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.8296 - loss: 0.3766
# Epoch 4: val_loss improved from 0.31338 to 0.30673, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_nadam.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 44s 535ms/step - accuracy: 0.8298 - loss: 0.3765 - val_accuracy: 0.8712 - val_loss: 0.3067 - learning_rate: 1.0000e-04
# Epoch 5/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.8799 - loss: 0.3144
# Epoch 5: val_loss did not improve from 0.30673
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 78s 491ms/step - accuracy: 0.8797 - loss: 0.3144 - val_accuracy: 0.8712 - val_loss: 0.3082 - learning_rate: 1.0000e-04
# Epoch 6/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.8729 - loss: 0.3175
# Epoch 6: val_loss improved from 0.30673 to 0.29814, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_nadam.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 43s 521ms/step - accuracy: 0.8730 - loss: 0.3173 - val_accuracy: 0.8788 - val_loss: 0.2981 - learning_rate: 1.0000e-04
# Epoch 7/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.8909 - loss: 0.2591
# Epoch 7: val_loss improved from 0.29814 to 0.28920, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_nadam.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 42s 510ms/step - accuracy: 0.8909 - loss: 0.2593 - val_accuracy: 0.8727 - val_loss: 0.2892 - learning_rate: 1.0000e-04
# Epoch 8/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - accuracy: 0.8838 - loss: 0.2671
# Epoch 8: val_loss did not improve from 0.28920
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 495ms/step - accuracy: 0.8839 - loss: 0.2669 - val_accuracy: 0.8848 - val_loss: 0.2916 - learning_rate: 1.0000e-04
# Epoch 9/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.9161 - loss: 0.2078
# Epoch 9: val_loss improved from 0.28920 to 0.27927, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_nadam.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 494ms/step - accuracy: 0.9160 - loss: 0.2081 - val_accuracy: 0.8758 - val_loss: 0.2793 - learning_rate: 1.0000e-04
# Epoch 10/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.9075 - loss: 0.2123
# Epoch 10: val_loss did not improve from 0.27927
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 81s 484ms/step - accuracy: 0.9074 - loss: 0.2125 - val_accuracy: 0.8773 - val_loss: 0.2953 - learning_rate: 1.0000e-04
# Epoch 11/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.9137 - loss: 0.1999
# Epoch 11: val_loss did not improve from 0.27927
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 491ms/step - accuracy: 0.9137 - loss: 0.2000 - val_accuracy: 0.8773 - val_loss: 0.2937 - learning_rate: 1.0000e-04
# Epoch 12/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.9157 - loss: 0.2016
# Epoch 12: val_loss did not improve from 0.27927
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 485ms/step - accuracy: 0.9158 - loss: 0.2014 - val_accuracy: 0.8818 - val_loss: 0.2829 - learning_rate: 1.0000e-04
# Epoch 13/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.9228 - loss: 0.1768
# Epoch 13: val_loss did not improve from 0.27927
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 480ms/step - accuracy: 0.9229 - loss: 0.1767 - val_accuracy: 0.8818 - val_loss: 0.2804 - learning_rate: 3.0000e-05
# Epoch 14/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.9201 - loss: 0.1930
# Epoch 14: val_loss improved from 0.27927 to 0.27825, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_nadam.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 488ms/step - accuracy: 0.9201 - loss: 0.1929 - val_accuracy: 0.8894 - val_loss: 0.2782 - learning_rate: 3.0000e-05
# Epoch 15/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - accuracy: 0.9231 - loss: 0.1742
# Epoch 15: val_loss improved from 0.27825 to 0.27262, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_nadam.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 44s 519ms/step - accuracy: 0.9232 - loss: 0.1742 - val_accuracy: 0.8924 - val_loss: 0.2726 - learning_rate: 3.0000e-05
# Epoch 16/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.9316 - loss: 0.1621
# Epoch 16: val_loss improved from 0.27262 to 0.27246, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_nadam.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 42s 507ms/step - accuracy: 0.9316 - loss: 0.1621 - val_accuracy: 0.8894 - val_loss: 0.2725 - learning_rate: 3.0000e-05
# Epoch 17/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.9296 - loss: 0.1774
# Epoch 17: val_loss improved from 0.27246 to 0.26974, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_nadam.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 81s 490ms/step - accuracy: 0.9297 - loss: 0.1772 - val_accuracy: 0.8894 - val_loss: 0.2697 - learning_rate: 3.0000e-05
# Epoch 18/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.9380 - loss: 0.1463
# Epoch 18: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 493ms/step - accuracy: 0.9379 - loss: 0.1463 - val_accuracy: 0.8909 - val_loss: 0.2717 - learning_rate: 3.0000e-05
# Epoch 19/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.9419 - loss: 0.1546
# Epoch 19: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 481ms/step - accuracy: 0.9418 - loss: 0.1547 - val_accuracy: 0.8864 - val_loss: 0.2760 - learning_rate: 3.0000e-05
# Epoch 20/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.9411 - loss: 0.1496
# Epoch 20: val_loss did not improve from 0.26974
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 478ms/step - accuracy: 0.9411 - loss: 0.1497 - val_accuracy: 0.8879 - val_loss: 0.2784 - learning_rate: 3.0000e-05
# Epoch 21/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.9501 - loss: 0.1334
# Epoch 21: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 477ms/step - accuracy: 0.9500 - loss: 0.1335 - val_accuracy: 0.8879 - val_loss: 0.2775 - learning_rate: 9.0000e-06
# Epoch 22/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.9364 - loss: 0.1475
# Epoch 22: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 477ms/step - accuracy: 0.9364 - loss: 0.1475 - val_accuracy: 0.8909 - val_loss: 0.2749 - learning_rate: 9.0000e-06
# Epoch 23/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.9477 - loss: 0.1327
# Epoch 23: val_loss did not improve from 0.26974
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 496ms/step - accuracy: 0.9477 - loss: 0.1327 - val_accuracy: 0.8955 - val_loss: 0.2758 - learning_rate: 9.0000e-06
# Epoch 24/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.9510 - loss: 0.1221
# Epoch 24: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 479ms/step - accuracy: 0.9510 - loss: 0.1222 - val_accuracy: 0.8924 - val_loss: 0.2766 - learning_rate: 2.7000e-06
# Epoch 25/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.9444 - loss: 0.1326
# Epoch 25: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 477ms/step - accuracy: 0.9443 - loss: 0.1328 - val_accuracy: 0.8909 - val_loss: 0.2766 - learning_rate: 2.7000e-06
# Epoch 26/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.9359 - loss: 0.1473
# Epoch 26: val_loss did not improve from 0.26974
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 42s 493ms/step - accuracy: 0.9359 - loss: 0.1472 - val_accuracy: 0.8924 - val_loss: 0.2764 - learning_rate: 2.7000e-06
# Epoch 27/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.9551 - loss: 0.1190
# Epoch 27: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 480ms/step - accuracy: 0.9551 - loss: 0.1191 - val_accuracy: 0.8924 - val_loss: 0.2771 - learning_rate: 1.0000e-06
# Epoch 28/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.9393 - loss: 0.1413
# Epoch 28: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 484ms/step - accuracy: 0.9393 - loss: 0.1413 - val_accuracy: 0.8894 - val_loss: 0.2775 - learning_rate: 1.0000e-06
# Epoch 29/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.9506 - loss: 0.1264
# Epoch 29: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 492ms/step - accuracy: 0.9506 - loss: 0.1264 - val_accuracy: 0.8924 - val_loss: 0.2763 - learning_rate: 1.0000e-06
# Epoch 30/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.9433 - loss: 0.1418
# Epoch 30: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 479ms/step - accuracy: 0.9433 - loss: 0.1417 - val_accuracy: 0.8909 - val_loss: 0.2758 - learning_rate: 1.0000e-06
# Epoch 31/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.9468 - loss: 0.1221
# Epoch 31: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 481ms/step - accuracy: 0.9467 - loss: 0.1222 - val_accuracy: 0.8924 - val_loss: 0.2753 - learning_rate: 1.0000e-06
# Epoch 32/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.9344 - loss: 0.1640
# Epoch 32: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 479ms/step - accuracy: 0.9345 - loss: 0.1639 - val_accuracy: 0.8955 - val_loss: 0.2760 - learning_rate: 1.0000e-06
# Epoch 33/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.9443 - loss: 0.1359
# Epoch 33: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 476ms/step - accuracy: 0.9443 - loss: 0.1359 - val_accuracy: 0.8924 - val_loss: 0.2763 - learning_rate: 1.0000e-06
# Epoch 34/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.9426 - loss: 0.1407
# Epoch 34: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 476ms/step - accuracy: 0.9427 - loss: 0.1407 - val_accuracy: 0.8909 - val_loss: 0.2771 - learning_rate: 1.0000e-06
# Epoch 35/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.9370 - loss: 0.1411
# Epoch 35: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 477ms/step - accuracy: 0.9370 - loss: 0.1410 - val_accuracy: 0.8909 - val_loss: 0.2761 - learning_rate: 1.0000e-06
# Epoch 36/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.9430 - loss: 0.1277
# Epoch 36: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 481ms/step - accuracy: 0.9431 - loss: 0.1276 - val_accuracy: 0.8939 - val_loss: 0.2758 - learning_rate: 1.0000e-06
# Epoch 37/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.9467 - loss: 0.1294
# Epoch 37: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 478ms/step - accuracy: 0.9467 - loss: 0.1295 - val_accuracy: 0.8939 - val_loss: 0.2749 - learning_rate: 1.0000e-06
# Epoch 38/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.9376 - loss: 0.1395
# Epoch 38: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 483ms/step - accuracy: 0.9376 - loss: 0.1394 - val_accuracy: 0.8909 - val_loss: 0.2757 - learning_rate: 1.0000e-06
# Epoch 39/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.9427 - loss: 0.1349
# Epoch 39: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 497ms/step - accuracy: 0.9428 - loss: 0.1348 - val_accuracy: 0.8909 - val_loss: 0.2755 - learning_rate: 1.0000e-06
# Epoch 40/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.9471 - loss: 0.1359
# Epoch 40: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 42s 500ms/step - accuracy: 0.9471 - loss: 0.1358 - val_accuracy: 0.8894 - val_loss: 0.2751 - learning_rate: 1.0000e-06
# Epoch 41/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.9510 - loss: 0.1370
# Epoch 41: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 481ms/step - accuracy: 0.9509 - loss: 0.1371 - val_accuracy: 0.8924 - val_loss: 0.2775 - learning_rate: 1.0000e-06
# Epoch 42/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.9393 - loss: 0.1354
# Epoch 42: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 483ms/step - accuracy: 0.9393 - loss: 0.1354 - val_accuracy: 0.8909 - val_loss: 0.2771 - learning_rate: 1.0000e-06
# Epoch 43/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.9495 - loss: 0.1219
# Epoch 43: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 482ms/step - accuracy: 0.9496 - loss: 0.1219 - val_accuracy: 0.8909 - val_loss: 0.2764 - learning_rate: 1.0000e-06
# Epoch 44/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.9421 - loss: 0.1543
# Epoch 44: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 483ms/step - accuracy: 0.9421 - loss: 0.1542 - val_accuracy: 0.8939 - val_loss: 0.2773 - learning_rate: 1.0000e-06
# Epoch 45/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.9395 - loss: 0.1467
# Epoch 45: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 484ms/step - accuracy: 0.9395 - loss: 0.1466 - val_accuracy: 0.8924 - val_loss: 0.2769 - learning_rate: 1.0000e-06
# Epoch 46/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.9407 - loss: 0.1302
# Epoch 46: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 483ms/step - accuracy: 0.9407 - loss: 0.1302 - val_accuracy: 0.8879 - val_loss: 0.2759 - learning_rate: 1.0000e-06
# Epoch 47/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.9476 - loss: 0.1156
# Epoch 47: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 495ms/step - accuracy: 0.9476 - loss: 0.1156 - val_accuracy: 0.8909 - val_loss: 0.2751 - learning_rate: 1.0000e-06
# Epoch 48/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.9411 - loss: 0.1532
# Epoch 48: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 483ms/step - accuracy: 0.9412 - loss: 0.1531 - val_accuracy: 0.8955 - val_loss: 0.2780 - learning_rate: 1.0000e-06
# Epoch 49/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.9475 - loss: 0.1239
# Epoch 49: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 497ms/step - accuracy: 0.9474 - loss: 0.1242 - val_accuracy: 0.8924 - val_loss: 0.2769 - learning_rate: 1.0000e-06
# Epoch 50/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.9503 - loss: 0.1234
# Epoch 50: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 489ms/step - accuracy: 0.9504 - loss: 0.1233 - val_accuracy: 0.8939 - val_loss: 0.2772 - learning_rate: 1.0000e-06
# Epoch 51/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.9505 - loss: 0.1209
# Epoch 51: val_loss did not improve from 0.26974
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 466ms/step - accuracy: 0.9505 - loss: 0.1209 - val_accuracy: 0.8924 - val_loss: 0.2771 - learning_rate: 1.0000e-06
# ✅ Model loaded from: /content/drive/MyDrive/best_efficientnetb0_binary_nadam.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 400ms/step
#
# ✅ Overall Validation Accuracy: 88.94%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       benign       0.89      0.91      0.90       360
#    malignant       0.89      0.86      0.88       300
#
#     accuracy                           0.89       660
#    macro avg       0.89      0.89      0.89       660
# weighted avg       0.89      0.89      0.89       660
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-676564380.py in <cell line: 0>()
#     195
#     196 for i in range(n_classes):
# --> 197     if np.sum(y_true_bin[:, i]) == 0:
#     198         continue
#     199     fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
