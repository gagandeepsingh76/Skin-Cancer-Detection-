# %%
# -*- coding: utf-8 -*-
"""MobileNetV3.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1YX65u1w9glAk0nmVr8F2nocjXAFn6axO
"""

from google.colab import drive
drive.mount('/content/drive')

import zipfile, os

zip_path = "/content/drive/MyDrive/d.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras.applications.mobilenet_v3 import preprocess_input

train_dir = "/content/dataset/d/train"
val_dir = "/content/dataset/d/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)

from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

base_model = MobileNetV3Large(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

# Freeze initial layers (adjust index based on MobileNetV3 architecture depth)
for layer in base_model.layers[:150]:  # MobileNetV3Large has ~270 layers
    layer.trainable = False

# Unfreeze later layers for fine-tuning
for layer in base_model.layers[150:]:
    layer.trainable = True

x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(2, activation='softmax')(x)  # Number of classes set to 2

model = Model(inputs=base_model.input, outputs=output)

# ----------------------------
# Optimizer: Adamax
# ----------------------------
from tensorflow.keras.optimizers import Adamax

# Configuration (adjust learning_rate if needed)
adamax_lr = 1e-3
optimizer = Adamax(learning_rate=adamax_lr)

# Compile model (loss remains sparse categorical since we use softmax with 2 outputs)
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Optional: build the model (only needed if model has not been fit before)
model.build((None, 224, 224, 3))

# Callbacks — updated checkpoint filename
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_mobilenetv3large_model.keras",  # Updated filename
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# Fit the model for 51 epochs (no EarlyStopping)
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=51,
    callbacks=[checkpoint, lr_scheduler]
)

import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained MobileNetV3Large model ===
model_path = "/content/drive/MyDrive/best_mobilenetv3large_model.keras"  # Updated path
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))

import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
# y_true: true labels (e.g., [0, 1, 1, 0, ...]), shape = (n_samples,)

# pred_probs: predicted probabilities, shape = (n_samples, n_classes)
# labels: class names (optional, replace with your own)
# graph_dir: directory where to save plot

n_classes = 2
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = "./plots"

# Ensure output directory exists
os.makedirs(graph_dir, exist_ok=True)

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")

model.save("/content/drive/MyDrive/final_resnet152_model.keras")
# Out:
# Mounted at /content/drive
#  Dataset extracted.
# Found 2637 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 626ms/step - accuracy: 0.7438 - loss: 0.6092
# Epoch 1: val_loss improved from inf to 0.87034, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 107s 944ms/step - accuracy: 0.7443 - loss: 0.6082 - val_accuracy: 0.6348 - val_loss: 0.8703 - learning_rate: 0.0010
# Epoch 2/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.8527 - loss: 0.3234
# Epoch 2: val_loss did not improve from 0.87034
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 564ms/step - accuracy: 0.8527 - loss: 0.3235 - val_accuracy: 0.5955 - val_loss: 1.0647 - learning_rate: 0.0010
# Epoch 3/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.8792 - loss: 0.3001
# Epoch 3: val_loss did not improve from 0.87034
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 558ms/step - accuracy: 0.8791 - loss: 0.3000 - val_accuracy: 0.6379 - val_loss: 1.1428 - learning_rate: 0.0010
# Epoch 4/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.8962 - loss: 0.2536
# Epoch 4: val_loss did not improve from 0.87034
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 577ms/step - accuracy: 0.8961 - loss: 0.2536 - val_accuracy: 0.6303 - val_loss: 1.2107 - learning_rate: 3.0000e-04
# Epoch 5/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.8905 - loss: 0.2701
# Epoch 5: val_loss did not improve from 0.87034
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 554ms/step - accuracy: 0.8906 - loss: 0.2698 - val_accuracy: 0.6409 - val_loss: 1.0980 - learning_rate: 3.0000e-04
# Epoch 6/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.9016 - loss: 0.2329
# Epoch 6: val_loss did not improve from 0.87034
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 567ms/step - accuracy: 0.9015 - loss: 0.2331 - val_accuracy: 0.6561 - val_loss: 1.0016 - learning_rate: 9.0000e-05
# Epoch 7/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - accuracy: 0.8974 - loss: 0.2434
# Epoch 7: val_loss did not improve from 0.87034
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 567ms/step - accuracy: 0.8974 - loss: 0.2432 - val_accuracy: 0.6833 - val_loss: 0.8817 - learning_rate: 9.0000e-05
# Epoch 8/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.9046 - loss: 0.2160
# Epoch 8: val_loss improved from 0.87034 to 0.79928, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 568ms/step - accuracy: 0.9045 - loss: 0.2162 - val_accuracy: 0.6955 - val_loss: 0.7993 - learning_rate: 2.7000e-05
# Epoch 9/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.9050 - loss: 0.2176
# Epoch 9: val_loss improved from 0.79928 to 0.69220, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 59s 710ms/step - accuracy: 0.9050 - loss: 0.2176 - val_accuracy: 0.7303 - val_loss: 0.6922 - learning_rate: 2.7000e-05
# Epoch 10/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.9023 - loss: 0.2300
# Epoch 10: val_loss improved from 0.69220 to 0.67124, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 69s 558ms/step - accuracy: 0.9024 - loss: 0.2300 - val_accuracy: 0.7439 - val_loss: 0.6712 - learning_rate: 2.7000e-05
# Epoch 11/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.9124 - loss: 0.1936
# Epoch 11: val_loss improved from 0.67124 to 0.54954, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 576ms/step - accuracy: 0.9124 - loss: 0.1937 - val_accuracy: 0.7652 - val_loss: 0.5495 - learning_rate: 2.7000e-05
# Epoch 12/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step - accuracy: 0.9030 - loss: 0.2298
# Epoch 12: val_loss improved from 0.54954 to 0.52781, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 81s 561ms/step - accuracy: 0.9029 - loss: 0.2299 - val_accuracy: 0.7833 - val_loss: 0.5278 - learning_rate: 2.7000e-05
# Epoch 13/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.8838 - loss: 0.2542
# Epoch 13: val_loss improved from 0.52781 to 0.50796, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 578ms/step - accuracy: 0.8839 - loss: 0.2540 - val_accuracy: 0.7939 - val_loss: 0.5080 - learning_rate: 2.7000e-05
# Epoch 14/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.9043 - loss: 0.2277
# Epoch 14: val_loss improved from 0.50796 to 0.40366, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 80s 559ms/step - accuracy: 0.9042 - loss: 0.2277 - val_accuracy: 0.8212 - val_loss: 0.4037 - learning_rate: 2.7000e-05
# Epoch 15/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.9011 - loss: 0.2275
# Epoch 15: val_loss did not improve from 0.40366
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 576ms/step - accuracy: 0.9012 - loss: 0.2273 - val_accuracy: 0.8333 - val_loss: 0.4109 - learning_rate: 2.7000e-05
# Epoch 16/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.9246 - loss: 0.1884
# Epoch 16: val_loss improved from 0.40366 to 0.39326, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 559ms/step - accuracy: 0.9245 - loss: 0.1887 - val_accuracy: 0.8288 - val_loss: 0.3933 - learning_rate: 2.7000e-05
# Epoch 17/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.9084 - loss: 0.2094
# Epoch 17: val_loss improved from 0.39326 to 0.37034, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 587ms/step - accuracy: 0.9084 - loss: 0.2095 - val_accuracy: 0.8348 - val_loss: 0.3703 - learning_rate: 2.7000e-05
# Epoch 18/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.9090 - loss: 0.2206
# Epoch 18: val_loss improved from 0.37034 to 0.34589, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 568ms/step - accuracy: 0.9089 - loss: 0.2205 - val_accuracy: 0.8485 - val_loss: 0.3459 - learning_rate: 2.7000e-05
# Epoch 19/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.9106 - loss: 0.1946
# Epoch 19: val_loss did not improve from 0.34589
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 575ms/step - accuracy: 0.9106 - loss: 0.1947 - val_accuracy: 0.8530 - val_loss: 0.3466 - learning_rate: 2.7000e-05
# Epoch 20/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.8973 - loss: 0.2195
# Epoch 20: val_loss improved from 0.34589 to 0.30804, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 558ms/step - accuracy: 0.8974 - loss: 0.2195 - val_accuracy: 0.8636 - val_loss: 0.3080 - learning_rate: 2.7000e-05
# Epoch 21/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.8975 - loss: 0.2250
# Epoch 21: val_loss improved from 0.30804 to 0.29022, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 584ms/step - accuracy: 0.8975 - loss: 0.2250 - val_accuracy: 0.8682 - val_loss: 0.2902 - learning_rate: 2.7000e-05
# Epoch 22/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.9025 - loss: 0.2157
# Epoch 22: val_loss did not improve from 0.29022
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 552ms/step - accuracy: 0.9025 - loss: 0.2156 - val_accuracy: 0.8576 - val_loss: 0.3058 - learning_rate: 2.7000e-05
# Epoch 23/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.9027 - loss: 0.2305
# Epoch 23: val_loss did not improve from 0.29022
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 559ms/step - accuracy: 0.9027 - loss: 0.2303 - val_accuracy: 0.8727 - val_loss: 0.2960 - learning_rate: 2.7000e-05
# Epoch 24/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.9073 - loss: 0.2150
# Epoch 24: val_loss did not improve from 0.29022
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 45s 545ms/step - accuracy: 0.9074 - loss: 0.2148 - val_accuracy: 0.8591 - val_loss: 0.2949 - learning_rate: 8.1000e-06
# Epoch 25/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.9062 - loss: 0.2027
# Epoch 25: val_loss improved from 0.29022 to 0.28897, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 566ms/step - accuracy: 0.9062 - loss: 0.2028 - val_accuracy: 0.8818 - val_loss: 0.2890 - learning_rate: 8.1000e-06
# Epoch 26/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.9068 - loss: 0.2156
# Epoch 26: val_loss improved from 0.28897 to 0.26387, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 554ms/step - accuracy: 0.9069 - loss: 0.2155 - val_accuracy: 0.8773 - val_loss: 0.2639 - learning_rate: 8.1000e-06
# Epoch 27/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.9103 - loss: 0.1997
# Epoch 27: val_loss did not improve from 0.26387
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 578ms/step - accuracy: 0.9104 - loss: 0.1996 - val_accuracy: 0.8758 - val_loss: 0.2655 - learning_rate: 8.1000e-06
# Epoch 28/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.9151 - loss: 0.2086
# Epoch 28: val_loss did not improve from 0.26387
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 45s 545ms/step - accuracy: 0.9151 - loss: 0.2086 - val_accuracy: 0.8788 - val_loss: 0.2641 - learning_rate: 8.1000e-06
# Epoch 29/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9120 - loss: 0.2102
# Epoch 29: val_loss did not improve from 0.26387
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 575ms/step - accuracy: 0.9120 - loss: 0.2103 - val_accuracy: 0.8667 - val_loss: 0.2971 - learning_rate: 2.4300e-06
# Epoch 30/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.9092 - loss: 0.2061
# Epoch 30: val_loss did not improve from 0.26387
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 45s 546ms/step - accuracy: 0.9093 - loss: 0.2060 - val_accuracy: 0.8682 - val_loss: 0.2748 - learning_rate: 2.4300e-06
# Epoch 31/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.9205 - loss: 0.1944
# Epoch 31: val_loss did not improve from 0.26387
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 556ms/step - accuracy: 0.9205 - loss: 0.1945 - val_accuracy: 0.8727 - val_loss: 0.2689 - learning_rate: 1.0000e-06
# Epoch 32/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.9077 - loss: 0.2114
# Epoch 32: val_loss improved from 0.26387 to 0.25256, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 564ms/step - accuracy: 0.9078 - loss: 0.2112 - val_accuracy: 0.8803 - val_loss: 0.2526 - learning_rate: 1.0000e-06
# Epoch 33/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.9267 - loss: 0.1872
# Epoch 33: val_loss did not improve from 0.25256
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 80s 547ms/step - accuracy: 0.9267 - loss: 0.1872 - val_accuracy: 0.8788 - val_loss: 0.2567 - learning_rate: 1.0000e-06
# Epoch 34/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.9113 - loss: 0.2048
# Epoch 34: val_loss did not improve from 0.25256
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 568ms/step - accuracy: 0.9113 - loss: 0.2048 - val_accuracy: 0.8682 - val_loss: 0.2614 - learning_rate: 1.0000e-06
# Epoch 35/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9192 - loss: 0.1930
# Epoch 35: val_loss improved from 0.25256 to 0.25079, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 557ms/step - accuracy: 0.9191 - loss: 0.1931 - val_accuracy: 0.8879 - val_loss: 0.2508 - learning_rate: 1.0000e-06
# Epoch 36/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.9078 - loss: 0.2167
# Epoch 36: val_loss did not improve from 0.25079
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 576ms/step - accuracy: 0.9079 - loss: 0.2165 - val_accuracy: 0.8773 - val_loss: 0.2567 - learning_rate: 1.0000e-06
# Epoch 37/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9002 - loss: 0.2096
# Epoch 37: val_loss improved from 0.25079 to 0.24753, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 557ms/step - accuracy: 0.9003 - loss: 0.2096 - val_accuracy: 0.8894 - val_loss: 0.2475 - learning_rate: 1.0000e-06
# Epoch 38/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.9076 - loss: 0.2109
# Epoch 38: val_loss did not improve from 0.24753
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 584ms/step - accuracy: 0.9076 - loss: 0.2110 - val_accuracy: 0.8803 - val_loss: 0.2523 - learning_rate: 1.0000e-06
# Epoch 39/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.9118 - loss: 0.1967
# Epoch 39: val_loss improved from 0.24753 to 0.23604, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 555ms/step - accuracy: 0.9118 - loss: 0.1968 - val_accuracy: 0.8864 - val_loss: 0.2360 - learning_rate: 1.0000e-06
# Epoch 40/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.9212 - loss: 0.1954
# Epoch 40: val_loss improved from 0.23604 to 0.22608, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 578ms/step - accuracy: 0.9212 - loss: 0.1954 - val_accuracy: 0.8924 - val_loss: 0.2261 - learning_rate: 1.0000e-06
# Epoch 41/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.9165 - loss: 0.2067
# Epoch 41: val_loss did not improve from 0.22608
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 555ms/step - accuracy: 0.9165 - loss: 0.2068 - val_accuracy: 0.8773 - val_loss: 0.2561 - learning_rate: 1.0000e-06
# Epoch 42/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.9120 - loss: 0.2121
# Epoch 42: val_loss did not improve from 0.22608
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 571ms/step - accuracy: 0.9120 - loss: 0.2121 - val_accuracy: 0.8833 - val_loss: 0.2562 - learning_rate: 1.0000e-06
# Epoch 43/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9139 - loss: 0.2105
# Epoch 43: val_loss did not improve from 0.22608
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 550ms/step - accuracy: 0.9140 - loss: 0.2104 - val_accuracy: 0.8773 - val_loss: 0.2757 - learning_rate: 1.0000e-06
# Epoch 44/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.9154 - loss: 0.2037
# Epoch 44: val_loss did not improve from 0.22608
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 564ms/step - accuracy: 0.9154 - loss: 0.2037 - val_accuracy: 0.8848 - val_loss: 0.2697 - learning_rate: 1.0000e-06
# Epoch 45/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.8972 - loss: 0.2312
# Epoch 45: val_loss did not improve from 0.22608
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 45s 547ms/step - accuracy: 0.8974 - loss: 0.2309 - val_accuracy: 0.8803 - val_loss: 0.2723 - learning_rate: 1.0000e-06
# Epoch 46/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.9136 - loss: 0.2037
# Epoch 46: val_loss did not improve from 0.22608
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 571ms/step - accuracy: 0.9136 - loss: 0.2037 - val_accuracy: 0.8848 - val_loss: 0.2496 - learning_rate: 1.0000e-06
# Epoch 47/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.9198 - loss: 0.1992
# Epoch 47: val_loss did not improve from 0.22608
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 551ms/step - accuracy: 0.9197 - loss: 0.1992 - val_accuracy: 0.8803 - val_loss: 0.2493 - learning_rate: 1.0000e-06
# Epoch 48/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9228 - loss: 0.1950
# Epoch 48: val_loss did not improve from 0.22608
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 575ms/step - accuracy: 0.9228 - loss: 0.1951 - val_accuracy: 0.8773 - val_loss: 0.2605 - learning_rate: 1.0000e-06
# Epoch 49/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.9249 - loss: 0.1838
# Epoch 49: val_loss did not improve from 0.22608
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 45s 548ms/step - accuracy: 0.9248 - loss: 0.1839 - val_accuracy: 0.8803 - val_loss: 0.2463 - learning_rate: 1.0000e-06
# Epoch 50/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.9154 - loss: 0.1891
# Epoch 50: val_loss did not improve from 0.22608
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 560ms/step - accuracy: 0.9153 - loss: 0.1893 - val_accuracy: 0.8879 - val_loss: 0.2459 - learning_rate: 1.0000e-06
# Epoch 51/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.9110 - loss: 0.2031
# Epoch 51: val_loss did not improve from 0.22608
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 547ms/step - accuracy: 0.9109 - loss: 0.2033 - val_accuracy: 0.8894 - val_loss: 0.2581 - learning_rate: 1.0000e-06
# ✅ Model loaded from: /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 19s 649ms/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1]
# Valid labels: [0, 1]
# Target names: ['benign', 'malignant']
#
# Predicted sample count per class:
# benign: 374
# malignant: 286
#
# ✅ Overall Validation Accuracy: 87.27%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       benign       0.87      0.90      0.89       360
#    malignant       0.88      0.84      0.86       300
#
#     accuracy                           0.87       660
#    macro avg       0.87      0.87      0.87       660
# weighted avg       0.87      0.87      0.87       660
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3809639178.py in <cell line: 0>()
#     274 # Compute ROC for each class
#     275 for i in range(n_classes):
# --> 276     if np.sum(y_true_bin[:, i]) == 0:
#     277         print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
#     278         missing_classes.append(labels[i])
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
