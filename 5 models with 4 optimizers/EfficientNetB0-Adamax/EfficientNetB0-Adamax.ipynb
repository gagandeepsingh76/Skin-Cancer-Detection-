# %%
# -*- coding: utf-8 -*-
"""efficientnetB0_binary_adamax.ipynb"""

from google.colab import drive
drive.mount('/content/drive')

import zipfile, os

# === Dataset Extraction ===
zip_path = "/content/drive/MyDrive/d.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print("✅ Dataset extracted.")

# === Imports ===
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
import collections

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adamax   # ✅ updated here

# === Dataset Paths ===
train_dir = "/content/dataset/d/train"
val_dir = "/content/dataset/d/val"

# === Data Generators ===
train_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)

# === Model Definition ===
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze first 100 layers
for layer in base_model.layers[:100]:
    layer.trainable = False
for layer in base_model.layers[100:]:
    layer.trainable = True

# Custom head
x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(2, activation='softmax')(x)   # ✅ 2 classes

model = Model(inputs=base_model.input, outputs=output)

# === Optimizer Adamax ===
optimizer = Adamax(
    learning_rate=1e-4,
    epsilon=1e-07
)

model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.build((None, 224, 224, 3))

# === Callbacks ===
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    verbose=1,
    min_lr=1e-6
)

# === Training ===
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=51,
    callbacks=[checkpoint, lr_scheduler]
)

# === Save Accuracy & Loss Plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

# === Load Best Model for Evaluation ===
model_path = "/content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras"
model = tf.keras.models.load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Predictions ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

print("\n✅ Overall Validation Accuracy: {:.2f}%".format(accuracy_score(y_true, y_pred) * 100))

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# Classification Report
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0
))

# === ROC Curve (binary) ===
n_classes = 2
labels = target_names
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

fpr, tpr, roc_auc = {}, {}, {}

for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(7, 6))
for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.savefig(f"{graph_dir}/roc_curve.png")
plt.show()

# === Save Final Model ===
model.save("/content/drive/MyDrive/final_efficientnetb0_binary_adamax.keras")
print("✅ Final model saved.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Dataset extracted.
# Found 2637 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 781ms/step - accuracy: 0.6177 - loss: 0.8413
# Epoch 1: val_loss improved from inf to 0.54695, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 135s 999ms/step - accuracy: 0.6185 - loss: 0.8397 - val_accuracy: 0.6742 - val_loss: 0.5470 - learning_rate: 1.0000e-04
# Epoch 2/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.7658 - loss: 0.5665
# Epoch 2: val_loss improved from 0.54695 to 0.44047, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 480ms/step - accuracy: 0.7659 - loss: 0.5662 - val_accuracy: 0.7682 - val_loss: 0.4405 - learning_rate: 1.0000e-04
# Epoch 3/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.8007 - loss: 0.5112
# Epoch 3: val_loss improved from 0.44047 to 0.39393, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 486ms/step - accuracy: 0.8007 - loss: 0.5110 - val_accuracy: 0.8136 - val_loss: 0.3939 - learning_rate: 1.0000e-04
# Epoch 4/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.8047 - loss: 0.4766
# Epoch 4: val_loss improved from 0.39393 to 0.37366, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 490ms/step - accuracy: 0.8048 - loss: 0.4764 - val_accuracy: 0.8379 - val_loss: 0.3737 - learning_rate: 1.0000e-04
# Epoch 5/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.8136 - loss: 0.4338
# Epoch 5: val_loss improved from 0.37366 to 0.36428, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 496ms/step - accuracy: 0.8138 - loss: 0.4336 - val_accuracy: 0.8439 - val_loss: 0.3643 - learning_rate: 1.0000e-04
# Epoch 6/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.8239 - loss: 0.4442
# Epoch 6: val_loss did not improve from 0.36428
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 477ms/step - accuracy: 0.8239 - loss: 0.4442 - val_accuracy: 0.8500 - val_loss: 0.3653 - learning_rate: 1.0000e-04
# Epoch 7/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.8402 - loss: 0.3800
# Epoch 7: val_loss did not improve from 0.36428
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 472ms/step - accuracy: 0.8402 - loss: 0.3800 - val_accuracy: 0.8530 - val_loss: 0.3658 - learning_rate: 1.0000e-04
# Epoch 8/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step - accuracy: 0.8383 - loss: 0.4003
# Epoch 8: val_loss improved from 0.36428 to 0.35696, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 473ms/step - accuracy: 0.8383 - loss: 0.4001 - val_accuracy: 0.8576 - val_loss: 0.3570 - learning_rate: 1.0000e-04
# Epoch 9/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - accuracy: 0.8411 - loss: 0.3917
# Epoch 9: val_loss improved from 0.35696 to 0.35132, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 483ms/step - accuracy: 0.8412 - loss: 0.3914 - val_accuracy: 0.8621 - val_loss: 0.3513 - learning_rate: 1.0000e-04
# Epoch 10/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.8521 - loss: 0.3756
# Epoch 10: val_loss improved from 0.35132 to 0.34886, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 494ms/step - accuracy: 0.8521 - loss: 0.3755 - val_accuracy: 0.8576 - val_loss: 0.3489 - learning_rate: 1.0000e-04
# Epoch 11/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.8582 - loss: 0.3226
# Epoch 11: val_loss improved from 0.34886 to 0.33874, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 493ms/step - accuracy: 0.8581 - loss: 0.3226 - val_accuracy: 0.8561 - val_loss: 0.3387 - learning_rate: 1.0000e-04
# Epoch 12/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.8430 - loss: 0.3658
# Epoch 12: val_loss improved from 0.33874 to 0.33521, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 492ms/step - accuracy: 0.8432 - loss: 0.3655 - val_accuracy: 0.8545 - val_loss: 0.3352 - learning_rate: 1.0000e-04
# Epoch 13/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.8727 - loss: 0.3087
# Epoch 13: val_loss improved from 0.33521 to 0.32967, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 490ms/step - accuracy: 0.8726 - loss: 0.3090 - val_accuracy: 0.8621 - val_loss: 0.3297 - learning_rate: 1.0000e-04
# Epoch 14/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.8704 - loss: 0.3076
# Epoch 14: val_loss improved from 0.32967 to 0.32716, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 488ms/step - accuracy: 0.8703 - loss: 0.3078 - val_accuracy: 0.8621 - val_loss: 0.3272 - learning_rate: 1.0000e-04
# Epoch 15/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.8700 - loss: 0.3014
# Epoch 15: val_loss improved from 0.32716 to 0.32610, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 494ms/step - accuracy: 0.8700 - loss: 0.3014 - val_accuracy: 0.8606 - val_loss: 0.3261 - learning_rate: 1.0000e-04
# Epoch 16/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step - accuracy: 0.8847 - loss: 0.2644
# Epoch 16: val_loss improved from 0.32610 to 0.32231, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 80s 472ms/step - accuracy: 0.8846 - loss: 0.2645 - val_accuracy: 0.8591 - val_loss: 0.3223 - learning_rate: 1.0000e-04
# Epoch 17/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.8813 - loss: 0.2888
# Epoch 17: val_loss improved from 0.32231 to 0.32121, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 493ms/step - accuracy: 0.8813 - loss: 0.2887 - val_accuracy: 0.8606 - val_loss: 0.3212 - learning_rate: 1.0000e-04
# Epoch 18/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.9010 - loss: 0.2449
# Epoch 18: val_loss improved from 0.32121 to 0.31498, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 81s 485ms/step - accuracy: 0.9009 - loss: 0.2449 - val_accuracy: 0.8576 - val_loss: 0.3150 - learning_rate: 1.0000e-04
# Epoch 19/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.8921 - loss: 0.2834
# Epoch 19: val_loss improved from 0.31498 to 0.31257, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 491ms/step - accuracy: 0.8920 - loss: 0.2835 - val_accuracy: 0.8545 - val_loss: 0.3126 - learning_rate: 1.0000e-04
# Epoch 20/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.8815 - loss: 0.2627
# Epoch 20: val_loss improved from 0.31257 to 0.31107, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 493ms/step - accuracy: 0.8816 - loss: 0.2626 - val_accuracy: 0.8621 - val_loss: 0.3111 - learning_rate: 1.0000e-04
# Epoch 21/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.8853 - loss: 0.2909
# Epoch 21: val_loss improved from 0.31107 to 0.31103, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 492ms/step - accuracy: 0.8853 - loss: 0.2906 - val_accuracy: 0.8652 - val_loss: 0.3110 - learning_rate: 1.0000e-04
# Epoch 22/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.8986 - loss: 0.2442
# Epoch 22: val_loss improved from 0.31103 to 0.30792, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 486ms/step - accuracy: 0.8985 - loss: 0.2444 - val_accuracy: 0.8591 - val_loss: 0.3079 - learning_rate: 1.0000e-04
# Epoch 23/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.8770 - loss: 0.2809
# Epoch 23: val_loss improved from 0.30792 to 0.30423, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 482ms/step - accuracy: 0.8771 - loss: 0.2807 - val_accuracy: 0.8667 - val_loss: 0.3042 - learning_rate: 1.0000e-04
# Epoch 24/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.9045 - loss: 0.2516
# Epoch 24: val_loss improved from 0.30423 to 0.29775, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 42s 499ms/step - accuracy: 0.9045 - loss: 0.2516 - val_accuracy: 0.8712 - val_loss: 0.2977 - learning_rate: 1.0000e-04
# Epoch 25/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.8964 - loss: 0.2315
# Epoch 25: val_loss did not improve from 0.29775
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 79s 468ms/step - accuracy: 0.8964 - loss: 0.2315 - val_accuracy: 0.8697 - val_loss: 0.2985 - learning_rate: 1.0000e-04
# Epoch 26/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.9004 - loss: 0.2426
# Epoch 26: val_loss improved from 0.29775 to 0.29573, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 490ms/step - accuracy: 0.9004 - loss: 0.2425 - val_accuracy: 0.8758 - val_loss: 0.2957 - learning_rate: 1.0000e-04
# Epoch 27/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.8943 - loss: 0.2774
# Epoch 27: val_loss improved from 0.29573 to 0.29339, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 487ms/step - accuracy: 0.8944 - loss: 0.2770 - val_accuracy: 0.8742 - val_loss: 0.2934 - learning_rate: 1.0000e-04
# Epoch 28/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.8919 - loss: 0.2445
# Epoch 28: val_loss improved from 0.29339 to 0.28991, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 487ms/step - accuracy: 0.8920 - loss: 0.2443 - val_accuracy: 0.8788 - val_loss: 0.2899 - learning_rate: 1.0000e-04
# Epoch 29/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.9245 - loss: 0.1934
# Epoch 29: val_loss improved from 0.28991 to 0.28956, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 489ms/step - accuracy: 0.9244 - loss: 0.1937 - val_accuracy: 0.8803 - val_loss: 0.2896 - learning_rate: 1.0000e-04
# Epoch 30/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.9178 - loss: 0.2118
# Epoch 30: val_loss did not improve from 0.28956
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 472ms/step - accuracy: 0.9178 - loss: 0.2119 - val_accuracy: 0.8818 - val_loss: 0.2923 - learning_rate: 1.0000e-04
# Epoch 31/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.9094 - loss: 0.2175
# Epoch 31: val_loss did not improve from 0.28956
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 460ms/step - accuracy: 0.9094 - loss: 0.2173 - val_accuracy: 0.8803 - val_loss: 0.2943 - learning_rate: 1.0000e-04
# Epoch 32/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9109 - loss: 0.1969
# Epoch 32: val_loss improved from 0.28956 to 0.28666, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 475ms/step - accuracy: 0.9108 - loss: 0.1970 - val_accuracy: 0.8803 - val_loss: 0.2867 - learning_rate: 1.0000e-04
# Epoch 33/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.9156 - loss: 0.1953
# Epoch 33: val_loss did not improve from 0.28666
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 42s 485ms/step - accuracy: 0.9156 - loss: 0.1954 - val_accuracy: 0.8833 - val_loss: 0.2902 - learning_rate: 1.0000e-04
# Epoch 34/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.9298 - loss: 0.1727
# Epoch 34: val_loss did not improve from 0.28666
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 38s 453ms/step - accuracy: 0.9297 - loss: 0.1729 - val_accuracy: 0.8788 - val_loss: 0.2908 - learning_rate: 1.0000e-04
# Epoch 35/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.9156 - loss: 0.2002
# Epoch 35: val_loss improved from 0.28666 to 0.28620, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 469ms/step - accuracy: 0.9157 - loss: 0.2001 - val_accuracy: 0.8879 - val_loss: 0.2862 - learning_rate: 1.0000e-04
# Epoch 36/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.9124 - loss: 0.2114
# Epoch 36: val_loss improved from 0.28620 to 0.28373, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 43s 493ms/step - accuracy: 0.9125 - loss: 0.2113 - val_accuracy: 0.8909 - val_loss: 0.2837 - learning_rate: 1.0000e-04
# Epoch 37/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.9268 - loss: 0.1806
# Epoch 37: val_loss improved from 0.28373 to 0.28204, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 492ms/step - accuracy: 0.9267 - loss: 0.1807 - val_accuracy: 0.8848 - val_loss: 0.2820 - learning_rate: 1.0000e-04
# Epoch 38/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.9126 - loss: 0.1979
# Epoch 38: val_loss did not improve from 0.28204
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 477ms/step - accuracy: 0.9127 - loss: 0.1978 - val_accuracy: 0.8864 - val_loss: 0.2823 - learning_rate: 1.0000e-04
# Epoch 39/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.9276 - loss: 0.1754
# Epoch 39: val_loss did not improve from 0.28204
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 468ms/step - accuracy: 0.9276 - loss: 0.1753 - val_accuracy: 0.8879 - val_loss: 0.2886 - learning_rate: 1.0000e-04
# Epoch 40/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.9428 - loss: 0.1477
# Epoch 40: val_loss did not improve from 0.28204
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 467ms/step - accuracy: 0.9427 - loss: 0.1479 - val_accuracy: 0.8894 - val_loss: 0.2856 - learning_rate: 1.0000e-04
# Epoch 41/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step - accuracy: 0.9310 - loss: 0.1614
# Epoch 41: val_loss did not improve from 0.28204
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 38s 461ms/step - accuracy: 0.9310 - loss: 0.1614 - val_accuracy: 0.8924 - val_loss: 0.2852 - learning_rate: 3.0000e-05
# Epoch 42/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.9368 - loss: 0.1541
# Epoch 42: val_loss improved from 0.28204 to 0.27918, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 463ms/step - accuracy: 0.9367 - loss: 0.1543 - val_accuracy: 0.8909 - val_loss: 0.2792 - learning_rate: 3.0000e-05
# Epoch 43/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.9395 - loss: 0.1630
# Epoch 43: val_loss improved from 0.27918 to 0.27788, saving model to /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 42s 506ms/step - accuracy: 0.9394 - loss: 0.1631 - val_accuracy: 0.8894 - val_loss: 0.2779 - learning_rate: 3.0000e-05
# Epoch 44/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.9422 - loss: 0.1380
# Epoch 44: val_loss did not improve from 0.27788
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 78s 466ms/step - accuracy: 0.9421 - loss: 0.1382 - val_accuracy: 0.8909 - val_loss: 0.2809 - learning_rate: 3.0000e-05
# Epoch 45/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9339 - loss: 0.1697
# Epoch 45: val_loss did not improve from 0.27788
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 466ms/step - accuracy: 0.9339 - loss: 0.1697 - val_accuracy: 0.8848 - val_loss: 0.2781 - learning_rate: 3.0000e-05
# Epoch 46/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - accuracy: 0.9358 - loss: 0.1690
# Epoch 46: val_loss did not improve from 0.27788
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 465ms/step - accuracy: 0.9358 - loss: 0.1690 - val_accuracy: 0.8864 - val_loss: 0.2786 - learning_rate: 3.0000e-05
# Epoch 47/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.9334 - loss: 0.1641
# Epoch 47: val_loss did not improve from 0.27788
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 464ms/step - accuracy: 0.9334 - loss: 0.1640 - val_accuracy: 0.8879 - val_loss: 0.2781 - learning_rate: 9.0000e-06
# Epoch 48/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.9340 - loss: 0.1551
# Epoch 48: val_loss did not improve from 0.27788
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 38s 455ms/step - accuracy: 0.9341 - loss: 0.1551 - val_accuracy: 0.8894 - val_loss: 0.2795 - learning_rate: 9.0000e-06
# Epoch 49/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.9280 - loss: 0.1702
# Epoch 49: val_loss did not improve from 0.27788
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 468ms/step - accuracy: 0.9280 - loss: 0.1701 - val_accuracy: 0.8894 - val_loss: 0.2792 - learning_rate: 9.0000e-06
# Epoch 50/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.9349 - loss: 0.1618
# Epoch 50: val_loss did not improve from 0.27788
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 461ms/step - accuracy: 0.9349 - loss: 0.1618 - val_accuracy: 0.8909 - val_loss: 0.2795 - learning_rate: 2.7000e-06
# Epoch 51/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.9425 - loss: 0.1534
# Epoch 51: val_loss did not improve from 0.27788
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 461ms/step - accuracy: 0.9425 - loss: 0.1533 - val_accuracy: 0.8894 - val_loss: 0.2793 - learning_rate: 2.7000e-06
# ✅ Model loaded from: /content/drive/MyDrive/best_efficientnetb0_binary_adamax.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 404ms/step
#
# ✅ Overall Validation Accuracy: 88.94%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       benign       0.88      0.93      0.90       360
#    malignant       0.91      0.84      0.87       300
#
#     accuracy                           0.89       660
#    macro avg       0.89      0.89      0.89       660
# weighted avg       0.89      0.89      0.89       660
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3595732147.py in <cell line: 0>()
#     195
#     196 for i in range(n_classes):
# --> 197     if np.sum(y_true_bin[:, i]) == 0:
#     198         continue
#     199     fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
