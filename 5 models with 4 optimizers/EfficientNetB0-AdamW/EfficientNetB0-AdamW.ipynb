# %%
# -*- coding: utf-8 -*-
"""efficientnetB0_binary.ipynb"""

from google.colab import drive
drive.mount('/content/drive')

import zipfile, os

# === Dataset Extraction ===
zip_path = "/content/drive/MyDrive/d.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print("✅ Dataset extracted.")

# === Imports ===
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
import collections

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import AdamW

# === Dataset Paths ===
train_dir = "/content/dataset/d/train"
val_dir = "/content/dataset/d/val"

# === Data Generators ===
train_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)

# === Model Definition ===
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze first 100 layers
for layer in base_model.layers[:100]:
    layer.trainable = False
for layer in base_model.layers[100:]:
    layer.trainable = True

# Custom head
x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(2, activation='softmax')(x)   # ✅ 2 classes

model = Model(inputs=base_model.input, outputs=output)

# === Optimizer AdamW ===
optimizer = AdamW(
    learning_rate=1e-4,
    weight_decay=1e-5,
    epsilon=1e-07
)

model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.build((None, 224, 224, 3))

# === Callbacks ===
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_efficientnetb0_binary.keras",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    verbose=1,
    min_lr=1e-6
)

# === Training ===
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=51,
    callbacks=[checkpoint, lr_scheduler]
)

# === Save Accuracy & Loss Plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

# === Load Best Model for Evaluation ===
model_path = "/content/drive/MyDrive/best_efficientnetb0_binary.keras"
model = tf.keras.models.load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Predictions ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

print("\n✅ Overall Validation Accuracy: {:.2f}%".format(accuracy_score(y_true, y_pred) * 100))

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# Classification Report
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0
))

# === ROC Curve (binary) ===
n_classes = 2
labels = target_names
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

fpr, tpr, roc_auc = {}, {}, {}

for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(7, 6))
for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.savefig(f"{graph_dir}/roc_curve.png")
plt.show()

# === Save Final Model ===
model.save("/content/drive/MyDrive/final_efficientnetb0_binary.keras")
print("✅ Final model saved.")
# Out:
# Mounted at /content/drive
# ✅ Dataset extracted.
# Found 2637 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 833ms/step - accuracy: 0.6683 - loss: 0.7563
# Epoch 1: val_loss improved from inf to 0.48867, saving model to /content/drive/MyDrive/best_efficientnetb0_binary.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.6691 - loss: 0.7547 - val_accuracy: 0.7379 - val_loss: 0.4887 - learning_rate: 1.0000e-04
# Epoch 2/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.8181 - loss: 0.4463
# Epoch 2: val_loss improved from 0.48867 to 0.34579, saving model to /content/drive/MyDrive/best_efficientnetb0_binary.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 494ms/step - accuracy: 0.8181 - loss: 0.4462 - val_accuracy: 0.8303 - val_loss: 0.3458 - learning_rate: 1.0000e-04
# Epoch 3/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.8459 - loss: 0.3719
# Epoch 3: val_loss improved from 0.34579 to 0.29505, saving model to /content/drive/MyDrive/best_efficientnetb0_binary.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 81s 488ms/step - accuracy: 0.8460 - loss: 0.3718 - val_accuracy: 0.8606 - val_loss: 0.2951 - learning_rate: 1.0000e-04
# Epoch 4/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.8571 - loss: 0.3217
# Epoch 4: val_loss did not improve from 0.29505
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 481ms/step - accuracy: 0.8572 - loss: 0.3218 - val_accuracy: 0.8576 - val_loss: 0.2996 - learning_rate: 1.0000e-04
# Epoch 5/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.8632 - loss: 0.3270
# Epoch 5: val_loss did not improve from 0.29505
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 485ms/step - accuracy: 0.8633 - loss: 0.3268 - val_accuracy: 0.8727 - val_loss: 0.2968 - learning_rate: 1.0000e-04
# Epoch 6/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.8778 - loss: 0.2873
# Epoch 6: val_loss improved from 0.29505 to 0.29122, saving model to /content/drive/MyDrive/best_efficientnetb0_binary.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 482ms/step - accuracy: 0.8778 - loss: 0.2873 - val_accuracy: 0.8712 - val_loss: 0.2912 - learning_rate: 1.0000e-04
# Epoch 7/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.8944 - loss: 0.2543
# Epoch 7: val_loss improved from 0.29122 to 0.29121, saving model to /content/drive/MyDrive/best_efficientnetb0_binary.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 42s 503ms/step - accuracy: 0.8944 - loss: 0.2544 - val_accuracy: 0.8879 - val_loss: 0.2912 - learning_rate: 1.0000e-04
# Epoch 8/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.9079 - loss: 0.2158
# Epoch 8: val_loss did not improve from 0.29121
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 482ms/step - accuracy: 0.9078 - loss: 0.2160 - val_accuracy: 0.8803 - val_loss: 0.2920 - learning_rate: 1.0000e-04
# Epoch 9/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.8916 - loss: 0.2402
# Epoch 9: val_loss did not improve from 0.29121
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 471ms/step - accuracy: 0.8916 - loss: 0.2402 - val_accuracy: 0.8788 - val_loss: 0.2936 - learning_rate: 1.0000e-04
# Epoch 10/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.9015 - loss: 0.2332
# Epoch 10: val_loss improved from 0.29121 to 0.28252, saving model to /content/drive/MyDrive/best_efficientnetb0_binary.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 488ms/step - accuracy: 0.9015 - loss: 0.2331 - val_accuracy: 0.8833 - val_loss: 0.2825 - learning_rate: 3.0000e-05
# Epoch 11/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.9201 - loss: 0.1840
# Epoch 11: val_loss improved from 0.28252 to 0.27666, saving model to /content/drive/MyDrive/best_efficientnetb0_binary.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 496ms/step - accuracy: 0.9202 - loss: 0.1840 - val_accuracy: 0.8818 - val_loss: 0.2767 - learning_rate: 3.0000e-05
# Epoch 12/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.9108 - loss: 0.2162
# Epoch 12: val_loss did not improve from 0.27666
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 80s 473ms/step - accuracy: 0.9109 - loss: 0.2160 - val_accuracy: 0.8848 - val_loss: 0.2805 - learning_rate: 3.0000e-05
# Epoch 13/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.9199 - loss: 0.1885
# Epoch 13: val_loss improved from 0.27666 to 0.27060, saving model to /content/drive/MyDrive/best_efficientnetb0_binary.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 43s 516ms/step - accuracy: 0.9199 - loss: 0.1885 - val_accuracy: 0.8909 - val_loss: 0.2706 - learning_rate: 3.0000e-05
# Epoch 14/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.9201 - loss: 0.1762
# Epoch 14: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 498ms/step - accuracy: 0.9201 - loss: 0.1763 - val_accuracy: 0.8879 - val_loss: 0.2745 - learning_rate: 3.0000e-05
# Epoch 15/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.9134 - loss: 0.1839
# Epoch 15: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 80s 474ms/step - accuracy: 0.9134 - loss: 0.1838 - val_accuracy: 0.8879 - val_loss: 0.2719 - learning_rate: 3.0000e-05
# Epoch 16/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.9120 - loss: 0.2042
# Epoch 16: val_loss did not improve from 0.27060
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 471ms/step - accuracy: 0.9121 - loss: 0.2039 - val_accuracy: 0.8803 - val_loss: 0.2785 - learning_rate: 3.0000e-05
# Epoch 17/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.9194 - loss: 0.1821
# Epoch 17: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 473ms/step - accuracy: 0.9195 - loss: 0.1819 - val_accuracy: 0.8848 - val_loss: 0.2760 - learning_rate: 9.0000e-06
# Epoch 18/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9162 - loss: 0.1866
# Epoch 18: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 468ms/step - accuracy: 0.9163 - loss: 0.1864 - val_accuracy: 0.8864 - val_loss: 0.2724 - learning_rate: 9.0000e-06
# Epoch 19/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.9282 - loss: 0.1622
# Epoch 19: val_loss did not improve from 0.27060
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 472ms/step - accuracy: 0.9283 - loss: 0.1622 - val_accuracy: 0.8939 - val_loss: 0.2738 - learning_rate: 9.0000e-06
# Epoch 20/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.9280 - loss: 0.1743
# Epoch 20: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 471ms/step - accuracy: 0.9279 - loss: 0.1744 - val_accuracy: 0.8909 - val_loss: 0.2745 - learning_rate: 2.7000e-06
# Epoch 21/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.9292 - loss: 0.1720
# Epoch 21: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 472ms/step - accuracy: 0.9293 - loss: 0.1719 - val_accuracy: 0.8909 - val_loss: 0.2729 - learning_rate: 2.7000e-06
# Epoch 22/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9229 - loss: 0.1687
# Epoch 22: val_loss did not improve from 0.27060
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 470ms/step - accuracy: 0.9231 - loss: 0.1685 - val_accuracy: 0.8909 - val_loss: 0.2728 - learning_rate: 2.7000e-06
# Epoch 23/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.9321 - loss: 0.1570
# Epoch 23: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 479ms/step - accuracy: 0.9321 - loss: 0.1571 - val_accuracy: 0.8924 - val_loss: 0.2721 - learning_rate: 1.0000e-06
# Epoch 24/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.9230 - loss: 0.1715
# Epoch 24: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 468ms/step - accuracy: 0.9231 - loss: 0.1715 - val_accuracy: 0.8924 - val_loss: 0.2718 - learning_rate: 1.0000e-06
# Epoch 25/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.9270 - loss: 0.1578
# Epoch 25: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 471ms/step - accuracy: 0.9270 - loss: 0.1578 - val_accuracy: 0.8924 - val_loss: 0.2720 - learning_rate: 1.0000e-06
# Epoch 26/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.9186 - loss: 0.1890
# Epoch 26: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 472ms/step - accuracy: 0.9187 - loss: 0.1888 - val_accuracy: 0.8909 - val_loss: 0.2727 - learning_rate: 1.0000e-06
# Epoch 27/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - accuracy: 0.9315 - loss: 0.1662
# Epoch 27: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 469ms/step - accuracy: 0.9315 - loss: 0.1661 - val_accuracy: 0.8924 - val_loss: 0.2739 - learning_rate: 1.0000e-06
# Epoch 28/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step - accuracy: 0.9309 - loss: 0.1550
# Epoch 28: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 466ms/step - accuracy: 0.9309 - loss: 0.1549 - val_accuracy: 0.8924 - val_loss: 0.2722 - learning_rate: 1.0000e-06
# Epoch 29/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.9389 - loss: 0.1844
# Epoch 29: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 474ms/step - accuracy: 0.9389 - loss: 0.1842 - val_accuracy: 0.8939 - val_loss: 0.2720 - learning_rate: 1.0000e-06
# Epoch 30/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.9263 - loss: 0.1610
# Epoch 30: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 38s 459ms/step - accuracy: 0.9263 - loss: 0.1610 - val_accuracy: 0.8924 - val_loss: 0.2727 - learning_rate: 1.0000e-06
# Epoch 31/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.9262 - loss: 0.1570
# Epoch 31: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 42s 470ms/step - accuracy: 0.9264 - loss: 0.1569 - val_accuracy: 0.8909 - val_loss: 0.2720 - learning_rate: 1.0000e-06
# Epoch 32/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.9385 - loss: 0.1572
# Epoch 32: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 470ms/step - accuracy: 0.9385 - loss: 0.1572 - val_accuracy: 0.8939 - val_loss: 0.2717 - learning_rate: 1.0000e-06
# Epoch 33/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.9244 - loss: 0.1813
# Epoch 33: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 476ms/step - accuracy: 0.9244 - loss: 0.1812 - val_accuracy: 0.8909 - val_loss: 0.2719 - learning_rate: 1.0000e-06
# Epoch 34/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step - accuracy: 0.9216 - loss: 0.2006
# Epoch 34: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 467ms/step - accuracy: 0.9217 - loss: 0.2002 - val_accuracy: 0.8909 - val_loss: 0.2717 - learning_rate: 1.0000e-06
# Epoch 35/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.9356 - loss: 0.1609
# Epoch 35: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 38s 461ms/step - accuracy: 0.9357 - loss: 0.1609 - val_accuracy: 0.8924 - val_loss: 0.2720 - learning_rate: 1.0000e-06
# Epoch 36/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.9268 - loss: 0.1692
# Epoch 36: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 474ms/step - accuracy: 0.9268 - loss: 0.1692 - val_accuracy: 0.8909 - val_loss: 0.2715 - learning_rate: 1.0000e-06
# Epoch 37/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.9358 - loss: 0.1502
# Epoch 37: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 462ms/step - accuracy: 0.9357 - loss: 0.1505 - val_accuracy: 0.8909 - val_loss: 0.2712 - learning_rate: 1.0000e-06
# Epoch 38/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.9313 - loss: 0.1725
# Epoch 38: val_loss did not improve from 0.27060
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 475ms/step - accuracy: 0.9313 - loss: 0.1724 - val_accuracy: 0.8909 - val_loss: 0.2707 - learning_rate: 1.0000e-06
# Epoch 39/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.9230 - loss: 0.1733
# Epoch 39: val_loss improved from 0.27060 to 0.27053, saving model to /content/drive/MyDrive/best_efficientnetb0_binary.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 479ms/step - accuracy: 0.9230 - loss: 0.1733 - val_accuracy: 0.8909 - val_loss: 0.2705 - learning_rate: 1.0000e-06
# Epoch 40/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.9217 - loss: 0.1613
# Epoch 40: val_loss did not improve from 0.27053
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 42s 490ms/step - accuracy: 0.9218 - loss: 0.1613 - val_accuracy: 0.8924 - val_loss: 0.2716 - learning_rate: 1.0000e-06
# Epoch 41/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9283 - loss: 0.1820
# Epoch 41: val_loss did not improve from 0.27053
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 481ms/step - accuracy: 0.9283 - loss: 0.1820 - val_accuracy: 0.8939 - val_loss: 0.2708 - learning_rate: 1.0000e-06
# Epoch 42/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.9346 - loss: 0.1522
# Epoch 42: val_loss did not improve from 0.27053
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 485ms/step - accuracy: 0.9346 - loss: 0.1522 - val_accuracy: 0.8909 - val_loss: 0.2714 - learning_rate: 1.0000e-06
# Epoch 43/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.9290 - loss: 0.1676
# Epoch 43: val_loss did not improve from 0.27053
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 473ms/step - accuracy: 0.9290 - loss: 0.1676 - val_accuracy: 0.8909 - val_loss: 0.2711 - learning_rate: 1.0000e-06
# Epoch 44/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.9340 - loss: 0.1534
# Epoch 44: val_loss did not improve from 0.27053
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 473ms/step - accuracy: 0.9340 - loss: 0.1535 - val_accuracy: 0.8909 - val_loss: 0.2717 - learning_rate: 1.0000e-06
# Epoch 45/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - accuracy: 0.9292 - loss: 0.1780
# Epoch 45: val_loss did not improve from 0.27053
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 480ms/step - accuracy: 0.9292 - loss: 0.1778 - val_accuracy: 0.8909 - val_loss: 0.2716 - learning_rate: 1.0000e-06
# Epoch 46/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.9261 - loss: 0.1746
# Epoch 46: val_loss did not improve from 0.27053
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 477ms/step - accuracy: 0.9261 - loss: 0.1744 - val_accuracy: 0.8939 - val_loss: 0.2711 - learning_rate: 1.0000e-06
# Epoch 47/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9394 - loss: 0.1521
# Epoch 47: val_loss did not improve from 0.27053
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 481ms/step - accuracy: 0.9394 - loss: 0.1520 - val_accuracy: 0.8939 - val_loss: 0.2727 - learning_rate: 1.0000e-06
# Epoch 48/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.9311 - loss: 0.1486
# Epoch 48: val_loss did not improve from 0.27053
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 469ms/step - accuracy: 0.9312 - loss: 0.1486 - val_accuracy: 0.8909 - val_loss: 0.2730 - learning_rate: 1.0000e-06
# Epoch 49/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.9293 - loss: 0.1703
# Epoch 49: val_loss did not improve from 0.27053
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 464ms/step - accuracy: 0.9294 - loss: 0.1702 - val_accuracy: 0.8939 - val_loss: 0.2721 - learning_rate: 1.0000e-06
# Epoch 50/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.9360 - loss: 0.1624
# Epoch 50: val_loss did not improve from 0.27053
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 38s 460ms/step - accuracy: 0.9360 - loss: 0.1624 - val_accuracy: 0.8939 - val_loss: 0.2732 - learning_rate: 1.0000e-06
# Epoch 51/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9317 - loss: 0.1652
# Epoch 51: val_loss did not improve from 0.27053
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 468ms/step - accuracy: 0.9317 - loss: 0.1653 - val_accuracy: 0.8939 - val_loss: 0.2720 - learning_rate: 1.0000e-06
# ✅ Model loaded from: /content/drive/MyDrive/best_efficientnetb0_binary.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 406ms/step
#
# ✅ Overall Validation Accuracy: 89.09%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       benign       0.88      0.92      0.90       360
#    malignant       0.90      0.85      0.88       300
#
#     accuracy                           0.89       660
#    macro avg       0.89      0.89      0.89       660
# weighted avg       0.89      0.89      0.89       660
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2379032707.py in <cell line: 0>()
#     196
#     197 for i in range(n_classes):
# --> 198     if np.sum(y_true_bin[:, i]) == 0:
#     199         continue
#     200     fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
