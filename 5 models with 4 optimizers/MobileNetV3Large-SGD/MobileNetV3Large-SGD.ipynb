# %%
# -*- coding: utf-8 -*-
"""MobileNetV3.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1YX65u1w9glAk0nmVr8F2nocjXAFn6axO
"""

from google.colab import drive
drive.mount('/content/drive')

import zipfile, os

zip_path = "/content/drive/MyDrive/d.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras.applications.mobilenet_v3 import preprocess_input

train_dir = "/content/dataset/d/train"
val_dir = "/content/dataset/d/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)

from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

base_model = MobileNetV3Large(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

# Freeze initial layers (adjust index based on MobileNetV3 architecture depth)
for layer in base_model.layers[:150]:  # MobileNetV3Large has ~270 layers
    layer.trainable = False

# Unfreeze later layers for fine-tuning
for layer in base_model.layers[150:]:
    layer.trainable = True

x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(2, activation='softmax')(x)  # Number of classes set to 2

model = Model(inputs=base_model.input, outputs=output)

# ----------------------------
# Optimizer: SGD with Momentum (optionally Nesterov)
# ----------------------------
# You can adjust learning_rate, momentum and nesterov flag as required.
from tensorflow.keras.optimizers import SGD

# Configuration (tune if needed)
learning_rate = 1e-3    # typical starting LR for SGD; adjust to 1e-2 or lower as required
momentum = 0.9
use_nesterov = True     # set to False if you prefer plain momentum

optimizer = SGD(learning_rate=learning_rate, momentum=momentum, nesterov=use_nesterov)

# Compile model (loss remains sparse categorical since we use softmax with 2 outputs)
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Optional: build the model (only needed if model has not been fit before)
model.build((None, 224, 224, 3))

# Callbacks — updated checkpoint filename
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_mobilenetv3large_model.keras",  # Updated filename
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# Fit the model for 51 epochs (no EarlyStopping)
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=51,
    callbacks=[checkpoint, lr_scheduler]
)

import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained MobileNetV3Large model ===
model_path = "/content/drive/MyDrive/best_mobilenetv3large_model.keras"  # Updated path
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))

import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
# y_true: true labels (e.g., [0, 1, 1, 0, ...]), shape = (n_samples,)
# pred_probs: predicted probabilities, shape = (n_samples, n_classes)
# labels: class names (optional, replace with your own)
# graph_dir: directory where to save plot

n_classes = 2
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = "./plots"

# Ensure output directory exists
os.makedirs(graph_dir, exist_ok=True)

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")

model.save("/content/drive/MyDrive/final_resnet152_model.keras")
# Out:
# Mounted at /content/drive
#  Dataset extracted.
# Found 2637 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 609ms/step - accuracy: 0.6143 - loss: 0.8120
# Epoch 1: val_loss improved from inf to 0.66617, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 101s 920ms/step - accuracy: 0.6153 - loss: 0.8104 - val_accuracy: 0.6636 - val_loss: 0.6662 - learning_rate: 0.0010
# Epoch 2/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.7742 - loss: 0.4992
# Epoch 2: val_loss improved from 0.66617 to 0.65211, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 573ms/step - accuracy: 0.7745 - loss: 0.4986 - val_accuracy: 0.6909 - val_loss: 0.6521 - learning_rate: 0.0010
# Epoch 3/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.8177 - loss: 0.4266
# Epoch 3: val_loss improved from 0.65211 to 0.63350, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 557ms/step - accuracy: 0.8178 - loss: 0.4263 - val_accuracy: 0.7106 - val_loss: 0.6335 - learning_rate: 0.0010
# Epoch 4/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.8467 - loss: 0.3594
# Epoch 4: val_loss did not improve from 0.63350
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 554ms/step - accuracy: 0.8465 - loss: 0.3597 - val_accuracy: 0.6818 - val_loss: 0.7214 - learning_rate: 0.0010
# Epoch 5/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.8421 - loss: 0.3702
# Epoch 5: val_loss did not improve from 0.63350
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 45s 543ms/step - accuracy: 0.8422 - loss: 0.3699 - val_accuracy: 0.6985 - val_loss: 0.6807 - learning_rate: 0.0010
# Epoch 6/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.8545 - loss: 0.3278
# Epoch 6: val_loss did not improve from 0.63350
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 550ms/step - accuracy: 0.8545 - loss: 0.3278 - val_accuracy: 0.7045 - val_loss: 0.6812 - learning_rate: 3.0000e-04
# Epoch 7/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.8480 - loss: 0.3184
# Epoch 7: val_loss improved from 0.63350 to 0.62422, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 558ms/step - accuracy: 0.8480 - loss: 0.3186 - val_accuracy: 0.7212 - val_loss: 0.6242 - learning_rate: 3.0000e-04
# Epoch 8/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.8677 - loss: 0.3192
# Epoch 8: val_loss improved from 0.62422 to 0.58623, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 552ms/step - accuracy: 0.8678 - loss: 0.3191 - val_accuracy: 0.7379 - val_loss: 0.5862 - learning_rate: 3.0000e-04
# Epoch 9/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.8569 - loss: 0.3281
# Epoch 9: val_loss improved from 0.58623 to 0.54308, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 579ms/step - accuracy: 0.8570 - loss: 0.3278 - val_accuracy: 0.7561 - val_loss: 0.5431 - learning_rate: 3.0000e-04
# Epoch 10/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.8560 - loss: 0.3294
# Epoch 10: val_loss improved from 0.54308 to 0.52685, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 572ms/step - accuracy: 0.8561 - loss: 0.3292 - val_accuracy: 0.7485 - val_loss: 0.5269 - learning_rate: 3.0000e-04
# Epoch 11/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.8852 - loss: 0.2941
# Epoch 11: val_loss improved from 0.52685 to 0.48707, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 578ms/step - accuracy: 0.8852 - loss: 0.2941 - val_accuracy: 0.7758 - val_loss: 0.4871 - learning_rate: 3.0000e-04
# Epoch 12/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.8646 - loss: 0.3115
# Epoch 12: val_loss improved from 0.48707 to 0.43006, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 591ms/step - accuracy: 0.8646 - loss: 0.3113 - val_accuracy: 0.7939 - val_loss: 0.4301 - learning_rate: 3.0000e-04
# Epoch 13/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.8658 - loss: 0.3204
# Epoch 13: val_loss did not improve from 0.43006
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 553ms/step - accuracy: 0.8658 - loss: 0.3203 - val_accuracy: 0.7727 - val_loss: 0.4538 - learning_rate: 3.0000e-04
# Epoch 14/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.8689 - loss: 0.3083
# Epoch 14: val_loss improved from 0.43006 to 0.41369, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 577ms/step - accuracy: 0.8689 - loss: 0.3081 - val_accuracy: 0.8045 - val_loss: 0.4137 - learning_rate: 3.0000e-04
# Epoch 15/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.8811 - loss: 0.2742
# Epoch 15: val_loss improved from 0.41369 to 0.39154, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 593ms/step - accuracy: 0.8811 - loss: 0.2743 - val_accuracy: 0.8167 - val_loss: 0.3915 - learning_rate: 3.0000e-04
# Epoch 16/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.8805 - loss: 0.2644
# Epoch 16: val_loss improved from 0.39154 to 0.38429, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 591ms/step - accuracy: 0.8804 - loss: 0.2645 - val_accuracy: 0.8197 - val_loss: 0.3843 - learning_rate: 3.0000e-04
# Epoch 17/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.8713 - loss: 0.2774
# Epoch 17: val_loss improved from 0.38429 to 0.36049, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 571ms/step - accuracy: 0.8713 - loss: 0.2774 - val_accuracy: 0.8288 - val_loss: 0.3605 - learning_rate: 3.0000e-04
# Epoch 18/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step - accuracy: 0.8776 - loss: 0.2776
# Epoch 18: val_loss did not improve from 0.36049
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 564ms/step - accuracy: 0.8775 - loss: 0.2778 - val_accuracy: 0.8318 - val_loss: 0.3807 - learning_rate: 3.0000e-04
# Epoch 19/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.8913 - loss: 0.2541
# Epoch 19: val_loss improved from 0.36049 to 0.35494, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 583ms/step - accuracy: 0.8912 - loss: 0.2543 - val_accuracy: 0.8379 - val_loss: 0.3549 - learning_rate: 3.0000e-04
# Epoch 20/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.9014 - loss: 0.2470
# Epoch 20: val_loss improved from 0.35494 to 0.33367, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 560ms/step - accuracy: 0.9013 - loss: 0.2472 - val_accuracy: 0.8409 - val_loss: 0.3337 - learning_rate: 3.0000e-04
# Epoch 21/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.8743 - loss: 0.2842
# Epoch 21: val_loss did not improve from 0.33367
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 568ms/step - accuracy: 0.8743 - loss: 0.2841 - val_accuracy: 0.8409 - val_loss: 0.3367 - learning_rate: 3.0000e-04
# Epoch 22/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.8926 - loss: 0.2739
# Epoch 22: val_loss improved from 0.33367 to 0.30712, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 560ms/step - accuracy: 0.8925 - loss: 0.2740 - val_accuracy: 0.8727 - val_loss: 0.3071 - learning_rate: 3.0000e-04
# Epoch 23/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.8844 - loss: 0.2524
# Epoch 23: val_loss did not improve from 0.30712
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 574ms/step - accuracy: 0.8844 - loss: 0.2526 - val_accuracy: 0.8561 - val_loss: 0.3126 - learning_rate: 3.0000e-04
# Epoch 24/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.8888 - loss: 0.2557
# Epoch 24: val_loss did not improve from 0.30712
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 45s 544ms/step - accuracy: 0.8888 - loss: 0.2557 - val_accuracy: 0.8545 - val_loss: 0.3110 - learning_rate: 3.0000e-04
# Epoch 25/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.8812 - loss: 0.2722
# Epoch 25: val_loss improved from 0.30712 to 0.30682, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 570ms/step - accuracy: 0.8813 - loss: 0.2722 - val_accuracy: 0.8652 - val_loss: 0.3068 - learning_rate: 9.0000e-05
# Epoch 26/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.8779 - loss: 0.2683
# Epoch 26: val_loss improved from 0.30682 to 0.28977, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 561ms/step - accuracy: 0.8780 - loss: 0.2682 - val_accuracy: 0.8682 - val_loss: 0.2898 - learning_rate: 9.0000e-05
# Epoch 27/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.9025 - loss: 0.2178
# Epoch 27: val_loss improved from 0.28977 to 0.28942, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 574ms/step - accuracy: 0.9024 - loss: 0.2181 - val_accuracy: 0.8697 - val_loss: 0.2894 - learning_rate: 9.0000e-05
# Epoch 28/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.8899 - loss: 0.2552
# Epoch 28: val_loss did not improve from 0.28942
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 45s 548ms/step - accuracy: 0.8898 - loss: 0.2552 - val_accuracy: 0.8530 - val_loss: 0.3130 - learning_rate: 9.0000e-05
# Epoch 29/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.8868 - loss: 0.2617
# Epoch 29: val_loss did not improve from 0.28942
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 563ms/step - accuracy: 0.8868 - loss: 0.2618 - val_accuracy: 0.8667 - val_loss: 0.2924 - learning_rate: 9.0000e-05
# Epoch 30/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.8896 - loss: 0.2382
# Epoch 30: val_loss improved from 0.28942 to 0.28285, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 45s 545ms/step - accuracy: 0.8896 - loss: 0.2383 - val_accuracy: 0.8894 - val_loss: 0.2828 - learning_rate: 2.7000e-05
# Epoch 31/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.8968 - loss: 0.2302
# Epoch 31: val_loss did not improve from 0.28285
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 568ms/step - accuracy: 0.8968 - loss: 0.2303 - val_accuracy: 0.8561 - val_loss: 0.3075 - learning_rate: 2.7000e-05
# Epoch 32/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.9023 - loss: 0.2438
# Epoch 32: val_loss did not improve from 0.28285
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 44s 534ms/step - accuracy: 0.9022 - loss: 0.2440 - val_accuracy: 0.8727 - val_loss: 0.2851 - learning_rate: 2.7000e-05
# Epoch 33/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.8957 - loss: 0.2496
# Epoch 33: val_loss improved from 0.28285 to 0.28116, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 45s 545ms/step - accuracy: 0.8955 - loss: 0.2498 - val_accuracy: 0.8712 - val_loss: 0.2812 - learning_rate: 8.1000e-06
# Epoch 34/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.8910 - loss: 0.2578
# Epoch 34: val_loss improved from 0.28116 to 0.26980, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 565ms/step - accuracy: 0.8910 - loss: 0.2577 - val_accuracy: 0.8758 - val_loss: 0.2698 - learning_rate: 8.1000e-06
# Epoch 35/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.8890 - loss: 0.2654
# Epoch 35: val_loss improved from 0.26980 to 0.26025, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 588ms/step - accuracy: 0.8890 - loss: 0.2653 - val_accuracy: 0.8742 - val_loss: 0.2603 - learning_rate: 8.1000e-06
# Epoch 36/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.8963 - loss: 0.2482
# Epoch 36: val_loss did not improve from 0.26025
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 553ms/step - accuracy: 0.8963 - loss: 0.2482 - val_accuracy: 0.8758 - val_loss: 0.2652 - learning_rate: 8.1000e-06
# Epoch 37/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.8851 - loss: 0.2681
# Epoch 37: val_loss did not improve from 0.26025
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 569ms/step - accuracy: 0.8851 - loss: 0.2681 - val_accuracy: 0.8894 - val_loss: 0.2635 - learning_rate: 8.1000e-06
# Epoch 38/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.8874 - loss: 0.2527
# Epoch 38: val_loss did not improve from 0.26025
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 551ms/step - accuracy: 0.8874 - loss: 0.2526 - val_accuracy: 0.8727 - val_loss: 0.2739 - learning_rate: 2.4300e-06
# Epoch 39/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.8761 - loss: 0.2866
# Epoch 39: val_loss did not improve from 0.26025
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 61s 733ms/step - accuracy: 0.8761 - loss: 0.2865 - val_accuracy: 0.8712 - val_loss: 0.2831 - learning_rate: 2.4300e-06
# Epoch 40/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.8770 - loss: 0.2853
# Epoch 40: val_loss improved from 0.26025 to 0.25669, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 566ms/step - accuracy: 0.8770 - loss: 0.2851 - val_accuracy: 0.8818 - val_loss: 0.2567 - learning_rate: 1.0000e-06
# Epoch 41/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.8886 - loss: 0.2438
# Epoch 41: val_loss did not improve from 0.25669
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 585ms/step - accuracy: 0.8886 - loss: 0.2438 - val_accuracy: 0.8833 - val_loss: 0.2669 - learning_rate: 1.0000e-06
# Epoch 42/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.8888 - loss: 0.2518
# Epoch 42: val_loss did not improve from 0.25669
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 565ms/step - accuracy: 0.8888 - loss: 0.2518 - val_accuracy: 0.8879 - val_loss: 0.2608 - learning_rate: 1.0000e-06
# Epoch 43/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.8721 - loss: 0.2762
# Epoch 43: val_loss did not improve from 0.25669
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 586ms/step - accuracy: 0.8722 - loss: 0.2762 - val_accuracy: 0.8727 - val_loss: 0.2665 - learning_rate: 1.0000e-06
# Epoch 44/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.8896 - loss: 0.2560
# Epoch 44: val_loss did not improve from 0.25669
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 581ms/step - accuracy: 0.8896 - loss: 0.2559 - val_accuracy: 0.8712 - val_loss: 0.2775 - learning_rate: 1.0000e-06
# Epoch 45/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.8815 - loss: 0.2666
# Epoch 45: val_loss did not improve from 0.25669
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 576ms/step - accuracy: 0.8815 - loss: 0.2665 - val_accuracy: 0.8818 - val_loss: 0.2750 - learning_rate: 1.0000e-06
# Epoch 46/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.8952 - loss: 0.2490
# Epoch 46: val_loss did not improve from 0.25669
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 566ms/step - accuracy: 0.8952 - loss: 0.2491 - val_accuracy: 0.8727 - val_loss: 0.2852 - learning_rate: 1.0000e-06
# Epoch 47/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.8942 - loss: 0.2410
# Epoch 47: val_loss did not improve from 0.25669
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 578ms/step - accuracy: 0.8942 - loss: 0.2410 - val_accuracy: 0.8697 - val_loss: 0.2861 - learning_rate: 1.0000e-06
# Epoch 48/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.8781 - loss: 0.2567
# Epoch 48: val_loss did not improve from 0.25669
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 559ms/step - accuracy: 0.8781 - loss: 0.2567 - val_accuracy: 0.8758 - val_loss: 0.2793 - learning_rate: 1.0000e-06
# Epoch 49/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.8992 - loss: 0.2389
# Epoch 49: val_loss did not improve from 0.25669
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 574ms/step - accuracy: 0.8991 - loss: 0.2391 - val_accuracy: 0.8758 - val_loss: 0.2697 - learning_rate: 1.0000e-06
# Epoch 50/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.8885 - loss: 0.2774
# Epoch 50: val_loss did not improve from 0.25669
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 586ms/step - accuracy: 0.8885 - loss: 0.2772 - val_accuracy: 0.8788 - val_loss: 0.2644 - learning_rate: 1.0000e-06
# Epoch 51/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.8832 - loss: 0.2550
# Epoch 51: val_loss did not improve from 0.25669
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 553ms/step - accuracy: 0.8833 - loss: 0.2549 - val_accuracy: 0.8621 - val_loss: 0.2926 - learning_rate: 1.0000e-06
# ✅ Model loaded from: /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 656ms/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1]
# Valid labels: [0, 1]
# Target names: ['benign', 'malignant']
#
# Predicted sample count per class:
# benign: 370
# malignant: 290
#
# ✅ Overall Validation Accuracy: 88.48%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       benign       0.88      0.91      0.90       360
#    malignant       0.89      0.86      0.87       300
#
#     accuracy                           0.88       660
#    macro avg       0.88      0.88      0.88       660
# weighted avg       0.88      0.88      0.88       660
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2817551065.py in <cell line: 0>()
#     277 # Compute ROC for each class
#     278 for i in range(n_classes):
# --> 279     if np.sum(y_true_bin[:, i]) == 0:
#     280         print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
#     281         missing_classes.append(labels[i])
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
