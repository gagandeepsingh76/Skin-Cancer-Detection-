# %%
# -*- coding: utf-8 -*-
"""MobileNetV3.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1YX65u1w9glAk0nmVr8F2nocjXAFn6axO
"""

from google.colab import drive
drive.mount('/content/drive')

import zipfile, os

zip_path = "/content/drive/MyDrive/d.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras.applications.mobilenet_v3 import preprocess_input

train_dir = "/content/dataset/d/train"
val_dir = "/content/dataset/d/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)

from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

base_model = MobileNetV3Large(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

# Freeze initial layers (adjust index based on MobileNetV3 architecture depth)
for layer in base_model.layers[:150]:  # MobileNetV3Large has ~270 layers
    layer.trainable = False

# Unfreeze later layers for fine-tuning
for layer in base_model.layers[150:]:
    layer.trainable = True

x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(2, activation='softmax')(x)  # Number of classes set to 2

model = Model(inputs=base_model.input, outputs=output)

# ----------------------------
# Optimizer: AdamW (Adam with Weight Decay)
# ----------------------------
from tensorflow.keras.optimizers import AdamW
optimizer = AdamW(learning_rate=1e-4, weight_decay=1e-5)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Optional: build the model (only needed if model has not been fit before)
model.build((None, 224, 224, 3))

# Callbacks — updated checkpoint filename
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_mobilenetv3large_model.keras",  # Updated filename
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# Fit the model for 51 epochs (no EarlyStopping)
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=51,
    callbacks=[checkpoint, lr_scheduler]
)

import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained MobileNetV3Large model ===
model_path = "/content/drive/MyDrive/best_mobilenetv3large_model.keras"  # Updated path
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))

import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
# y_true: true labels (e.g., [0, 1, 1, 0, ...]), shape = (n_samples,)
# pred_probs: predicted probabilities, shape = (n_samples, n_classes)
# labels: class names (optional, replace with your own)
# graph_dir: directory where to save plot

n_classes = 2
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = "./plots"

# Ensure output directory exists
os.makedirs(graph_dir, exist_ok=True)

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")

model.save("/content/drive/MyDrive/final_resnet152_model.keras")
# Out:
# Mounted at /content/drive
#  Dataset extracted.
# Found 2637 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 678ms/step - accuracy: 0.6454 - loss: 0.7731
# Epoch 1: val_loss improved from inf to 0.83663, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 118s 1s/step - accuracy: 0.6462 - loss: 0.7717 - val_accuracy: 0.6212 - val_loss: 0.8366 - learning_rate: 1.0000e-04
# Epoch 2/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.7862 - loss: 0.4788
# Epoch 2: val_loss did not improve from 0.83663
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 602ms/step - accuracy: 0.7863 - loss: 0.4786 - val_accuracy: 0.6424 - val_loss: 0.8502 - learning_rate: 1.0000e-04
# Epoch 3/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - accuracy: 0.8051 - loss: 0.4545
# Epoch 3: val_loss did not improve from 0.83663
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 603ms/step - accuracy: 0.8054 - loss: 0.4541 - val_accuracy: 0.6167 - val_loss: 1.0022 - learning_rate: 1.0000e-04
# Epoch 4/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.8443 - loss: 0.3825
# Epoch 4: val_loss did not improve from 0.83663
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 569ms/step - accuracy: 0.8443 - loss: 0.3824 - val_accuracy: 0.6394 - val_loss: 0.9656 - learning_rate: 3.0000e-05
# Epoch 5/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.8587 - loss: 0.3336
# Epoch 5: val_loss did not improve from 0.83663
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 585ms/step - accuracy: 0.8586 - loss: 0.3337 - val_accuracy: 0.6500 - val_loss: 0.9109 - learning_rate: 3.0000e-05
# Epoch 6/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.8543 - loss: 0.3654
# Epoch 6: val_loss did not improve from 0.83663
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 557ms/step - accuracy: 0.8542 - loss: 0.3655 - val_accuracy: 0.6576 - val_loss: 0.8552 - learning_rate: 9.0000e-06
# Epoch 7/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.8564 - loss: 0.3464
# Epoch 7: val_loss improved from 0.83663 to 0.77390, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 595ms/step - accuracy: 0.8565 - loss: 0.3462 - val_accuracy: 0.6879 - val_loss: 0.7739 - learning_rate: 9.0000e-06
# Epoch 8/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.8702 - loss: 0.3202
# Epoch 8: val_loss improved from 0.77390 to 0.72010, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 601ms/step - accuracy: 0.8702 - loss: 0.3202 - val_accuracy: 0.7076 - val_loss: 0.7201 - learning_rate: 9.0000e-06
# Epoch 9/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.8540 - loss: 0.3584
# Epoch 9: val_loss improved from 0.72010 to 0.68050, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 597ms/step - accuracy: 0.8539 - loss: 0.3582 - val_accuracy: 0.7076 - val_loss: 0.6805 - learning_rate: 9.0000e-06
# Epoch 10/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.8632 - loss: 0.3338
# Epoch 10: val_loss improved from 0.68050 to 0.59730, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 607ms/step - accuracy: 0.8632 - loss: 0.3337 - val_accuracy: 0.7424 - val_loss: 0.5973 - learning_rate: 9.0000e-06
# Epoch 11/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.8570 - loss: 0.3431
# Epoch 11: val_loss improved from 0.59730 to 0.56778, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 582ms/step - accuracy: 0.8569 - loss: 0.3432 - val_accuracy: 0.7470 - val_loss: 0.5678 - learning_rate: 9.0000e-06
# Epoch 12/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.8578 - loss: 0.3125
# Epoch 12: val_loss improved from 0.56778 to 0.53456, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 599ms/step - accuracy: 0.8578 - loss: 0.3126 - val_accuracy: 0.7697 - val_loss: 0.5346 - learning_rate: 9.0000e-06
# Epoch 13/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.8619 - loss: 0.2993
# Epoch 13: val_loss improved from 0.53456 to 0.52088, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 602ms/step - accuracy: 0.8618 - loss: 0.2996 - val_accuracy: 0.7758 - val_loss: 0.5209 - learning_rate: 9.0000e-06
# Epoch 14/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.8602 - loss: 0.3181
# Epoch 14: val_loss improved from 0.52088 to 0.46496, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 81s 593ms/step - accuracy: 0.8601 - loss: 0.3182 - val_accuracy: 0.7742 - val_loss: 0.4650 - learning_rate: 9.0000e-06
# Epoch 15/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.8738 - loss: 0.3007
# Epoch 15: val_loss did not improve from 0.46496
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 593ms/step - accuracy: 0.8737 - loss: 0.3008 - val_accuracy: 0.7712 - val_loss: 0.4765 - learning_rate: 9.0000e-06
# Epoch 16/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.8734 - loss: 0.2937
# Epoch 16: val_loss improved from 0.46496 to 0.44132, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 569ms/step - accuracy: 0.8733 - loss: 0.2939 - val_accuracy: 0.7955 - val_loss: 0.4413 - learning_rate: 9.0000e-06
# Epoch 17/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.8692 - loss: 0.3095
# Epoch 17: val_loss improved from 0.44132 to 0.42600, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 587ms/step - accuracy: 0.8692 - loss: 0.3094 - val_accuracy: 0.8045 - val_loss: 0.4260 - learning_rate: 9.0000e-06
# Epoch 18/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - accuracy: 0.8827 - loss: 0.2880
# Epoch 18: val_loss improved from 0.42600 to 0.38850, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 573ms/step - accuracy: 0.8826 - loss: 0.2881 - val_accuracy: 0.8076 - val_loss: 0.3885 - learning_rate: 9.0000e-06
# Epoch 19/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.8700 - loss: 0.2947
# Epoch 19: val_loss improved from 0.38850 to 0.38758, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 600ms/step - accuracy: 0.8700 - loss: 0.2948 - val_accuracy: 0.8348 - val_loss: 0.3876 - learning_rate: 9.0000e-06
# Epoch 20/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.8760 - loss: 0.2920
# Epoch 20: val_loss improved from 0.38758 to 0.37624, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 80s 578ms/step - accuracy: 0.8759 - loss: 0.2922 - val_accuracy: 0.8288 - val_loss: 0.3762 - learning_rate: 9.0000e-06
# Epoch 21/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - accuracy: 0.8626 - loss: 0.3061
# Epoch 21: val_loss improved from 0.37624 to 0.33586, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 601ms/step - accuracy: 0.8626 - loss: 0.3060 - val_accuracy: 0.8530 - val_loss: 0.3359 - learning_rate: 9.0000e-06
# Epoch 22/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.8742 - loss: 0.2978
# Epoch 22: val_loss improved from 0.33586 to 0.33445, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 593ms/step - accuracy: 0.8743 - loss: 0.2978 - val_accuracy: 0.8409 - val_loss: 0.3345 - learning_rate: 9.0000e-06
# Epoch 23/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.8653 - loss: 0.3112
# Epoch 23: val_loss improved from 0.33445 to 0.32342, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 84s 615ms/step - accuracy: 0.8654 - loss: 0.3111 - val_accuracy: 0.8561 - val_loss: 0.3234 - learning_rate: 9.0000e-06
# Epoch 24/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.8780 - loss: 0.2959
# Epoch 24: val_loss did not improve from 0.32342
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 51s 614ms/step - accuracy: 0.8780 - loss: 0.2958 - val_accuracy: 0.8606 - val_loss: 0.3263 - learning_rate: 9.0000e-06
# Epoch 25/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.8767 - loss: 0.2782
# Epoch 25: val_loss did not improve from 0.32342
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 610ms/step - accuracy: 0.8767 - loss: 0.2783 - val_accuracy: 0.8545 - val_loss: 0.3258 - learning_rate: 9.0000e-06
# Epoch 26/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.8912 - loss: 0.2668
# Epoch 26: val_loss improved from 0.32342 to 0.30195, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 51s 616ms/step - accuracy: 0.8911 - loss: 0.2672 - val_accuracy: 0.8606 - val_loss: 0.3019 - learning_rate: 2.7000e-06
# Epoch 27/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.8741 - loss: 0.2864
# Epoch 27: val_loss improved from 0.30195 to 0.29650, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 51s 615ms/step - accuracy: 0.8742 - loss: 0.2864 - val_accuracy: 0.8636 - val_loss: 0.2965 - learning_rate: 2.7000e-06
# Epoch 28/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.8791 - loss: 0.2930
# Epoch 28: val_loss did not improve from 0.29650
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 51s 610ms/step - accuracy: 0.8791 - loss: 0.2930 - val_accuracy: 0.8439 - val_loss: 0.3162 - learning_rate: 2.7000e-06
# Epoch 29/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.8879 - loss: 0.2743
# Epoch 29: val_loss improved from 0.29650 to 0.28785, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 51s 613ms/step - accuracy: 0.8878 - loss: 0.2744 - val_accuracy: 0.8788 - val_loss: 0.2879 - learning_rate: 2.7000e-06
# Epoch 30/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.8676 - loss: 0.3165
# Epoch 30: val_loss improved from 0.28785 to 0.27407, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 81s 603ms/step - accuracy: 0.8678 - loss: 0.3162 - val_accuracy: 0.8864 - val_loss: 0.2741 - learning_rate: 2.7000e-06
# Epoch 31/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.8800 - loss: 0.2992
# Epoch 31: val_loss did not improve from 0.27407
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 598ms/step - accuracy: 0.8799 - loss: 0.2991 - val_accuracy: 0.8697 - val_loss: 0.2757 - learning_rate: 2.7000e-06
# Epoch 32/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.8716 - loss: 0.2866
# Epoch 32: val_loss did not improve from 0.27407
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 571ms/step - accuracy: 0.8717 - loss: 0.2865 - val_accuracy: 0.8682 - val_loss: 0.2870 - learning_rate: 2.7000e-06
# Epoch 33/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.8796 - loss: 0.2914
# Epoch 33: val_loss did not improve from 0.27407
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 588ms/step - accuracy: 0.8796 - loss: 0.2914 - val_accuracy: 0.8682 - val_loss: 0.2883 - learning_rate: 1.0000e-06
# Epoch 34/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.8703 - loss: 0.3171
# Epoch 34: val_loss did not improve from 0.27407
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 573ms/step - accuracy: 0.8704 - loss: 0.3169 - val_accuracy: 0.8727 - val_loss: 0.2855 - learning_rate: 1.0000e-06
# Epoch 35/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.8906 - loss: 0.2757
# Epoch 35: val_loss improved from 0.27407 to 0.26478, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 595ms/step - accuracy: 0.8905 - loss: 0.2757 - val_accuracy: 0.8788 - val_loss: 0.2648 - learning_rate: 1.0000e-06
# Epoch 36/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.8688 - loss: 0.2840
# Epoch 36: val_loss did not improve from 0.26478
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 80s 577ms/step - accuracy: 0.8689 - loss: 0.2840 - val_accuracy: 0.8712 - val_loss: 0.2761 - learning_rate: 1.0000e-06
# Epoch 37/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.8783 - loss: 0.2858
# Epoch 37: val_loss did not improve from 0.26478
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 592ms/step - accuracy: 0.8783 - loss: 0.2858 - val_accuracy: 0.8818 - val_loss: 0.2738 - learning_rate: 1.0000e-06
# Epoch 38/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.8727 - loss: 0.2898
# Epoch 38: val_loss improved from 0.26478 to 0.26311, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 579ms/step - accuracy: 0.8727 - loss: 0.2898 - val_accuracy: 0.8803 - val_loss: 0.2631 - learning_rate: 1.0000e-06
# Epoch 39/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.8627 - loss: 0.2863
# Epoch 39: val_loss did not improve from 0.26311
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 599ms/step - accuracy: 0.8628 - loss: 0.2862 - val_accuracy: 0.8803 - val_loss: 0.2678 - learning_rate: 1.0000e-06
# Epoch 40/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.8854 - loss: 0.2641
# Epoch 40: val_loss did not improve from 0.26311
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 597ms/step - accuracy: 0.8854 - loss: 0.2641 - val_accuracy: 0.8818 - val_loss: 0.2729 - learning_rate: 1.0000e-06
# Epoch 41/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.8801 - loss: 0.2684
# Epoch 41: val_loss did not improve from 0.26311
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 571ms/step - accuracy: 0.8801 - loss: 0.2684 - val_accuracy: 0.8727 - val_loss: 0.2687 - learning_rate: 1.0000e-06
# Epoch 42/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.8775 - loss: 0.2885
# Epoch 42: val_loss improved from 0.26311 to 0.25745, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 605ms/step - accuracy: 0.8776 - loss: 0.2884 - val_accuracy: 0.8742 - val_loss: 0.2574 - learning_rate: 1.0000e-06
# Epoch 43/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.8758 - loss: 0.2948
# Epoch 43: val_loss did not improve from 0.25745
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 51s 607ms/step - accuracy: 0.8758 - loss: 0.2948 - val_accuracy: 0.8742 - val_loss: 0.2626 - learning_rate: 1.0000e-06
# Epoch 44/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.8789 - loss: 0.2847
# Epoch 44: val_loss did not improve from 0.25745
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 579ms/step - accuracy: 0.8789 - loss: 0.2848 - val_accuracy: 0.8636 - val_loss: 0.2751 - learning_rate: 1.0000e-06
# Epoch 45/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.8799 - loss: 0.2822
# Epoch 45: val_loss did not improve from 0.25745
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 593ms/step - accuracy: 0.8799 - loss: 0.2821 - val_accuracy: 0.8909 - val_loss: 0.2622 - learning_rate: 1.0000e-06
# Epoch 46/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.8779 - loss: 0.2819
# Epoch 46: val_loss did not improve from 0.25745
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 576ms/step - accuracy: 0.8778 - loss: 0.2819 - val_accuracy: 0.8879 - val_loss: 0.2637 - learning_rate: 1.0000e-06
# Epoch 47/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.8667 - loss: 0.2945
# Epoch 47: val_loss did not improve from 0.25745
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 597ms/step - accuracy: 0.8668 - loss: 0.2944 - val_accuracy: 0.8727 - val_loss: 0.2689 - learning_rate: 1.0000e-06
# Epoch 48/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.8689 - loss: 0.2908
# Epoch 48: val_loss did not improve from 0.25745
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 570ms/step - accuracy: 0.8689 - loss: 0.2908 - val_accuracy: 0.8864 - val_loss: 0.2587 - learning_rate: 1.0000e-06
# Epoch 49/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.8832 - loss: 0.2879
# Epoch 49: val_loss did not improve from 0.25745
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 592ms/step - accuracy: 0.8832 - loss: 0.2879 - val_accuracy: 0.8833 - val_loss: 0.2605 - learning_rate: 1.0000e-06
# Epoch 50/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.8875 - loss: 0.2544
# Epoch 50: val_loss did not improve from 0.25745
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 586ms/step - accuracy: 0.8873 - loss: 0.2547 - val_accuracy: 0.8667 - val_loss: 0.2685 - learning_rate: 1.0000e-06
# Epoch 51/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.8790 - loss: 0.2565
# Epoch 51: val_loss improved from 0.25745 to 0.25658, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 604ms/step - accuracy: 0.8790 - loss: 0.2566 - val_accuracy: 0.8955 - val_loss: 0.2566 - learning_rate: 1.0000e-06
# ✅ Model loaded from: /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 710ms/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1]
# Valid labels: [0, 1]
# Target names: ['benign', 'malignant']
#
# Predicted sample count per class:
# benign: 365
# malignant: 295
#
# ✅ Overall Validation Accuracy: 87.42%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       benign       0.88      0.89      0.89       360
#    malignant       0.87      0.85      0.86       300
#
#     accuracy                           0.87       660
#    macro avg       0.87      0.87      0.87       660
# weighted avg       0.87      0.87      0.87       660
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-4220698297.py in <cell line: 0>()
#     270 # Compute ROC for each class
#     271 for i in range(n_classes):
# --> 272     if np.sum(y_true_bin[:, i]) == 0:
#     273         print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
#     274         missing_classes.append(labels[i])
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
