# %%
# Updated: InceptionV3 -> PyTorch Swin training & evaluation (Colab-ready)
# Replaces your TensorFlow InceptionV3 notebook with a robust PyTorch Swin pipeline.
# Requirements: torch, torchvision, timm, scikit-learn, tqdm, matplotlib, seaborn
# Uncomment to install in a fresh Colab runtime:
# !pip install -q torch torchvision timm scikit-learn tqdm matplotlib seaborn

import os
import random
import zipfile
import time
from collections import Counter

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torchvision import transforms, datasets
import timm
from tqdm import tqdm

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.utils.class_weight import compute_class_weight

# ---------------- Configuration (edit as needed) ----------------
DRIVE_MOUNT = True
ZIP_PATH = "/content/drive/MyDrive/d.zip"            # dataset zip on Drive (if used)
EXTRACT_PATH = "/content/dataset"
TRAIN_DIR = "/content/dataset/d/train"
VAL_DIR   = "/content/dataset/d/val"
GRAPH_DIR = "/content/drive/MyDrive/diabetic_eye_results"
CHECKPOINT_PATH = "/content/drive/MyDrive/best_swin_replacement.pt"
FINAL_MODEL_PATH = "/content/drive/MyDrive/final_swin_replacement.pt"

# Use Swin model (timm names). Examples:
# 'swin_tiny_patch4_window7_224', 'swin_small_patch4_window7_224',
# 'swin_base_patch4_window7_224', 'swin_large_patch4_window12_384' (if you have memory)
MODEL_NAME = "swin_base_patch4_window7_224"
IMG_SIZE = 224                        # Swin standard for these variants
BATCH_SIZE = 32
NUM_WORKERS = 2                       # safe default for Colab
SEED = 42
PHASE1_EPOCHS = 8
PHASE2_EPOCHS = 18
N_UNFREEZE = 6                        # number of Swin "layers/stages" to unfreeze in phase 2
SHOW_GPU_MEM = True                   # show GPU memory in postfix if CUDA available

# ---------------- Reproducibility ----------------
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# ---------------- Mount Drive & extract dataset (Colab) ----------------
if DRIVE_MOUNT:
    try:
        from google.colab import drive
        drive.mount('/content/drive', force_remount=False)
    except Exception:
        pass

if os.path.exists(ZIP_PATH) and not os.path.exists(EXTRACT_PATH):
    with zipfile.ZipFile(ZIP_PATH, 'r') as z:
        z.extractall(EXTRACT_PATH)
        print("Dataset extracted to", EXTRACT_PATH)
else:
    print("Zip not found or dataset already extracted (or already extracted).")

os.makedirs(GRAPH_DIR, exist_ok=True)
os.makedirs(os.path.dirname(CHECKPOINT_PATH), exist_ok=True)

# ---------------- Device & dataset checks ----------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

if not os.path.isdir(TRAIN_DIR) or not os.path.isdir(VAL_DIR):
    raise FileNotFoundError(f"Train/Val directories not found. Expected: {TRAIN_DIR} and {VAL_DIR}")

# ---------------- Class discovery ----------------
classes = sorted([d for d in os.listdir(TRAIN_DIR) if os.path.isdir(os.path.join(TRAIN_DIR, d))])
num_classes = len(classes)
print(f"Detected {num_classes} classes: {classes}")

# ---------------- Transforms ----------------
IMAGENET_MEAN = (0.485, 0.456, 0.406)
IMAGENET_STD  = (0.229, 0.224, 0.225)

train_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.RandomResizedCrop(IMG_SIZE, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.ColorJitter(brightness=0.12, contrast=0.12, saturation=0.12, hue=0.02),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

val_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(IMG_SIZE),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

# ---------------- Datasets & DataLoaders ----------------
train_dataset = datasets.ImageFolder(TRAIN_DIR, transform=train_transform)
val_dataset   = datasets.ImageFolder(VAL_DIR, transform=val_transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True,
                                           num_workers=NUM_WORKERS, pin_memory=True)
val_loader   = torch.utils.data.DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False,
                                           num_workers=NUM_WORKERS, pin_memory=True)

print("Train samples:", len(train_dataset), "Val samples:", len(val_dataset))

# ---------------- Class weights ----------------
y_train = [label for _, label in train_dataset.samples]
if num_classes > 1 and len(y_train) > 0:
    class_weights_np = compute_class_weight(class_weight='balanced', classes=np.arange(num_classes), y=y_train)
    class_weights = torch.tensor(class_weights_np, dtype=torch.float).to(device)
    print("Class weights:", class_weights.cpu().numpy())
else:
    class_weights = None

# ---------------- Model (timm Swin) ----------------
print("Creating model:", MODEL_NAME)
model = timm.create_model(MODEL_NAME, pretrained=True, num_classes=num_classes)
model.to(device)
print("Model created:", MODEL_NAME)

# ---------------- Phase 1: freeze backbone, train head ----------------
# First freeze everything
for name, p in model.named_parameters():
    p.requires_grad = False

# Heuristic: unfreeze head/classifier parameters (common names: 'head', 'fc', 'classifier')
head_param_count = 0
for name, p in model.named_parameters():
    lname = name.lower()
    if ('head' in lname) or ('classifier' in lname) or lname.endswith('.fc') or lname.endswith('.out_proj'):
        p.requires_grad = True
        head_param_count += 1

# Some timm swin variants use 'head' or 'norm' + 'head' naming; if none matched, attempt common final linear
if head_param_count == 0:
    for name, p in model.named_parameters():
        if name.endswith('fc') or name.endswith('head') or 'classifier' in name.lower():
            p.requires_grad = True
            head_param_count += 1

# As a last resort, try to find any parameter with shape matching (num_classes, ...) for a linear layer
if head_param_count == 0:
    for name, p in model.named_parameters():
        if p.dim() == 2 and p.size(0) == num_classes:
            p.requires_grad = True
            head_param_count += 1

print("Approx. trainable head parameter groups:", head_param_count)

# ---------------- Loss, optimizer, scheduler ----------------
criterion = nn.CrossEntropyLoss(weight=class_weights) if class_weights is not None else nn.CrossEntropyLoss()
optimizer = AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=2e-4, weight_decay=1e-2)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.3, patience=2)

# ---------------- Utilities ----------------
def human_gpu_mem():
    if not torch.cuda.is_available() or not SHOW_GPU_MEM:
        return ""
    # approximate reserved memory in GB
    return f"{torch.cuda.memory_reserved(device)/1024**3:.2f}GB"

def compute_metrics_all(y_true_list, y_pred_list, y_prob_array, class_names):
    y_true = np.array(y_true_list)
    y_pred = np.array(y_pred_list)
    acc = accuracy_score(y_true, y_pred)
    report = classification_report(y_true, y_pred, target_names=class_names, zero_division=0)
    n_classes = len(class_names)
    y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))
    if y_true_bin.ndim == 1:
        y_true_bin = y_true_bin.reshape(-1, 1)
    if y_true_bin.shape[1] == 1:
        y_true_bin = np.hstack([1 - y_true_bin, y_true_bin])
    fpr, tpr, roc_auc = {}, {}, {}
    aucs = []
    missing = []
    for i in range(n_classes):
        if np.sum(y_true_bin[:, i]) == 0:
            missing.append(class_names[i])
            continue
        try:
            fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_prob_array[:, i])
            roc_auc[i] = auc(fpr[i], tpr[i])
            aucs.append(roc_auc[i])
        except Exception:
            missing.append(class_names[i])
    macro_auc = np.mean(aucs) if len(aucs) > 0 else 0.0
    return acc, report, roc_auc, fpr, tpr, macro_auc, missing

# ---------------- Single-line progress training & validation ----------------
def train_one_epoch(model, loader, optimizer, device, epoch, total_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    pbar = tqdm(enumerate(loader, start=1), total=len(loader),
                desc=f"Train {epoch}/{total_epochs}", ncols=120, leave=False)
    for batch_idx, (imgs, labels) in pbar:
        imgs = imgs.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        logits = model(imgs)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * imgs.size(0)
        preds = logits.argmax(dim=1)
        correct += (preds == labels).sum().item()
        total += imgs.size(0)
        b_acc = (preds == labels).float().mean().item()
        running_epoch_loss = running_loss / total
        running_epoch_acc = correct / total
        postfix = {
            "b_loss": f"{loss.item():.4f}",
            "b_acc": f"{b_acc:.3f}",
            "e_loss": f"{running_epoch_loss:.4f}",
            "e_acc": f"{running_epoch_acc:.3f}"
        }
        if torch.cuda.is_available() and SHOW_GPU_MEM:
            postfix["GPU"] = human_gpu_mem()
        pbar.set_postfix(postfix, refresh=False)
    pbar.close()
    return running_loss / len(loader.dataset), correct / total if total>0 else 0.0

def validate(model, loader, device, epoch=None):
    model.eval()
    running_loss = 0.0
    all_preds = []
    all_labels = []
    all_probs = []
    pbar = tqdm(enumerate(loader, start=1), total=len(loader),
                desc=f"Val {epoch}" if epoch else "Val", ncols=120, leave=False)
    with torch.no_grad():
        for batch_idx, (imgs, labels) in pbar:
            imgs = imgs.to(device)
            labels = labels.to(device)
            logits = model(imgs)
            loss = criterion(logits, labels)
            running_loss += loss.item() * imgs.size(0)
            probs = F.softmax(logits, dim=1).cpu().numpy()
            preds = np.argmax(probs, axis=1)
            all_probs.append(probs)
            all_preds.extend(list(preds))
            all_labels.extend(list(labels.cpu().numpy()))
            batch_acc = (preds == labels.cpu().numpy()).mean()
            running_epoch_loss = running_loss / (len(all_labels) if len(all_labels)>0 else 1)
            running_epoch_acc = accuracy_score(all_labels, all_preds) if len(all_labels)>0 else 0.0
            postfix = {
                "b_loss": f"{loss.item():.4f}",
                "b_acc": f"{batch_acc:.3f}",
                "e_loss": f"{running_epoch_loss:.4f}",
                "e_acc": f"{running_epoch_acc:.3f}"
            }
            if torch.cuda.is_available() and SHOW_GPU_MEM:
                postfix["GPU"] = human_gpu_mem()
            pbar.set_postfix(postfix, refresh=False)
    pbar.close()
    val_loss = running_loss / len(loader.dataset)
    all_probs = np.vstack(all_probs) if all_probs else np.zeros((0, num_classes))
    return val_loss, all_labels, all_preds, all_probs

# ---------------- Helper: unfreeze last N Swin "blocks/layers" robustly ----------------
def unfreeze_last_swin_layers(model, n_unfreeze):
    """
    Attempt to unfreeze the last `n_unfreeze` logical blocks/layers of a Swin-like model.
    Tries common attribute names used in timm implementations: layers, stages, blocks, features.
    If none found, falls back to unfreezing the entire backbone (everything except head).
    """
    unfrozen = 0
    # Try several possible attribute names in decreasing specificity
    candidates = []
    if hasattr(model, "layers"):
        candidates.append(("layers", model.layers))
    if hasattr(model, "stages"):
        candidates.append(("stages", model.stages))
    if hasattr(model, "blocks"):
        candidates.append(("blocks", model.blocks))
    if hasattr(model, "features"):
        candidates.append(("features", model.features))
    # also check model.backbone or model.patch_embed (less common)
    if hasattr(model, "backbone"):
        backbone = getattr(model, "backbone")
        if hasattr(backbone, "layers"):
            candidates.append(("backbone.layers", backbone.layers))
        if hasattr(backbone, "stages"):
            candidates.append(("backbone.stages", backbone.stages))

    for name, container in candidates:
        try:
            # many containers are torch.nn.ModuleList or list-like
            total = len(container)
            start_idx = max(0, total - n_unfreeze)
            print(f"Detected container '{name}' with {total} elements. Unfreezing indices [{start_idx} .. {total-1}].")
            for i in range(start_idx, total):
                block = container[i]
                for p in block.parameters():
                    p.requires_grad = True
                    unfrozen += 1
            if unfrozen > 0:
                return True
        except Exception as e:
            # continue trying other candidates
            print(f"Candidate '{name}' unfreeze attempt failed: {e}")
            continue

    # fallback: try to find sequential modules that look like swin stages under model (search shallowly)
    try:
        named_children = list(model.named_children())
        # look for attributes containing 'layer' or 'stage' in their name
        stage_attrs = [getattr(model, n) for n, _ in named_children if 'layer' in n.lower() or 'stage' in n.lower() or 'block' in n.lower()]
        for container in stage_attrs:
            try:
                total = len(container)
                start_idx = max(0, total - n_unfreeze)
                for i in range(start_idx, total):
                    for p in container[i].parameters():
                        p.requires_grad = True
                        unfrozen += 1
                if unfrozen > 0:
                    return True
            except Exception:
                continue
    except Exception:
        pass

    # Last resort: unfreeze everything (but keep head already trainable)
    if unfrozen == 0:
        print("Could not detect 'layers/stages/blocks' on model. Falling back to unfreezing entire model backbone.")
        for name, p in model.named_parameters():
            # keep head as is (head already trainable); here we make everything trainable
            p.requires_grad = True
        return True

    return unfrozen > 0

# ---------------- Training loop ----------------
history = {"train_loss":[], "train_acc":[], "val_loss":[], "val_acc":[], "val_auc_macro":[]}
best_val_loss = float('inf')
best_auc_macro = 0.0
total_epochs = PHASE1_EPOCHS + PHASE2_EPOCHS

print("Starting Phase 1 (head-only) for", PHASE1_EPOCHS, "epochs.")
for epoch in range(1, PHASE1_EPOCHS + 1):
    t0 = time.time()
    train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, device, epoch, total_epochs)
    val_loss, y_true_val, y_pred_val, y_prob_val = validate(model, val_loader, device, epoch)
    _, _, _, _, _, val_auc_macro, _ = compute_metrics_all(y_true_val, y_pred_val, y_prob_val, classes)
    scheduler.step(val_loss)
    history["train_loss"].append(train_loss); history["train_acc"].append(train_acc)
    history["val_loss"].append(val_loss); history["val_acc"].append(accuracy_score(y_true_val, y_pred_val))
    history["val_auc_macro"].append(val_auc_macro)
    print(f"Epoch {epoch}/{PHASE1_EPOCHS} summary: train_loss={train_loss:.4f} train_acc={train_acc:.4f} val_loss={val_loss:.4f} val_acc={history['val_acc'][-1]:.4f} val_auc={val_auc_macro:.4f}  time={time.time()-t0:.1f}s")
    if val_loss < best_val_loss or val_auc_macro > best_auc_macro:
        best_val_loss = val_loss
        best_auc_macro = max(best_auc_macro, val_auc_macro)
        torch.save(model.state_dict(), CHECKPOINT_PATH)
        print("Saved best model to:", CHECKPOINT_PATH)

# ---------------- Phase 2: unfreeze last N swin layers/stages ----------------
print("Unfreezing last", N_UNFREEZE, "Swin blocks/layers (if available).")
try:
    unfreeze_last_swin_layers(model, N_UNFREEZE)
except Exception as e:
    print("Unfreeze fallback — setting entire model trainable. Error:", e)
    for p in model.parameters():
        p.requires_grad = True

# Recreate optimizer and scheduler for finetuning (lower LR)
optimizer = AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-5, weight_decay=1e-2)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.3, patience=2)

print("Starting Phase 2 (fine-tuning) for", PHASE2_EPOCHS, "epochs.")
for epoch in range(PHASE1_EPOCHS + 1, total_epochs + 1):
    t0 = time.time()
    train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, device, epoch, total_epochs)
    val_loss, y_true_val, y_pred_val, y_prob_val = validate(model, val_loader, device, epoch)
    _, _, _, _, _, val_auc_macro, _ = compute_metrics_all(y_true_val, y_pred_val, y_prob_val, classes)
    scheduler.step(val_loss)
    history["train_loss"].append(train_loss); history["train_acc"].append(train_acc)
    history["val_loss"].append(val_loss); history["val_acc"].append(accuracy_score(y_true_val, y_pred_val))
    history["val_auc_macro"].append(val_auc_macro)
    print(f"Epoch {epoch}/{total_epochs} summary: train_loss={train_loss:.4f} train_acc={train_acc:.4f} val_loss={val_loss:.4f} val_acc={history['val_acc'][-1]:.4f} val_auc={val_auc_macro:.4f}  time={time.time()-t0:.1f}s")
    if val_loss < best_val_loss or val_auc_macro > best_auc_macro:
        best_val_loss = min(best_val_loss, val_loss)
        best_auc_macro = max(best_auc_macro, val_auc_macro)
        torch.save(model.state_dict(), CHECKPOINT_PATH)
        print("Saved best model to:", CHECKPOINT_PATH)

# ---------------- Final evaluation ----------------
print("Loading best model from:", CHECKPOINT_PATH)
model.load_state_dict(torch.load(CHECKPOINT_PATH, map_location=device))
model.to(device)
model.eval()

val_loss, y_true_val, y_pred_val, y_prob_val = validate(model, val_loader, device, epoch="final")
acc, report, roc_auc_dict, fpr_dict, tpr_dict, macro_auc, missing = compute_metrics_all(y_true_val, y_pred_val, y_prob_val, classes)
print("\nFinal Validation Accuracy: {:.2f}%".format(acc * 100))
print("\nClassification Report:\n", report)
print("Macro AUC (mean of available class AUCs):", macro_auc)
if missing:
    print("Skipped ROC for classes (no positive samples):", missing)

# ---------------- Save plots ----------------
os.makedirs(GRAPH_DIR, exist_ok=True)
epochs_range = range(1, len(history["train_loss"]) + 1)

plt.figure(figsize=(8,5))
plt.plot(epochs_range, history["train_acc"], marker='o', label='Train Acc')
plt.plot(epochs_range, history["val_acc"], marker='o', label='Val Acc')
plt.xlabel("Epoch"); plt.ylabel("Accuracy"); plt.title("Accuracy over Epochs"); plt.grid(True, linestyle='--', alpha=0.4); plt.legend()
acc_path = os.path.join(GRAPH_DIR, "swin_repl_accuracy.png")
plt.tight_layout(); plt.savefig(acc_path, dpi=150); plt.show()
print("Saved accuracy plot to:", acc_path)

plt.figure(figsize=(8,5))
plt.plot(epochs_range, history["train_loss"], marker='o', label='Train Loss')
plt.plot(epochs_range, history["val_loss"], marker='o', label='Val Loss')
plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.title("Loss over Epochs"); plt.grid(True, linestyle='--', alpha=0.4); plt.legend()
loss_path = os.path.join(GRAPH_DIR, "swin_repl_loss.png")
plt.tight_layout(); plt.savefig(loss_path, dpi=150); plt.show()
print("Saved loss plot to:", loss_path)

cm = confusion_matrix(y_true_val, y_pred_val, labels=list(range(num_classes)))
plt.figure(figsize=(7,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
plt.xlabel("Predicted"); plt.ylabel("Actual"); plt.title("Confusion Matrix"); plt.tight_layout()
cm_path = os.path.join(GRAPH_DIR, "swin_repl_confusion_matrix.png")
plt.savefig(cm_path, dpi=150); plt.show()
print("Saved confusion matrix to:", cm_path)

plt.figure(figsize=(9,8))
plotted = False
for i in range(num_classes):
    if i in roc_auc_dict:
        plt.plot(fpr_dict[i], tpr_dict[i], label=f"{classes[i]} (AUC={roc_auc_dict[i]:.3f})"); plotted = True
plt.plot([0,1],[0,1], linestyle='--', label='Chance')
if plotted:
    plt.title("ROC Curves per class"); plt.xlabel("FPR"); plt.ylabel("TPR"); plt.legend(loc='lower right')
    roc_path = os.path.join(GRAPH_DIR, "swin_repl_roc.png"); plt.tight_layout(); plt.savefig(roc_path, dpi=150); plt.show()
    print("Saved ROC plot to:", roc_path)
else:
    print("No ROC curves plotted (no positive samples for some classes).")

# ---------------- Save final model ----------------
torch.save(model.state_dict(), FINAL_MODEL_PATH)
print("Saved final model state dict to:", FINAL_MODEL_PATH)
# Out:
# Mounted at /content/drive
# Dataset extracted to /content/dataset
# Device: cuda
# Detected 2 classes: ['benign', 'malignant']
# Train samples: 2637 Val samples: 660
# Class weights: [0.915625  1.1015037]
# Creating model: swin_base_patch4_window7_224
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Model created: swin_base_patch4_window7_224
# Approx. trainable head parameter groups: 2
# Starting Phase 1 (head-only) for 8 epochs.
# Epoch 1/8 summary: train_loss=0.5727 train_acc=0.7156 val_loss=0.4836 val_acc=0.7606 val_auc=0.8688  time=43.6s
# Saved best model to: /content/drive/MyDrive/best_swin_replacement.pt
# Epoch 2/8 summary: train_loss=0.4415 train_acc=0.8089 val_loss=0.4118 val_acc=0.8091 val_auc=0.9092  time=42.2s
# Saved best model to: /content/drive/MyDrive/best_swin_replacement.pt
# Epoch 3/8 summary: train_loss=0.3909 train_acc=0.8347 val_loss=0.3790 val_acc=0.8348 val_auc=0.9196  time=44.4s
# Saved best model to: /content/drive/MyDrive/best_swin_replacement.pt
# Epoch 4/8 summary: train_loss=0.3680 train_acc=0.8335 val_loss=0.3624 val_acc=0.8439 val_auc=0.9269  time=43.4s
# Saved best model to: /content/drive/MyDrive/best_swin_replacement.pt
# Epoch 5/8 summary: train_loss=0.3543 train_acc=0.8400 val_loss=0.3458 val_acc=0.8485 val_auc=0.9300  time=44.4s
# Saved best model to: /content/drive/MyDrive/best_swin_replacement.pt
# Epoch 6/8 summary: train_loss=0.3484 train_acc=0.8411 val_loss=0.3432 val_acc=0.8576 val_auc=0.9308  time=45.1s
# Saved best model to: /content/drive/MyDrive/best_swin_replacement.pt
# Epoch 7/8 summary: train_loss=0.3368 train_acc=0.8457 val_loss=0.3469 val_acc=0.8515 val_auc=0.9331  time=44.1s
# Saved best model to: /content/drive/MyDrive/best_swin_replacement.pt
# Epoch 8/8 summary: train_loss=0.3341 train_acc=0.8453 val_loss=0.3333 val_acc=0.8545 val_auc=0.9344  time=44.3s
# Saved best model to: /content/drive/MyDrive/best_swin_replacement.pt
# Unfreezing last 6 Swin blocks/layers (if available).
# Detected container 'layers' with 4 elements. Unfreezing indices [0 .. 3].
# Starting Phase 2 (fine-tuning) for 18 epochs.
# Epoch 9/26 summary: train_loss=0.2974 train_acc=0.8631 val_loss=0.2687 val_acc=0.8682 val_auc=0.9570  time=101.3s
# Saved best model to: /content/drive/MyDrive/best_swin_replacement.pt
# Epoch 10/26 summary: train_loss=0.2467 train_acc=0.8832 val_loss=0.2687 val_acc=0.8742 val_auc=0.9607  time=101.2s
# Saved best model to: /content/drive/MyDrive/best_swin_replacement.pt
# Epoch 11/26 summary: train_loss=0.2092 train_acc=0.9029 val_loss=0.2288 val_acc=0.8970 val_auc=0.9678  time=101.2s
# Saved best model to: /content/drive/MyDrive/best_swin_replacement.pt
# Epoch 12/26 summary: train_loss=0.1756 train_acc=0.9226 val_loss=0.2697 val_acc=0.8818 val_auc=0.9698  time=101.4s
# Saved best model to: /content/drive/MyDrive/best_swin_replacement.pt
# Epoch 13/26 summary: train_loss=0.1615 train_acc=0.9257 val_loss=0.2310 val_acc=0.8894 val_auc=0.9693  time=101.1s
# Epoch 14/26 summary: train_loss=0.1551 train_acc=0.9333 val_loss=0.2600 val_acc=0.8864 val_auc=0.9731  time=101.5s
# Saved best model to: /content/drive/MyDrive/best_swin_replacement.pt
# Epoch 15/26 summary: train_loss=0.1072 train_acc=0.9560 val_loss=0.2233 val_acc=0.9045 val_auc=0.9735  time=100.8s
# Saved best model to: /content/drive/MyDrive/best_swin_replacement.pt
# Epoch 16/26 summary: train_loss=0.0982 train_acc=0.9621 val_loss=0.2382 val_acc=0.9015 val_auc=0.9731  time=101.0s
# Epoch 17/26 summary: train_loss=0.0894 train_acc=0.9659 val_loss=0.2662 val_acc=0.8879 val_auc=0.9725  time=100.7s
# Epoch 18/26 summary: train_loss=0.0866 train_acc=0.9644 val_loss=0.2505 val_acc=0.8955 val_auc=0.9717  time=101.2s
# Epoch 19/26 summary: train_loss=0.0767 train_acc=0.9727 val_loss=0.2448 val_acc=0.9030 val_auc=0.9728  time=101.3s
# Epoch 20/26 summary: train_loss=0.0770 train_acc=0.9697 val_loss=0.2538 val_acc=0.9045 val_auc=0.9726  time=101.2s
# Epoch 21/26 summary: train_loss=0.0730 train_acc=0.9712 val_loss=0.2567 val_acc=0.9015 val_auc=0.9728  time=101.6s
# Epoch 22/26 summary: train_loss=0.0655 train_acc=0.9803 val_loss=0.2608 val_acc=0.9015 val_auc=0.9728  time=101.4s
# Epoch 23/26 summary: train_loss=0.0685 train_acc=0.9735 val_loss=0.2633 val_acc=0.9015 val_auc=0.9728  time=102.0s
# Epoch 24/26 summary: train_loss=0.0741 train_acc=0.9689 val_loss=0.2665 val_acc=0.8985 val_auc=0.9727  time=101.4s
# Epoch 25/26 summary: train_loss=0.0578 train_acc=0.9829 val_loss=0.2662 val_acc=0.9030 val_auc=0.9727  time=101.4s
# Epoch 26/26 summary: train_loss=0.0697 train_acc=0.9784 val_loss=0.2655 val_acc=0.9015 val_auc=0.9726  time=101.5s
# Loading best model from: /content/drive/MyDrive/best_swin_replacement.pt
# Final Validation Accuracy: 90.45%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.95      0.88      0.91       360
#    malignant       0.86      0.94      0.90       300
#
#     accuracy                           0.90       660
#    macro avg       0.90      0.91      0.90       660
# weighted avg       0.91      0.90      0.90       660
#
# Macro AUC (mean of available class AUCs): 0.973462962962963
# Saved accuracy plot to: /content/drive/MyDrive/diabetic_eye_results/swin_repl_accuracy.png
# Saved loss plot to: /content/drive/MyDrive/diabetic_eye_results/swin_repl_loss.png
# Saved confusion matrix to: /content/drive/MyDrive/diabetic_eye_results/swin_repl_confusion_matrix.png
# Saved ROC plot to: /content/drive/MyDrive/diabetic_eye_results/swin_repl_roc.png
# Saved final model state dict to: /content/drive/MyDrive/final_swin_replacement.pt
