# %%
# Updated: ViT replaced with ResNet50 + CBAM (Colab-ready)
# Requirements: torch, torchvision, timm, scikit-learn, tqdm, matplotlib, seaborn
# Uncomment to install in a fresh Colab runtime:
# !pip install -q torch torchvision timm scikit-learn tqdm matplotlib seaborn

import os
import random
import zipfile
import time
from collections import Counter

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torchvision import transforms, datasets, models   # changed: import models
import timm
from tqdm import tqdm

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.utils.class_weight import compute_class_weight

# ---------------- Configuration (edit as needed) ----------------
DRIVE_MOUNT = True
ZIP_PATH = "/content/drive/MyDrive/d.zip"            # dataset zip on Drive (if used)
EXTRACT_PATH = "/content/dataset"
TRAIN_DIR = "/content/dataset/d/train"
VAL_DIR   = "/content/dataset/d/val"
GRAPH_DIR = "/content/drive/MyDrive/diabetic_eye_results"
CHECKPOINT_PATH = "/content/drive/MyDrive/best_vit_inception_replacement.pt"
FINAL_MODEL_PATH = "/content/drive/MyDrive/final_vit_inception_replacement.pt"

# --- CBAM / CNN CHANGES ---
BACKBONE_NAME = "resnet50"   # use torchvision resnet50 as backbone
IMG_SIZE = 224               # consistent with earlier
# --- end CBAM / CNN CHANGES ---

BATCH_SIZE = 32
NUM_WORKERS = 2                       # safe default for Colab
SEED = 42
PHASE1_EPOCHS = 8
PHASE2_EPOCHS = 18
N_UNFREEZE = 6                        # interpreted as number of ResNet bottleneck blocks to unfreeze (last N)
SHOW_GPU_MEM = True                   # show GPU memory in postfix if CUDA available

# ---------------- Reproducibility ----------------
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# ---------------- Mount Drive & extract dataset (Colab) ----------------
if DRIVE_MOUNT:
    try:
        from google.colab import drive
        drive.mount('/content/drive', force_remount=False)
    except Exception:
        pass

if os.path.exists(ZIP_PATH) and not os.path.exists(EXTRACT_PATH):
    with zipfile.ZipFile(ZIP_PATH, 'r') as z:
        z.extractall(EXTRACT_PATH)
        print("Dataset extracted to", EXTRACT_PATH)
else:
    print("Zip not found or dataset already extracted (or already extracted).")

os.makedirs(GRAPH_DIR, exist_ok=True)
os.makedirs(os.path.dirname(CHECKPOINT_PATH), exist_ok=True)

# ---------------- Device & dataset checks ----------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

if not os.path.isdir(TRAIN_DIR) or not os.path.isdir(VAL_DIR):
    raise FileNotFoundError(f"Train/Val directories not found. Expected: {TRAIN_DIR} and {VAL_DIR}")

# ---------------- Class discovery ----------------
classes = sorted([d for d in os.listdir(TRAIN_DIR) if os.path.isdir(os.path.join(TRAIN_DIR, d))])
num_classes = len(classes)
print(f"Detected {num_classes} classes: {classes}")

# ---------------- Transforms ----------------
IMAGENET_MEAN = (0.485, 0.456, 0.406)
IMAGENET_STD  = (0.229, 0.224, 0.225)

train_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.RandomResizedCrop(IMG_SIZE, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.ColorJitter(brightness=0.12, contrast=0.12, saturation=0.12, hue=0.02),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

val_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(IMG_SIZE),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

# ---------------- Datasets & DataLoaders ----------------
train_dataset = datasets.ImageFolder(TRAIN_DIR, transform=train_transform)
val_dataset   = datasets.ImageFolder(VAL_DIR, transform=val_transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True,
                                           num_workers=NUM_WORKERS, pin_memory=True)
val_loader   = torch.utils.data.DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False,
                                           num_workers=NUM_WORKERS, pin_memory=True)

print("Train samples:", len(train_dataset), "Val samples:", len(val_dataset))

# ---------------- Class weights ----------------
y_train = [label for _, label in train_dataset.samples]
if num_classes > 1 and len(y_train) > 0:
    class_weights_np = compute_class_weight(class_weight='balanced', classes=np.arange(num_classes), y=y_train)
    class_weights = torch.tensor(class_weights_np, dtype=torch.float).to(device)
    print("Class weights:", class_weights.cpu().numpy())
else:
    class_weights = None

# ---------------- CBAM Implementation (Channel & Spatial Attention) ----------------
# Reference idea: CBAM: https://arxiv.org/abs/1807.06521 (implementation adapted)
class ChannelAttention(nn.Module):
    def __init__(self, in_planes, ratio=16):
        super(ChannelAttention, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)

        self.fc = nn.Sequential(
            nn.Conv2d(in_planes, in_planes // ratio, 1, bias=False),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_planes // ratio, in_planes, 1, bias=False)
        )
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = self.fc(self.avg_pool(x))
        max_out = self.fc(self.max_pool(x))
        out = avg_out + max_out
        return self.sigmoid(out)

class SpatialAttention(nn.Module):
    def __init__(self, kernel_size=7):
        super(SpatialAttention, self).__init__()
        assert kernel_size in (3, 7), "kernel_size must be 3 or 7"
        padding = 3 if kernel_size == 7 else 1
        self.conv = nn.Conv2d(2, 1, kernel_size, padding=padding, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        # channel-wise avg & max
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        cat = torch.cat([avg_out, max_out], dim=1)
        out = self.conv(cat)
        return self.sigmoid(out)

class CBAM(nn.Module):
    def __init__(self, channels, ratio=16, kernel_size=7):
        super(CBAM, self).__init__()
        self.ca = ChannelAttention(channels, ratio)
        self.sa = SpatialAttention(kernel_size)

    def forward(self, x):
        out = x * self.ca(x)
        out = out * self.sa(out)
        return out

# ---------------- ResNet50 + CBAM wrapper ----------------
class ResNetCBAM(nn.Module):
    def __init__(self, backbone_name='resnet50', pretrained=True, num_classes=2, dropout=0.5, use_cbam_after=('layer3', 'layer4')):
        super(ResNetCBAM, self).__init__()
        assert backbone_name in ['resnet18','resnet34','resnet50','resnet101','resnet152']
        # load torchvision backbone
        backbone = getattr(models, backbone_name)(pretrained=pretrained)
        # keep the conv/BN/relu/maxpool/layers but remove the original fc
        self.conv1 = backbone.conv1
        self.bn1 = backbone.bn1
        self.relu = backbone.relu
        self.maxpool = backbone.maxpool
        self.layer1 = backbone.layer1
        self.layer2 = backbone.layer2
        self.layer3 = backbone.layer3
        self.layer4 = backbone.layer4
        self.avgpool = backbone.avgpool

        # CBAM placement: create CBAMs for specified layers if available
        self.cbam_after = {}
        if 'layer3' in use_cbam_after:
            # layer3 output channels: for resnet50 it's 1024
            channels = self._get_layer_out_channels('layer3', backbone_name)
            self.cbam3 = CBAM(channels)
            self.cbam_after['layer3'] = self.cbam3
        else:
            self.cbam3 = None

        if 'layer4' in use_cbam_after:
            channels = self._get_layer_out_channels('layer4', backbone_name)
            self.cbam4 = CBAM(channels)
            self.cbam_after['layer4'] = self.cbam4
        else:
            self.cbam4 = None

        # Head
        self.dropout = nn.Dropout(dropout) if dropout > 0 else nn.Identity()
        self.classifier = nn.Linear(self._get_layer_out_channels('layer4', backbone_name), num_classes)

        # init classifier if needed (small init)
        nn.init.normal_(self.classifier.weight, 0, 0.01)
        if self.classifier.bias is not None:
            nn.init.constant_(self.classifier.bias, 0.0)

    def _get_layer_out_channels(self, layer_name, backbone_name):
        # typical mapping for ResNet variants (channels after layerX)
        # resnet50/101/152: layer1=256, layer2=512, layer3=1024, layer4=2048
        # resnet18/34: layer1=64, layer2=128, layer3=256, layer4=512
        if backbone_name in ['resnet18', 'resnet34']:
            mapping = {'layer1': 64, 'layer2': 128, 'layer3': 256, 'layer4': 512}
        else:
            mapping = {'layer1': 256, 'layer2': 512, 'layer3': 1024, 'layer4': 2048}
        return mapping[layer_name]

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool(x)

        x = self.layer1(x)
        x = self.layer2(x)
        x = self.layer3(x)
        if self.cbam3 is not None:
            x = self.cbam3(x)   # apply CBAM after layer3
        x = self.layer4(x)
        if self.cbam4 is not None:
            x = self.cbam4(x)   # apply CBAM after layer4

        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.dropout(x)
        x = self.classifier(x)
        return x

# ---------------- Model (ResNet50 + CBAM) ----------------
print("Creating ResNet + CBAM model:", BACKBONE_NAME)
model = ResNetCBAM(backbone_name=BACKBONE_NAME, pretrained=True, num_classes=num_classes, dropout=0.5,
                   use_cbam_after=('layer3','layer4'))
model.to(device)
print("Model created:", BACKBONE_NAME, "with CBAM after layer3 and layer4")

# ---------------- Phase 1: freeze backbone, train head + CBAM modules ----------------
# Freeze all parameters first
for name, p in model.named_parameters():
    p.requires_grad = False

# Unfreeze classifier head and CBAM parameters
unfrozen = 0
for name, p in model.named_parameters():
    if name.startswith("classifier") or "cbam" in name.lower() or name.startswith("dropout"):
        p.requires_grad = True
        unfrozen += 1

# If classifier naming differs, ensure classifier weights are trainable
if unfrozen == 0:
    for name, p in model.named_parameters():
        if name.endswith(".weight") and p.shape and p.shape[0] == num_classes:
            p.requires_grad = True
            unfrozen += 1

print("Approx. trainable parameter groups after Phase 1 freeze (head+CBAM):", unfrozen)

# ---------------- Loss, optimizer, scheduler ----------------
criterion = nn.CrossEntropyLoss(weight=class_weights) if class_weights is not None else nn.CrossEntropyLoss()
optimizer = AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=2e-4, weight_decay=1e-2)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.3, patience=2)

# ---------------- Utilities ----------------
def human_gpu_mem():
    if not torch.cuda.is_available() or not SHOW_GPU_MEM:
        return ""
    # approximate reserved memory in GB
    return f"{torch.cuda.memory_reserved(device)/1024**3:.2f}GB"

def compute_metrics_all(y_true_list, y_pred_list, y_prob_array, class_names):
    y_true = np.array(y_true_list)
    y_pred = np.array(y_pred_list)
    acc = accuracy_score(y_true, y_pred)
    report = classification_report(y_true, y_pred, target_names=class_names, zero_division=0)
    n_classes = len(class_names)
    y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))
    if y_true_bin.ndim == 1:
        y_true_bin = y_true_bin.reshape(-1, 1)
    if y_true_bin.shape[1] == 1:
        y_true_bin = np.hstack([1 - y_true_bin, y_true_bin])
    fpr, tpr, roc_auc = {}, {}, {}
    aucs = []
    missing = []
    for i in range(n_classes):
        if np.sum(y_true_bin[:, i]) == 0:
            missing.append(class_names[i])
            continue
        try:
            fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_prob_array[:, i])
            roc_auc[i] = auc(fpr[i], tpr[i])
            aucs.append(roc_auc[i])
        except Exception:
            missing.append(class_names[i])
    macro_auc = np.mean(aucs) if len(aucs) > 0 else 0.0
    return acc, report, roc_auc, fpr, tpr, macro_auc, missing

# ---------------- Single-line progress training & validation ----------------
def train_one_epoch(model, loader, optimizer, device, epoch, total_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    pbar = tqdm(enumerate(loader, start=1), total=len(loader),
                desc=f"Train {epoch}/{total_epochs}", ncols=120, leave=False)
    for batch_idx, (imgs, labels) in pbar:
        imgs = imgs.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        logits = model(imgs)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * imgs.size(0)
        preds = logits.argmax(dim=1)
        correct += (preds == labels).sum().item()
        total += imgs.size(0)
        b_acc = (preds == labels).float().mean().item()
        running_epoch_loss = running_loss / total
        running_epoch_acc = correct / total
        postfix = {
            "b_loss": f"{loss.item():.4f}",
            "b_acc": f"{b_acc:.3f}",
            "e_loss": f"{running_epoch_loss:.4f}",
            "e_acc": f"{running_epoch_acc:.3f}"
        }
        if torch.cuda.is_available() and SHOW_GPU_MEM:
            postfix["GPU"] = human_gpu_mem()
        pbar.set_postfix(postfix, refresh=False)
    pbar.close()
    return running_loss / len(loader.dataset), correct / total if total>0 else 0.0

def validate(model, loader, device, epoch=None):
    model.eval()
    running_loss = 0.0
    all_preds = []
    all_labels = []
    all_probs = []
    pbar = tqdm(enumerate(loader, start=1), total=len(loader),
                desc=f"Val {epoch}" if epoch else "Val", ncols=120, leave=False)
    with torch.no_grad():
        for batch_idx, (imgs, labels) in pbar:
            imgs = imgs.to(device)
            labels = labels.to(device)
            logits = model(imgs)
            loss = criterion(logits, labels)
            running_loss += loss.item() * imgs.size(0)
            probs = F.softmax(logits, dim=1).cpu().numpy()
            preds = np.argmax(probs, axis=1)
            all_probs.append(probs)
            all_preds.extend(list(preds))
            all_labels.extend(list(labels.cpu().numpy()))
            batch_acc = (preds == labels.cpu().numpy()).mean()
            running_epoch_loss = running_loss / (len(all_labels) if len(all_labels)>0 else 1)
            running_epoch_acc = accuracy_score(all_labels, all_preds) if len(all_labels)>0 else 0.0
            postfix = {
                "b_loss": f"{loss.item():.4f}",
                "b_acc": f"{batch_acc:.3f}",
                "e_loss": f"{running_epoch_loss:.4f}",
                "e_acc": f"{running_epoch_acc:.3f}"
            }
            if torch.cuda.is_available() and SHOW_GPU_MEM:
                postfix["GPU"] = human_gpu_mem()
            pbar.set_postfix(postfix, refresh=False)
    pbar.close()
    val_loss = running_loss / len(loader.dataset)
    all_probs = np.vstack(all_probs) if all_probs else np.zeros((0, num_classes))
    return val_loss, all_labels, all_preds, all_probs

# ---------------- Training loop ----------------
history = {"train_loss":[], "train_acc":[], "val_loss":[], "val_acc":[], "val_auc_macro":[]}
best_val_loss = float('inf')
best_auc_macro = 0.0
total_epochs = PHASE1_EPOCHS + PHASE2_EPOCHS

print("Starting Phase 1 (head-only) for", PHASE1_EPOCHS, "epochs.")
for epoch in range(1, PHASE1_EPOCHS + 1):
    t0 = time.time()
    train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, device, epoch, total_epochs)
    val_loss, y_true_val, y_pred_val, y_prob_val = validate(model, val_loader, device, epoch)
    _, _, _, _, _, val_auc_macro, _ = compute_metrics_all(y_true_val, y_pred_val, y_prob_val, classes)
    scheduler.step(val_loss)
    history["train_loss"].append(train_loss); history["train_acc"].append(train_acc)
    history["val_loss"].append(val_loss); history["val_acc"].append(accuracy_score(y_true_val, y_pred_val))
    history["val_auc_macro"].append(val_auc_macro)
    print(f"Epoch {epoch}/{PHASE1_EPOCHS} summary: train_loss={train_loss:.4f} train_acc={train_acc:.4f} val_loss={val_loss:.4f} val_acc={history['val_acc'][-1]:.4f} val_auc={val_auc_macro:.4f}  time={time.time()-t0:.1f}s")
    if val_loss < best_val_loss or val_auc_macro > best_auc_macro:
        best_val_loss = val_loss
        best_auc_macro = max(best_auc_macro, val_auc_macro)
        torch.save(model.state_dict(), CHECKPOINT_PATH)
        print("Saved best model to:", CHECKPOINT_PATH)

# ---------------- Phase 2: unfreeze last N_UNFREEZE ResNet bottleneck blocks ----------------
print("Unfreezing last", N_UNFREEZE, "ResNet bottleneck blocks (if available).")

# gather all bottleneck modules from layer1..layer4 in order
bottlenecks = []
layer_names = ['layer1','layer2','layer3','layer4']
for lname in layer_names:
    layer = getattr(model, lname, None)
    if layer is None:
        continue
    # each layer is a Sequential of Bottleneck/BasicBlock modules
    for block in layer:
        bottlenecks.append(block)

total_blocks = len(bottlenecks)
print("Detected total ResNet bottleneck blocks:", total_blocks)

# unfreeze last N_UNFREEZE bottleneck blocks
to_unfreeze = min(N_UNFREEZE, total_blocks)
start_idx = max(0, total_blocks - to_unfreeze)
for i in range(start_idx, total_blocks):
    for p in bottlenecks[i].parameters():
        p.requires_grad = True

# also ensure CBAM modules and head remain trainable
for name, p in model.named_parameters():
    if "cbam" in name.lower() or name.startswith("classifier") or name.startswith("dropout"):
        p.requires_grad = True

# fallback: if nothing trainable (very unlikely), unfreeze whole model
if not any(p.requires_grad for p in model.parameters()):
    print("Fallback: no parameters were trainable, unfreezing entire model.")
    for p in model.parameters():
        p.requires_grad = True

# Recreate optimizer and scheduler for finetuning (lower LR)
optimizer = AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-5, weight_decay=1e-2)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.3, patience=2)

print("Starting Phase 2 (fine-tuning) for", PHASE2_EPOCHS, "epochs.")
for epoch in range(PHASE1_EPOCHS + 1, total_epochs + 1):
    t0 = time.time()
    train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, device, epoch, total_epochs)
    val_loss, y_true_val, y_pred_val, y_prob_val = validate(model, val_loader, device, epoch)
    _, _, _, _, _, val_auc_macro, _ = compute_metrics_all(y_true_val, y_pred_val, y_prob_val, classes)
    scheduler.step(val_loss)
    history["train_loss"].append(train_loss); history["train_acc"].append(train_acc)
    history["val_loss"].append(val_loss); history["val_acc"].append(accuracy_score(y_true_val, y_pred_val))
    history["val_auc_macro"].append(val_auc_macro)
    print(f"Epoch {epoch}/{total_epochs} summary: train_loss={train_loss:.4f} train_acc={train_acc:.4f} val_loss={val_loss:.4f} val_acc={history['val_acc'][-1]:.4f} val_auc={val_auc_macro:.4f}  time={time.time()-t0:.1f}s")
    if val_loss < best_val_loss or val_auc_macro > best_auc_macro:
        best_val_loss = min(best_val_loss, val_loss)
        best_auc_macro = max(best_auc_macro, val_auc_macro)
        torch.save(model.state_dict(), CHECKPOINT_PATH)
        print("Saved best model to:", CHECKPOINT_PATH)

# ---------------- Final evaluation ----------------
print("Loading best model from:", CHECKPOINT_PATH)
model.load_state_dict(torch.load(CHECKPOINT_PATH, map_location=device))
model.to(device)
model.eval()

val_loss, y_true_val, y_pred_val, y_prob_val = validate(model, val_loader, device, epoch="final")
acc, report, roc_auc_dict, fpr_dict, tpr_dict, macro_auc, missing = compute_metrics_all(y_true_val, y_pred_val, y_prob_val, classes)
print("\nFinal Validation Accuracy: {:.2f}%".format(acc * 100))
print("\nClassification Report:\n", report)
print("Macro AUC (mean of available class AUCs):", macro_auc)
if missing:
    print("Skipped ROC for classes (no positive samples):", missing)

# ---------------- Save plots ----------------
os.makedirs(GRAPH_DIR, exist_ok=True)
epochs_range = range(1, len(history["train_loss"]) + 1)

plt.figure(figsize=(8,5))
plt.plot(epochs_range, history["train_acc"], marker='o', label='Train Acc')
plt.plot(epochs_range, history["val_acc"], marker='o', label='Val Acc')
plt.xlabel("Epoch"); plt.ylabel("Accuracy"); plt.title("Accuracy over Epochs"); plt.grid(True, linestyle='--', alpha=0.4); plt.legend()
acc_path = os.path.join(GRAPH_DIR, "inception_repl_accuracy.png")
plt.tight_layout(); plt.savefig(acc_path, dpi=150); plt.show()
print("Saved accuracy plot to:", acc_path)

plt.figure(figsize=(8,5))
plt.plot(epochs_range, history["train_loss"], marker='o', label='Train Loss')
plt.plot(epochs_range, history["val_loss"], marker='o', label='Val Loss')
plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.title("Loss over Epochs"); plt.grid(True, linestyle='--', alpha=0.4); plt.legend()
loss_path = os.path.join(GRAPH_DIR, "inception_repl_loss.png")
plt.tight_layout(); plt.savefig(loss_path, dpi=150); plt.show()
print("Saved loss plot to:", loss_path)

cm = confusion_matrix(y_true_val, y_pred_val, labels=list(range(num_classes)))
plt.figure(figsize=(7,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
plt.xlabel("Predicted"); plt.ylabel("Actual"); plt.title("Confusion Matrix"); plt.tight_layout()
cm_path = os.path.join(GRAPH_DIR, "inception_repl_confusion_matrix.png")
plt.savefig(cm_path, dpi=150); plt.show()
print("Saved confusion matrix to:", cm_path)

plt.figure(figsize=(9,8))
plotted = False
for i in range(num_classes):
    if i in roc_auc_dict:
        plt.plot(fpr_dict[i], tpr_dict[i], label=f"{classes[i]} (AUC={roc_auc_dict[i]:.3f})"); plotted = True
plt.plot([0,1],[0,1], linestyle='--', label='Chance')
if plotted:
    plt.title("ROC Curves per class"); plt.xlabel("FPR"); plt.ylabel("TPR"); plt.legend(loc='lower right')
    roc_path = os.path.join(GRAPH_DIR, "inception_repl_roc.png"); plt.tight_layout(); plt.savefig(roc_path, dpi=150); plt.show()
    print("Saved ROC plot to:", roc_path)
else:
    print("No ROC curves plotted (no positive samples for some classes).")

# ---------------- Save final model ----------------
torch.save(model.state_dict(), FINAL_MODEL_PATH)
print("Saved final model state dict to:", FINAL_MODEL_PATH)
# Out:
# Mounted at /content/drive
# Dataset extracted to /content/dataset
# Device: cuda
# Detected 2 classes: ['benign', 'malignant']
# Train samples: 2637 Val samples: 660
# Class weights: [0.915625  1.1015037]
# Creating ResNet + CBAM model: resnet50
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 147MB/s]
# Model created: resnet50 with CBAM after layer3 and layer4
# Approx. trainable parameter groups after Phase 1 freeze (head+CBAM): 8
# Starting Phase 1 (head-only) for 8 epochs.
# Epoch 1/8 summary: train_loss=0.6058 train_acc=0.6849 val_loss=0.4595 val_acc=0.8106 val_auc=0.8810  time=31.9s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Epoch 2/8 summary: train_loss=0.4380 train_acc=0.8028 val_loss=0.3861 val_acc=0.8242 val_auc=0.9017  time=28.9s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Epoch 3/8 summary: train_loss=0.3914 train_acc=0.8221 val_loss=0.3508 val_acc=0.8409 val_auc=0.9164  time=29.8s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Epoch 4/8 summary: train_loss=0.3688 train_acc=0.8407 val_loss=0.3568 val_acc=0.8394 val_auc=0.9201  time=29.7s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Epoch 5/8 summary: train_loss=0.3499 train_acc=0.8415 val_loss=0.3604 val_acc=0.8409 val_auc=0.9272  time=29.6s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Epoch 6/8 summary: train_loss=0.3433 train_acc=0.8521 val_loss=0.3168 val_acc=0.8561 val_auc=0.9345  time=29.7s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Epoch 7/8 summary: train_loss=0.3222 train_acc=0.8491 val_loss=0.3121 val_acc=0.8530 val_auc=0.9369  time=29.6s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Epoch 8/8 summary: train_loss=0.3217 train_acc=0.8567 val_loss=0.3210 val_acc=0.8576 val_auc=0.9394  time=30.0s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Unfreezing last 6 ResNet bottleneck blocks (if available).
# Detected total ResNet bottleneck blocks: 16
# Starting Phase 2 (fine-tuning) for 18 epochs.
# Epoch 9/26 summary: train_loss=0.3084 train_acc=0.8616 val_loss=0.3177 val_acc=0.8576 val_auc=0.9475  time=31.1s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Epoch 10/26 summary: train_loss=0.2814 train_acc=0.8695 val_loss=0.3026 val_acc=0.8652 val_auc=0.9532  time=31.8s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Epoch 11/26 summary: train_loss=0.2583 train_acc=0.8855 val_loss=0.2709 val_acc=0.8727 val_auc=0.9572  time=31.8s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Epoch 12/26 summary: train_loss=0.2420 train_acc=0.8904 val_loss=0.2754 val_acc=0.8727 val_auc=0.9574  time=32.9s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Epoch 13/26 summary: train_loss=0.2378 train_acc=0.8953 val_loss=0.2592 val_acc=0.8818 val_auc=0.9608  time=32.2s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Epoch 14/26 summary: train_loss=0.2144 train_acc=0.9105 val_loss=0.2675 val_acc=0.8742 val_auc=0.9616  time=31.4s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Epoch 15/26 summary: train_loss=0.1912 train_acc=0.9219 val_loss=0.2491 val_acc=0.8879 val_auc=0.9645  time=32.7s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Epoch 16/26 summary: train_loss=0.1888 train_acc=0.9143 val_loss=0.2408 val_acc=0.8939 val_auc=0.9657  time=32.1s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Epoch 17/26 summary: train_loss=0.1751 train_acc=0.9242 val_loss=0.2483 val_acc=0.8879 val_auc=0.9657  time=32.1s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Epoch 18/26 summary: train_loss=0.1567 train_acc=0.9397 val_loss=0.2438 val_acc=0.8909 val_auc=0.9687  time=33.4s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Epoch 19/26 summary: train_loss=0.1459 train_acc=0.9420 val_loss=0.2372 val_acc=0.8985 val_auc=0.9699  time=31.8s
# Saved best model to: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Epoch 20/26 summary: train_loss=0.1483 train_acc=0.9382 val_loss=0.2540 val_acc=0.8970 val_auc=0.9696  time=32.1s
# Epoch 21/26 summary: train_loss=0.1230 train_acc=0.9515 val_loss=0.2602 val_acc=0.9030 val_auc=0.9689  time=31.6s
# Epoch 22/26 summary: train_loss=0.1204 train_acc=0.9556 val_loss=0.2694 val_acc=0.9015 val_auc=0.9670  time=30.7s
# Epoch 23/26 summary: train_loss=0.1134 train_acc=0.9583 val_loss=0.2727 val_acc=0.8985 val_auc=0.9691  time=30.4s
# Epoch 24/26 summary: train_loss=0.1115 train_acc=0.9564 val_loss=0.2533 val_acc=0.9015 val_auc=0.9695  time=30.9s
# Epoch 25/26 summary: train_loss=0.0942 train_acc=0.9651 val_loss=0.2626 val_acc=0.8970 val_auc=0.9693  time=30.7s
# Epoch 26/26 summary: train_loss=0.1094 train_acc=0.9609 val_loss=0.2593 val_acc=0.8985 val_auc=0.9695  time=31.7s
# Loading best model from: /content/drive/MyDrive/best_vit_inception_replacement.pt
# Final Validation Accuracy: 89.85%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.93      0.88      0.90       360
#    malignant       0.86      0.92      0.89       300
#
#     accuracy                           0.90       660
#    macro avg       0.90      0.90      0.90       660
# weighted avg       0.90      0.90      0.90       660
#
# Macro AUC (mean of available class AUCs): 0.9699444444444445
# Saved accuracy plot to: /content/drive/MyDrive/diabetic_eye_results/inception_repl_accuracy.png
# Saved loss plot to: /content/drive/MyDrive/diabetic_eye_results/inception_repl_loss.png
# Saved confusion matrix to: /content/drive/MyDrive/diabetic_eye_results/inception_repl_confusion_matrix.png
# Saved ROC plot to: /content/drive/MyDrive/diabetic_eye_results/inception_repl_roc.png
# Saved final model state dict to: /content/drive/MyDrive/final_vit_inception_replacement.pt
