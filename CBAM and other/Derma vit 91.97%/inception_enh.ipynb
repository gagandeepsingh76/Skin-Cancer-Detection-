# %%
# Updated: InceptionV3 -> PyTorch ViT training & evaluation (Colab-ready)
# Replaces your TensorFlow InceptionV3 notebook with a robust PyTorch ViT pipeline.
# Requirements: torch, torchvision, timm, scikit-learn, tqdm, matplotlib, seaborn
# Uncomment to install in a fresh Colab runtime:
# !pip install -q torch torchvision timm scikit-learn tqdm matplotlib seaborn

import os
import random
import zipfile
import time
from collections import Counter

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torchvision import transforms, datasets
import timm
from tqdm import tqdm

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.utils.class_weight import compute_class_weight

# ---------------- Configuration (edit as needed) ----------------
DRIVE_MOUNT = True
ZIP_PATH = "/content/drive/MyDrive/d.zip"            # dataset zip on Drive (if used)
EXTRACT_PATH = "/content/dataset"
TRAIN_DIR = "/content/dataset/d/train"
VAL_DIR   = "/content/dataset/d/val"

# Experiment / graph directory (keeps per-experiment plots separate)
BASE_GRAPH_DIR = "/content/drive/MyDrive/diabetic_eye_results"
MODEL_NAME = "DermaViT224"   # Your experiment name (alias)

# Map experiment alias -> actual timm model name (so you can use friendly names)
MODEL_MAP = {
    "DermaViT224": "vit_base_patch16_224",
    "SkinViT224":  "vit_base_patch16_224",
    "MelaViT224":  "vit_base_patch16_224",
    "OncoViT224":  "vit_base_patch16_224",
    # larger resolution options (if you want to run 384 later)
    "DermaViT384": "vit_base_patch16_384",
    "SkinViT384":  "vit_base_patch16_384",
    "MelaViT384":  "vit_base_patch16_384",
    "OncoViT384":  "vit_base_patch16_384",
}

# Resolve timm model name (falls back to MODEL_NAME if a real timm name is provided)
TIMM_MODEL_NAME = MODEL_MAP.get(MODEL_NAME, MODEL_NAME)

# Save paths that include your experiment name
GRAPH_DIR = os.path.join(BASE_GRAPH_DIR, MODEL_NAME)
CHECKPOINT_PATH = f"/content/drive/MyDrive/{MODEL_NAME}_best.pt"
FINAL_MODEL_PATH = f"/content/drive/MyDrive/{MODEL_NAME}_final.pt"

IMG_SIZE = 224                        # ViT standard (224) — change to 384 if using *384 timm variant
BATCH_SIZE = 32
NUM_WORKERS = 2                       # safe default for Colab
SEED = 42
PHASE1_EPOCHS = 8
PHASE2_EPOCHS = 43   # updated so total epochs = 8 + 43 = 51
N_UNFREEZE = 6                        # number of transformer blocks to unfreeze in phase 2
SHOW_GPU_MEM = True                   # show GPU memory in postfix if CUDA available

# ---------------- Reproducibility ----------------
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# ---------------- Mount Drive & extract dataset (Colab) ----------------
if DRIVE_MOUNT:
    try:
        from google.colab import drive
        drive.mount('/content/drive', force_remount=False)
    except Exception:
        pass

if os.path.exists(ZIP_PATH) and not os.path.exists(EXTRACT_PATH):
    with zipfile.ZipFile(ZIP_PATH, 'r') as z:
        z.extractall(EXTRACT_PATH)
        print("Dataset extracted to", EXTRACT_PATH)
else:
    print("Zip not found or dataset already extracted (or already extracted).")

os.makedirs(GRAPH_DIR, exist_ok=True)
os.makedirs(os.path.dirname(CHECKPOINT_PATH), exist_ok=True)

# ---------------- Device & dataset checks ----------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

if not os.path.isdir(TRAIN_DIR) or not os.path.isdir(VAL_DIR):
    raise FileNotFoundError(f"Train/Val directories not found. Expected: {TRAIN_DIR} and {VAL_DIR}")

# ---------------- Class discovery ----------------
classes = sorted([d for d in os.listdir(TRAIN_DIR) if os.path.isdir(os.path.join(TRAIN_DIR, d))])
num_classes = len(classes)
print(f"Detected {num_classes} classes: {classes}")

# ---------------- Transforms ----------------
IMAGENET_MEAN = (0.485, 0.456, 0.406)
IMAGENET_STD  = (0.229, 0.224, 0.225)

train_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.RandomResizedCrop(IMG_SIZE, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.ColorJitter(brightness=0.12, contrast=0.12, saturation=0.12, hue=0.02),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

val_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(IMG_SIZE),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

# ---------------- Datasets & DataLoaders ----------------
train_dataset = datasets.ImageFolder(TRAIN_DIR, transform=train_transform)
val_dataset   = datasets.ImageFolder(VAL_DIR, transform=val_transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True,
                                           num_workers=NUM_WORKERS, pin_memory=True)
val_loader   = torch.utils.data.DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False,
                                           num_workers=NUM_WORKERS, pin_memory=True)

print("Train samples:", len(train_dataset), "Val samples:", len(val_dataset))

# ---------------- Class weights ----------------
y_train = [label for _, label in train_dataset.samples]
if num_classes > 1 and len(y_train) > 0:
    class_weights_np = compute_class_weight(class_weight='balanced', classes=np.arange(num_classes), y=y_train)
    class_weights = torch.tensor(class_weights_np, dtype=torch.float).to(device)
    print("Class weights:", class_weights.cpu().numpy())
else:
    class_weights = None

# ---------------- Model (timm ViT) ----------------
print(f"Creating timm model: {TIMM_MODEL_NAME} (experiment name: {MODEL_NAME})")
model = timm.create_model(TIMM_MODEL_NAME, pretrained=True, num_classes=num_classes)
model.to(device)
print("Model created:", TIMM_MODEL_NAME)

# ---------------- Phase 1: freeze ViT encoder, train head ----------------
# Freeze encoder (model.vit / model.patch_embed etc.) — timm models expose `requires_grad` via named_parameters
for name, p in model.named_parameters():
    p.requires_grad = False

# Make classifier head parameters trainable (timm usually uses 'head' naming)
head_param_count = 0
for name, p in model.named_parameters():
    if ("head" in name) or ("classifier" in name) or ("norm" in name and "head" in name):
        p.requires_grad = True
        head_param_count += 1
# If none matched, unfreeze final linear layer directly
if head_param_count == 0:
    # try common names
    for name, p in model.named_parameters():
        if name.endswith("fc") or "head" in name:
            p.requires_grad = True
            head_param_count += 1

print("Approx. trainable head parameter groups:", head_param_count)

# ---------------- Loss, optimizer, scheduler ----------------
criterion = nn.CrossEntropyLoss(weight=class_weights) if class_weights is not None else nn.CrossEntropyLoss()
optimizer = AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=2e-4, weight_decay=1e-2)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.3, patience=2)

# ---------------- Utilities ----------------
def human_gpu_mem():
    if not torch.cuda.is_available() or not SHOW_GPU_MEM:
        return ""
    # approximate reserved memory in GB
    return f"{torch.cuda.memory_reserved(device)/1024**3:.2f}GB"

def compute_metrics_all(y_true_list, y_pred_list, y_prob_array, class_names):
    y_true = np.array(y_true_list)
    y_pred = np.array(y_pred_list)
    acc = accuracy_score(y_true, y_pred)
    report = classification_report(y_true, y_pred, target_names=class_names, zero_division=0)
    n_classes = len(class_names)
    y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))
    if y_true_bin.ndim == 1:
        y_true_bin = y_true_bin.reshape(-1, 1)
    if y_true_bin.shape[1] == 1:
        y_true_bin = np.hstack([1 - y_true_bin, y_true_bin])
    fpr, tpr, roc_auc = {}, {}, {}
    aucs = []
    missing = []
    for i in range(n_classes):
        if np.sum(y_true_bin[:, i]) == 0:
            missing.append(class_names[i])
            continue
        try:
            fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_prob_array[:, i])
            roc_auc[i] = auc(fpr[i], tpr[i])
            aucs.append(roc_auc[i])
        except Exception:
            missing.append(class_names[i])
    macro_auc = np.mean(aucs) if len(aucs) > 0 else 0.0
    return acc, report, roc_auc, fpr, tpr, macro_auc, missing

# ---------------- Single-line progress training & validation ----------------
def train_one_epoch(model, loader, optimizer, device, epoch, total_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    pbar = tqdm(enumerate(loader, start=1), total=len(loader),
                desc=f"Train {epoch}/{total_epochs}", ncols=120, leave=False)
    for batch_idx, (imgs, labels) in pbar:
        imgs = imgs.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        logits = model(imgs)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * imgs.size(0)
        preds = logits.argmax(dim=1)
        correct += (preds == labels).sum().item()
        total += imgs.size(0)
        b_acc = (preds == labels).float().mean().item()
        running_epoch_loss = running_loss / total
        running_epoch_acc = correct / total
        postfix = {
            "b_loss": f"{loss.item():.4f}",
            "b_acc": f"{b_acc:.3f}",
            "e_loss": f"{running_epoch_loss:.4f}",
            "e_acc": f"{running_epoch_acc:.3f}"
        }
        if torch.cuda.is_available() and SHOW_GPU_MEM:
            postfix["GPU"] = human_gpu_mem()
        pbar.set_postfix(postfix, refresh=False)
    pbar.close()
    return running_loss / len(loader.dataset), correct / total if total>0 else 0.0

def validate(model, loader, device, epoch=None):
    model.eval()
    running_loss = 0.0
    all_preds = []
    all_labels = []
    all_probs = []
    pbar = tqdm(enumerate(loader, start=1), total=len(loader),
                desc=f"Val {epoch}" if epoch else "Val", ncols=120, leave=False)
    with torch.no_grad():
        for batch_idx, (imgs, labels) in pbar:
            imgs = imgs.to(device)
            labels = labels.to(device)
            logits = model(imgs)
            loss = criterion(logits, labels)
            running_loss += loss.item() * imgs.size(0)
            probs = F.softmax(logits, dim=1).cpu().numpy()
            preds = np.argmax(probs, axis=1)
            all_probs.append(probs)
            all_preds.extend(list(preds))
            all_labels.extend(list(labels.cpu().numpy()))
            batch_acc = (preds == labels.cpu().numpy()).mean()
            running_epoch_loss = running_loss / (len(all_labels) if len(all_labels)>0 else 1)
            running_epoch_acc = accuracy_score(all_labels, all_preds) if len(all_labels)>0 else 0.0
            postfix = {
                "b_loss": f"{loss.item():.4f}",
                "b_acc": f"{batch_acc:.3f}",
                "e_loss": f"{running_epoch_loss:.4f}",
                "e_acc": f"{running_epoch_acc:.3f}"
            }
            if torch.cuda.is_available() and SHOW_GPU_MEM:
                postfix["GPU"] = human_gpu_mem()
            pbar.set_postfix(postfix, refresh=False)
    pbar.close()
    val_loss = running_loss / len(loader.dataset)
    all_probs = np.vstack(all_probs) if all_probs else np.zeros((0, num_classes))
    return val_loss, all_labels, all_preds, all_probs

# ---------------- Training loop ----------------
history = {"train_loss":[], "train_acc":[], "val_loss":[], "val_acc":[], "val_auc_macro":[]}
best_val_loss = float('inf')
best_auc_macro = 0.0
total_epochs = PHASE1_EPOCHS + PHASE2_EPOCHS

print("Starting Phase 1 (head-only) for", PHASE1_EPOCHS, "epochs.")
for epoch in range(1, PHASE1_EPOCHS + 1):
    t0 = time.time()
    train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, device, epoch, total_epochs)
    val_loss, y_true_val, y_pred_val, y_prob_val = validate(model, val_loader, device, epoch)
    _, _, _, _, _, val_auc_macro, _ = compute_metrics_all(y_true_val, y_pred_val, y_prob_val, classes)
    scheduler.step(val_loss)
    history["train_loss"].append(train_loss); history["train_acc"].append(train_acc)
    history["val_loss"].append(val_loss); history["val_acc"].append(accuracy_score(y_true_val, y_pred_val))
    history["val_auc_macro"].append(val_auc_macro)
    print(f"Epoch {epoch}/{PHASE1_EPOCHS} summary: train_loss={train_loss:.4f} train_acc={train_acc:.4f} val_loss={val_loss:.4f} val_acc={history['val_acc'][-1]:.4f} val_auc={val_auc_macro:.4f}  time={time.time()-t0:.1f}s")
    if val_loss < best_val_loss or val_auc_macro > best_auc_macro:
        best_val_loss = val_loss
        best_auc_macro = max(best_auc_macro, val_auc_macro)
        torch.save(model.state_dict(), CHECKPOINT_PATH)
        print("Saved best model to:", CHECKPOINT_PATH)

# ---------------- Phase 2: unfreeze last N transformer blocks ----------------
print("Unfreezing last", N_UNFREEZE, "transformer blocks (if available).")
try:
    # many timm ViT variants use model.blocks or model.blocks (inside model.vit). Try common locations
    unfreezed = False
    if hasattr(model, "blocks"):
        total_blocks = len(model.blocks)
        print("Transformer blocks detected at model.blocks:", total_blocks)
        for i in range(max(0, total_blocks - N_UNFREEZE), total_blocks):
            for p in model.blocks[i].parameters():
                p.requires_grad = True
        unfreezed = True
    elif hasattr(model, "vit") and hasattr(model.vit, "blocks"):
        total_blocks = len(model.vit.blocks)
        print("Transformer blocks detected at model.vit.blocks:", total_blocks)
        for i in range(max(0, total_blocks - N_UNFREEZE), total_blocks):
            for p in model.vit.blocks[i].parameters():
                p.requires_grad = True
        unfreezed = True

    if not unfreezed:
        # fallback: make entire model trainable
        print("No blocks attribute found — falling back to full model unfreeze.")
        for p in model.parameters():
            p.requires_grad = True
except Exception as e:
    print("Unfreeze fallback — setting entire model trainable. Error:", e)
    for p in model.parameters():
        p.requires_grad = True

# Recreate optimizer and scheduler for finetuning (lower LR)
optimizer = AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-5, weight_decay=1e-2)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.3, patience=2)

print("Starting Phase 2 (fine-tuning) for", PHASE2_EPOCHS, "epochs.")
for epoch in range(PHASE1_EPOCHS + 1, total_epochs + 1):
    t0 = time.time()
    train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, device, epoch, total_epochs)
    val_loss, y_true_val, y_pred_val, y_prob_val = validate(model, val_loader, device, epoch)
    _, _, _, _, _, val_auc_macro, _ = compute_metrics_all(y_true_val, y_pred_val, y_prob_val, classes)
    scheduler.step(val_loss)
    history["train_loss"].append(train_loss); history["train_acc"].append(train_acc)
    history["val_loss"].append(val_loss); history["val_acc"].append(accuracy_score(y_true_val, y_pred_val))
    history["val_auc_macro"].append(val_auc_macro)
    print(f"Epoch {epoch}/{total_epochs} summary: train_loss={train_loss:.4f} train_acc={train_acc:.4f} val_loss={val_loss:.4f} val_acc={history['val_acc'][-1]:.4f} val_auc={val_auc_macro:.4f}  time={time.time()-t0:.1f}s")
    if val_loss < best_val_loss or val_auc_macro > best_auc_macro:
        best_val_loss = min(best_val_loss, val_loss)
        best_auc_macro = max(best_auc_macro, val_auc_macro)
        torch.save(model.state_dict(), CHECKPOINT_PATH)
        print("Saved best model to:", CHECKPOINT_PATH)

# ---------------- Final evaluation ----------------
print("Loading best model from:", CHECKPOINT_PATH)
model.load_state_dict(torch.load(CHECKPOINT_PATH, map_location=device))
model.to(device)
model.eval()

val_loss, y_true_val, y_pred_val, y_prob_val = validate(model, val_loader, device, epoch="final")
acc, report, roc_auc_dict, fpr_dict, tpr_dict, macro_auc, missing = compute_metrics_all(y_true_val, y_pred_val, y_prob_val, classes)
print("\nFinal Validation Accuracy: {:.2f}%".format(acc * 100))
print("\nClassification Report:\n", report)
print("Macro AUC (mean of available class AUCs):", macro_auc)
if missing:
    print("Skipped ROC for classes (no positive samples):", missing)

# ---------------- Save plots ----------------
os.makedirs(GRAPH_DIR, exist_ok=True)
epochs_range = range(1, len(history["train_loss"]) + 1)

plt.figure(figsize=(8,5))
plt.plot(epochs_range, history["train_acc"], marker='o', label='Train Acc')
plt.plot(epochs_range, history["val_acc"], marker='o', label='Val Acc')
plt.xlabel("Epoch"); plt.ylabel("Accuracy"); plt.title(f"{MODEL_NAME} - Accuracy over Epochs"); plt.grid(True, linestyle='--', alpha=0.4); plt.legend()
acc_path = os.path.join(GRAPH_DIR, f"{MODEL_NAME}_accuracy.png")
plt.tight_layout(); plt.savefig(acc_path, dpi=150); plt.show()
print("Saved accuracy plot to:", acc_path)

plt.figure(figsize=(8,5))
plt.plot(epochs_range, history["train_loss"], marker='o', label='Train Loss')
plt.plot(epochs_range, history["val_loss"], marker='o', label='Val Loss')
plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.title(f"{MODEL_NAME} - Loss over Epochs"); plt.grid(True, linestyle='--', alpha=0.4); plt.legend()
loss_path = os.path.join(GRAPH_DIR, f"{MODEL_NAME}_loss.png")
plt.tight_layout(); plt.savefig(loss_path, dpi=150); plt.show()
print("Saved loss plot to:", loss_path)

cm = confusion_matrix(y_true_val, y_pred_val, labels=list(range(num_classes)))
plt.figure(figsize=(7,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
plt.xlabel("Predicted"); plt.ylabel("Actual"); plt.title(f"{MODEL_NAME} - Confusion Matrix"); plt.tight_layout()
cm_path = os.path.join(GRAPH_DIR, f"{MODEL_NAME}_confusion_matrix.png")
plt.savefig(cm_path, dpi=150); plt.show()
print("Saved confusion matrix to:", cm_path)

plt.figure(figsize=(9,8))
plotted = False
for i in range(num_classes):
    if i in roc_auc_dict:
        plt.plot(fpr_dict[i], tpr_dict[i], label=f"{classes[i]} (AUC={roc_auc_dict[i]:.3f})"); plotted = True
plt.plot([0,1],[0,1], linestyle='--', label='Chance')
if plotted:
    plt.title(f"{MODEL_NAME} - ROC Curves per class"); plt.xlabel("FPR"); plt.ylabel("TPR"); plt.legend(loc='lower right')
    roc_path = os.path.join(GRAPH_DIR, f"{MODEL_NAME}_roc.png"); plt.tight_layout(); plt.savefig(roc_path, dpi=150); plt.show()
    print("Saved ROC plot to:", roc_path)
else:
    print("No ROC curves plotted (no positive samples for some classes).")

# ---------------- Save final model ----------------
torch.save(model.state_dict(), FINAL_MODEL_PATH)
print("Saved final model state dict to:", FINAL_MODEL_PATH)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Zip not found or dataset already extracted (or already extracted).
# Device: cuda
# Detected 2 classes: ['benign', 'malignant']
# Train samples: 2637 Val samples: 660
# Class weights: [0.915625  1.1015037]
# Creating timm model: vit_base_patch16_224 (experiment name: DermaViT224)
# Model created: vit_base_patch16_224
# Approx. trainable head parameter groups: 2
# Starting Phase 1 (head-only) for 8 epochs.
# Epoch 1/8 summary: train_loss=0.5814 train_acc=0.7008 val_loss=0.4311 val_acc=0.7985 val_auc=0.8885  time=37.7s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 2/8 summary: train_loss=0.4145 train_acc=0.8187 val_loss=0.3751 val_acc=0.8424 val_auc=0.9142  time=39.1s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 3/8 summary: train_loss=0.3851 train_acc=0.8335 val_loss=0.3497 val_acc=0.8333 val_auc=0.9260  time=40.2s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 4/8 summary: train_loss=0.3574 train_acc=0.8464 val_loss=0.3333 val_acc=0.8606 val_auc=0.9317  time=40.5s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 5/8 summary: train_loss=0.3434 train_acc=0.8540 val_loss=0.3273 val_acc=0.8530 val_auc=0.9335  time=40.9s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 6/8 summary: train_loss=0.3436 train_acc=0.8495 val_loss=0.3275 val_acc=0.8712 val_auc=0.9365  time=40.9s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 7/8 summary: train_loss=0.3261 train_acc=0.8654 val_loss=0.3208 val_acc=0.8652 val_auc=0.9382  time=40.9s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 8/8 summary: train_loss=0.3229 train_acc=0.8597 val_loss=0.3211 val_acc=0.8591 val_auc=0.9379  time=40.5s
# Unfreezing last 6 transformer blocks (if available).
# Transformer blocks detected at model.blocks: 12
# Starting Phase 2 (fine-tuning) for 43 epochs.
# Epoch 9/51 summary: train_loss=0.3104 train_acc=0.8604 val_loss=0.2604 val_acc=0.8788 val_auc=0.9588  time=68.6s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 10/51 summary: train_loss=0.2430 train_acc=0.8900 val_loss=0.2464 val_acc=0.8848 val_auc=0.9628  time=67.5s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 11/51 summary: train_loss=0.2127 train_acc=0.9082 val_loss=0.2477 val_acc=0.8924 val_auc=0.9659  time=67.3s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 12/51 summary: train_loss=0.1806 train_acc=0.9170 val_loss=0.2348 val_acc=0.9000 val_auc=0.9690  time=67.7s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 13/51 summary: train_loss=0.1599 train_acc=0.9264 val_loss=0.2509 val_acc=0.8894 val_auc=0.9702  time=67.6s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 14/51 summary: train_loss=0.1375 train_acc=0.9374 val_loss=0.2250 val_acc=0.9030 val_auc=0.9704  time=67.4s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 15/51 summary: train_loss=0.1144 train_acc=0.9511 val_loss=0.2304 val_acc=0.9091 val_auc=0.9739  time=67.8s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 16/51 summary: train_loss=0.0994 train_acc=0.9571 val_loss=0.2243 val_acc=0.9152 val_auc=0.9757  time=67.5s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 17/51 summary: train_loss=0.0940 train_acc=0.9617 val_loss=0.2617 val_acc=0.9061 val_auc=0.9756  time=67.8s
# Epoch 18/51 summary: train_loss=0.0651 train_acc=0.9723 val_loss=0.2479 val_acc=0.9015 val_auc=0.9728  time=67.9s
# Epoch 19/51 summary: train_loss=0.0588 train_acc=0.9772 val_loss=0.2447 val_acc=0.9076 val_auc=0.9749  time=67.9s
# Epoch 20/51 summary: train_loss=0.0432 train_acc=0.9848 val_loss=0.2471 val_acc=0.9167 val_auc=0.9764  time=68.2s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 21/51 summary: train_loss=0.0289 train_acc=0.9905 val_loss=0.2514 val_acc=0.9076 val_auc=0.9760  time=68.0s
# Epoch 22/51 summary: train_loss=0.0274 train_acc=0.9920 val_loss=0.2487 val_acc=0.9227 val_auc=0.9775  time=67.8s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 23/51 summary: train_loss=0.0223 train_acc=0.9924 val_loss=0.2498 val_acc=0.9197 val_auc=0.9776  time=68.1s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 24/51 summary: train_loss=0.0200 train_acc=0.9932 val_loss=0.2526 val_acc=0.9197 val_auc=0.9775  time=67.9s
# Epoch 25/51 summary: train_loss=0.0171 train_acc=0.9947 val_loss=0.2566 val_acc=0.9167 val_auc=0.9776  time=67.9s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 26/51 summary: train_loss=0.0192 train_acc=0.9947 val_loss=0.2534 val_acc=0.9212 val_auc=0.9777  time=67.6s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 27/51 summary: train_loss=0.0190 train_acc=0.9947 val_loss=0.2560 val_acc=0.9197 val_auc=0.9781  time=67.8s
# Saved best model to: /content/drive/MyDrive/DermaViT224_best.pt
# Epoch 28/51 summary: train_loss=0.0162 train_acc=0.9962 val_loss=0.2547 val_acc=0.9212 val_auc=0.9778  time=67.9s
# Epoch 29/51 summary: train_loss=0.0171 train_acc=0.9951 val_loss=0.2545 val_acc=0.9212 val_auc=0.9777  time=67.7s
# Epoch 30/51 summary: train_loss=0.0176 train_acc=0.9947 val_loss=0.2538 val_acc=0.9227 val_auc=0.9779  time=67.7s
# Epoch 31/51 summary: train_loss=0.0167 train_acc=0.9943 val_loss=0.2533 val_acc=0.9212 val_auc=0.9778  time=67.7s
# Epoch 32/51 summary: train_loss=0.0156 train_acc=0.9954 val_loss=0.2533 val_acc=0.9212 val_auc=0.9778  time=67.6s
# Epoch 33/51 summary: train_loss=0.0156 train_acc=0.9970 val_loss=0.2535 val_acc=0.9212 val_auc=0.9779  time=67.7s
# Epoch 34/51 summary: train_loss=0.0141 train_acc=0.9954 val_loss=0.2537 val_acc=0.9212 val_auc=0.9779  time=67.4s
# Epoch 35/51 summary: train_loss=0.0167 train_acc=0.9947 val_loss=0.2538 val_acc=0.9212 val_auc=0.9779  time=67.9s
# Epoch 36/51 summary: train_loss=0.0185 train_acc=0.9936 val_loss=0.2538 val_acc=0.9212 val_auc=0.9779  time=68.1s
# Epoch 37/51 summary: train_loss=0.0137 train_acc=0.9962 val_loss=0.2538 val_acc=0.9212 val_auc=0.9779  time=68.1s
# Epoch 38/51 summary: train_loss=0.0173 train_acc=0.9951 val_loss=0.2538 val_acc=0.9212 val_auc=0.9779  time=67.4s
# Epoch 39/51 summary: train_loss=0.0171 train_acc=0.9951 val_loss=0.2539 val_acc=0.9212 val_auc=0.9779  time=65.6s
# Epoch 40/51 summary: train_loss=0.0162 train_acc=0.9958 val_loss=0.2539 val_acc=0.9212 val_auc=0.9779  time=65.1s
# Epoch 41/51 summary: train_loss=0.0164 train_acc=0.9947 val_loss=0.2539 val_acc=0.9212 val_auc=0.9779  time=64.3s
# Epoch 42/51 summary: train_loss=0.0162 train_acc=0.9958 val_loss=0.2541 val_acc=0.9197 val_auc=0.9779  time=64.5s
# Epoch 43/51 summary: train_loss=0.0179 train_acc=0.9951 val_loss=0.2542 val_acc=0.9197 val_auc=0.9779  time=64.2s
# Epoch 44/51 summary: train_loss=0.0146 train_acc=0.9954 val_loss=0.2543 val_acc=0.9197 val_auc=0.9779  time=64.3s
# Epoch 45/51 summary: train_loss=0.0132 train_acc=0.9970 val_loss=0.2543 val_acc=0.9197 val_auc=0.9779  time=64.0s
# Epoch 46/51 summary: train_loss=0.0179 train_acc=0.9947 val_loss=0.2544 val_acc=0.9197 val_auc=0.9779  time=64.2s
# Epoch 47/51 summary: train_loss=0.0238 train_acc=0.9936 val_loss=0.2545 val_acc=0.9212 val_auc=0.9780  time=64.9s
# Epoch 48/51 summary: train_loss=0.0151 train_acc=0.9970 val_loss=0.2546 val_acc=0.9212 val_auc=0.9780  time=64.3s
# Epoch 49/51 summary: train_loss=0.0191 train_acc=0.9951 val_loss=0.2546 val_acc=0.9227 val_auc=0.9779  time=64.8s
# Epoch 50/51 summary: train_loss=0.0199 train_acc=0.9943 val_loss=0.2545 val_acc=0.9212 val_auc=0.9780  time=64.6s
# Epoch 51/51 summary: train_loss=0.0155 train_acc=0.9951 val_loss=0.2544 val_acc=0.9212 val_auc=0.9780  time=64.4s
# Loading best model from: /content/drive/MyDrive/DermaViT224_best.pt
# Final Validation Accuracy: 91.97%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       benign       0.94      0.91      0.93       360
#    malignant       0.90      0.93      0.91       300
#
#     accuracy                           0.92       660
#    macro avg       0.92      0.92      0.92       660
# weighted avg       0.92      0.92      0.92       660
#
# Macro AUC (mean of available class AUCs): 0.9781111111111112
# Saved accuracy plot to: /content/drive/MyDrive/diabetic_eye_results/DermaViT224/DermaViT224_accuracy.png
# Saved loss plot to: /content/drive/MyDrive/diabetic_eye_results/DermaViT224/DermaViT224_loss.png
# Saved confusion matrix to: /content/drive/MyDrive/diabetic_eye_results/DermaViT224/DermaViT224_confusion_matrix.png
# Saved ROC plot to: /content/drive/MyDrive/diabetic_eye_results/DermaViT224/DermaViT224_roc.png
# Saved final model state dict to: /content/drive/MyDrive/DermaViT224_final.pt
