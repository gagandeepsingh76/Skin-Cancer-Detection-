# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/d.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")
# Out:
#  Dataset extracted.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
from tensorflow.keras.applications.efficientnet import preprocess_input

train_dir = "/content/dataset/d/train"
val_dir = "/content/dataset/d/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Found 2637 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

# Load EfficientNetB0 base model without top layers
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze initial layers
for layer in base_model.layers[:100]:
    layer.trainable = False

# Unfreeze remaining layers
for layer in base_model.layers[100:]:
    layer.trainable = True

# Add custom classification head
x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(5, activation='softmax')(x)

# Combine base and top layers
model = Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# ✅ Optimizer — reduce LR for stability
optimizer = SGD(
    learning_rate=0.001,   # safer than 0.1
    momentum=0.9,
    nesterov=True
)

# ✅ Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.build((None, 224, 224, 3))

# ✅ Callbacks
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_resnet152_model.keras",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,    # wait before reducing LR
    verbose=1,
    min_lr=1e-6
)

# 🚀 Training — runs full 51 epochs (no early stopping)
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=51,
    callbacks=[checkpoint, lr_scheduler]   # 👈 no EarlyStopping here
)
# Out:
# Epoch 1/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 672ms/step - accuracy: 0.7893 - loss: 0.4387
# Epoch 1: val_loss improved from inf to 0.38221, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 116s 943ms/step - accuracy: 0.7893 - loss: 0.4387 - val_accuracy: 0.8227 - val_loss: 0.3822 - learning_rate: 0.0010
# Epoch 2/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.8021 - loss: 0.4341
# Epoch 2: val_loss improved from 0.38221 to 0.37388, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 588ms/step - accuracy: 0.8022 - loss: 0.4340 - val_accuracy: 0.8212 - val_loss: 0.3739 - learning_rate: 0.0010
# Epoch 3/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.7939 - loss: 0.4989
# Epoch 3: val_loss improved from 0.37388 to 0.37300, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 582ms/step - accuracy: 0.7939 - loss: 0.4985 - val_accuracy: 0.8258 - val_loss: 0.3730 - learning_rate: 0.0010
# Epoch 4/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.8049 - loss: 0.4205
# Epoch 4: val_loss improved from 0.37300 to 0.36925, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 586ms/step - accuracy: 0.8048 - loss: 0.4207 - val_accuracy: 0.8333 - val_loss: 0.3693 - learning_rate: 0.0010
# Epoch 5/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.8132 - loss: 0.4239
# Epoch 5: val_loss did not improve from 0.36925
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 575ms/step - accuracy: 0.8131 - loss: 0.4241 - val_accuracy: 0.8273 - val_loss: 0.3703 - learning_rate: 0.0010
# Epoch 6/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.7945 - loss: 0.4260
# Epoch 6: val_loss improved from 0.36925 to 0.36221, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 587ms/step - accuracy: 0.7948 - loss: 0.4260 - val_accuracy: 0.8348 - val_loss: 0.3622 - learning_rate: 0.0010
# Epoch 7/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.8100 - loss: 0.4119
# Epoch 7: val_loss did not improve from 0.36221
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 589ms/step - accuracy: 0.8101 - loss: 0.4120 - val_accuracy: 0.8364 - val_loss: 0.3724 - learning_rate: 0.0010
# Epoch 8/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.8139 - loss: 0.4156
# Epoch 8: val_loss did not improve from 0.36221
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 560ms/step - accuracy: 0.8139 - loss: 0.4157 - val_accuracy: 0.8364 - val_loss: 0.3734 - learning_rate: 0.0010
# Epoch 9/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.8146 - loss: 0.4157
# Epoch 9: val_loss did not improve from 0.36221
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 588ms/step - accuracy: 0.8146 - loss: 0.4157 - val_accuracy: 0.8273 - val_loss: 0.3874 - learning_rate: 0.0010
# Epoch 10/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.8077 - loss: 0.4385
# Epoch 10: val_loss did not improve from 0.36221
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 567ms/step - accuracy: 0.8078 - loss: 0.4382 - val_accuracy: 0.8318 - val_loss: 0.3730 - learning_rate: 3.0000e-04
# Epoch 11/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.8132 - loss: 0.4173
# Epoch 11: val_loss improved from 0.36221 to 0.35717, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 589ms/step - accuracy: 0.8132 - loss: 0.4173 - val_accuracy: 0.8470 - val_loss: 0.3572 - learning_rate: 3.0000e-04
# Epoch 12/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.8055 - loss: 0.4053
# Epoch 12: val_loss improved from 0.35717 to 0.35402, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 81s 577ms/step - accuracy: 0.8054 - loss: 0.4056 - val_accuracy: 0.8303 - val_loss: 0.3540 - learning_rate: 3.0000e-04
# Epoch 13/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.8191 - loss: 0.4295
# Epoch 13: val_loss did not improve from 0.35402
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 603ms/step - accuracy: 0.8189 - loss: 0.4294 - val_accuracy: 0.8288 - val_loss: 0.3579 - learning_rate: 3.0000e-04
# Epoch 14/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.8056 - loss: 0.4206
# Epoch 14: val_loss did not improve from 0.35402
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 593ms/step - accuracy: 0.8056 - loss: 0.4206 - val_accuracy: 0.8303 - val_loss: 0.3753 - learning_rate: 3.0000e-04
# Epoch 15/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - accuracy: 0.7939 - loss: 0.4536
# Epoch 15: val_loss improved from 0.35402 to 0.35100, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 609ms/step - accuracy: 0.7941 - loss: 0.4534 - val_accuracy: 0.8364 - val_loss: 0.3510 - learning_rate: 3.0000e-04
# Epoch 16/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.8026 - loss: 0.4199
# Epoch 16: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 80s 588ms/step - accuracy: 0.8027 - loss: 0.4198 - val_accuracy: 0.8379 - val_loss: 0.3731 - learning_rate: 3.0000e-04
# Epoch 17/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.8142 - loss: 0.3939
# Epoch 17: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 593ms/step - accuracy: 0.8142 - loss: 0.3942 - val_accuracy: 0.8348 - val_loss: 0.3586 - learning_rate: 3.0000e-04
# Epoch 18/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.8213 - loss: 0.4112
# Epoch 18: val_loss did not improve from 0.35100
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 567ms/step - accuracy: 0.8212 - loss: 0.4113 - val_accuracy: 0.8318 - val_loss: 0.3574 - learning_rate: 3.0000e-04
# Epoch 19/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.8141 - loss: 0.4195
# Epoch 19: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 582ms/step - accuracy: 0.8140 - loss: 0.4194 - val_accuracy: 0.8379 - val_loss: 0.3616 - learning_rate: 9.0000e-05
# Epoch 20/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - accuracy: 0.8230 - loss: 0.3806
# Epoch 20: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 602ms/step - accuracy: 0.8229 - loss: 0.3807 - val_accuracy: 0.8364 - val_loss: 0.3590 - learning_rate: 9.0000e-05
# Epoch 21/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.8111 - loss: 0.4066
# Epoch 21: val_loss did not improve from 0.35100
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 608ms/step - accuracy: 0.8110 - loss: 0.4066 - val_accuracy: 0.8273 - val_loss: 0.3781 - learning_rate: 9.0000e-05
# Epoch 22/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - accuracy: 0.8212 - loss: 0.4193
# Epoch 22: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 600ms/step - accuracy: 0.8211 - loss: 0.4193 - val_accuracy: 0.8318 - val_loss: 0.3547 - learning_rate: 2.7000e-05
# Epoch 23/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.8219 - loss: 0.4137
# Epoch 23: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 585ms/step - accuracy: 0.8218 - loss: 0.4136 - val_accuracy: 0.8273 - val_loss: 0.3639 - learning_rate: 2.7000e-05
# Epoch 24/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.8196 - loss: 0.3836
# Epoch 24: val_loss did not improve from 0.35100
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 51s 612ms/step - accuracy: 0.8195 - loss: 0.3838 - val_accuracy: 0.8409 - val_loss: 0.3892 - learning_rate: 2.7000e-05
# Epoch 25/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.8209 - loss: 0.3919
# Epoch 25: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 605ms/step - accuracy: 0.8210 - loss: 0.3920 - val_accuracy: 0.8348 - val_loss: 0.3638 - learning_rate: 8.1000e-06
# Epoch 26/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.8085 - loss: 0.4228
# Epoch 26: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 606ms/step - accuracy: 0.8085 - loss: 0.4227 - val_accuracy: 0.8364 - val_loss: 0.3609 - learning_rate: 8.1000e-06
# Epoch 27/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - accuracy: 0.8078 - loss: 0.4194
# Epoch 27: val_loss did not improve from 0.35100
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 81s 598ms/step - accuracy: 0.8076 - loss: 0.4195 - val_accuracy: 0.8394 - val_loss: 0.3717 - learning_rate: 8.1000e-06
# Epoch 28/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.8073 - loss: 0.4144
# Epoch 28: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 603ms/step - accuracy: 0.8073 - loss: 0.4144 - val_accuracy: 0.8470 - val_loss: 0.3690 - learning_rate: 2.4300e-06
# Epoch 29/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.8016 - loss: 0.4131
# Epoch 29: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 580ms/step - accuracy: 0.8017 - loss: 0.4132 - val_accuracy: 0.8409 - val_loss: 0.3582 - learning_rate: 2.4300e-06
# Epoch 30/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.8149 - loss: 0.4391
# Epoch 30: val_loss did not improve from 0.35100
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 591ms/step - accuracy: 0.8149 - loss: 0.4389 - val_accuracy: 0.8318 - val_loss: 0.3563 - learning_rate: 2.4300e-06
# Epoch 31/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.8092 - loss: 0.4418
# Epoch 31: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 585ms/step - accuracy: 0.8092 - loss: 0.4415 - val_accuracy: 0.8364 - val_loss: 0.3573 - learning_rate: 1.0000e-06
# Epoch 32/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.8177 - loss: 0.4082
# Epoch 32: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 595ms/step - accuracy: 0.8177 - loss: 0.4082 - val_accuracy: 0.8303 - val_loss: 0.3595 - learning_rate: 1.0000e-06
# Epoch 33/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.8166 - loss: 0.4024
# Epoch 33: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 589ms/step - accuracy: 0.8165 - loss: 0.4024 - val_accuracy: 0.8379 - val_loss: 0.3661 - learning_rate: 1.0000e-06
# Epoch 34/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.8085 - loss: 0.4406
# Epoch 34: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 572ms/step - accuracy: 0.8085 - loss: 0.4405 - val_accuracy: 0.8379 - val_loss: 0.3847 - learning_rate: 1.0000e-06
# Epoch 35/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.7980 - loss: 0.4394
# Epoch 35: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 589ms/step - accuracy: 0.7981 - loss: 0.4390 - val_accuracy: 0.8318 - val_loss: 0.3611 - learning_rate: 1.0000e-06
# Epoch 36/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - accuracy: 0.8124 - loss: 0.4221
# Epoch 36: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 603ms/step - accuracy: 0.8124 - loss: 0.4220 - val_accuracy: 0.8348 - val_loss: 0.3669 - learning_rate: 1.0000e-06
# Epoch 37/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.8084 - loss: 0.4223
# Epoch 37: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 578ms/step - accuracy: 0.8083 - loss: 0.4222 - val_accuracy: 0.8348 - val_loss: 0.3829 - learning_rate: 1.0000e-06
# Epoch 38/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.8052 - loss: 0.4065
# Epoch 38: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 595ms/step - accuracy: 0.8052 - loss: 0.4065 - val_accuracy: 0.8303 - val_loss: 0.3748 - learning_rate: 1.0000e-06
# Epoch 39/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.8056 - loss: 0.4279
# Epoch 39: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 601ms/step - accuracy: 0.8057 - loss: 0.4278 - val_accuracy: 0.8303 - val_loss: 0.3687 - learning_rate: 1.0000e-06
# Epoch 40/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.8128 - loss: 0.4276
# Epoch 40: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 573ms/step - accuracy: 0.8128 - loss: 0.4275 - val_accuracy: 0.8348 - val_loss: 0.3626 - learning_rate: 1.0000e-06
# Epoch 41/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.7896 - loss: 0.4513
# Epoch 41: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 577ms/step - accuracy: 0.7897 - loss: 0.4509 - val_accuracy: 0.8424 - val_loss: 0.3526 - learning_rate: 1.0000e-06
# Epoch 42/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.8160 - loss: 0.4001
# Epoch 42: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 568ms/step - accuracy: 0.8160 - loss: 0.4000 - val_accuracy: 0.8288 - val_loss: 0.3663 - learning_rate: 1.0000e-06
# Epoch 43/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.8086 - loss: 0.3892
# Epoch 43: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 587ms/step - accuracy: 0.8086 - loss: 0.3895 - val_accuracy: 0.8364 - val_loss: 0.3736 - learning_rate: 1.0000e-06
# Epoch 44/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.8141 - loss: 0.4109
# Epoch 44: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 596ms/step - accuracy: 0.8141 - loss: 0.4109 - val_accuracy: 0.8439 - val_loss: 0.3659 - learning_rate: 1.0000e-06
# Epoch 45/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.8091 - loss: 0.4318
# Epoch 45: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 578ms/step - accuracy: 0.8091 - loss: 0.4317 - val_accuracy: 0.8197 - val_loss: 0.3727 - learning_rate: 1.0000e-06
# Epoch 46/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.8195 - loss: 0.3921
# Epoch 46: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 596ms/step - accuracy: 0.8194 - loss: 0.3922 - val_accuracy: 0.8424 - val_loss: 0.3604 - learning_rate: 1.0000e-06
# Epoch 47/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.8055 - loss: 0.4187
# Epoch 47: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 587ms/step - accuracy: 0.8055 - loss: 0.4187 - val_accuracy: 0.8409 - val_loss: 0.3555 - learning_rate: 1.0000e-06
# Epoch 48/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.8235 - loss: 0.3950
# Epoch 48: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 573ms/step - accuracy: 0.8234 - loss: 0.3952 - val_accuracy: 0.8424 - val_loss: 0.3694 - learning_rate: 1.0000e-06
# Epoch 49/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.8144 - loss: 0.4174
# Epoch 49: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 585ms/step - accuracy: 0.8143 - loss: 0.4175 - val_accuracy: 0.8348 - val_loss: 0.3689 - learning_rate: 1.0000e-06
# Epoch 50/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - accuracy: 0.8097 - loss: 0.3980
# Epoch 50: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 598ms/step - accuracy: 0.8097 - loss: 0.3981 - val_accuracy: 0.8364 - val_loss: 0.3678 - learning_rate: 1.0000e-06
# Epoch 51/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.7986 - loss: 0.4324
# Epoch 51: val_loss did not improve from 0.35100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 570ms/step - accuracy: 0.7987 - loss: 0.4322 - val_accuracy: 0.8288 - val_loss: 0.3661 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained ResNet152 model ===
model_path = "/content/drive/MyDrive/best_resnet152_model.keras"
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))
# Out:
# ✅ Model loaded from: /content/drive/MyDrive/best_resnet152_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 24s 759ms/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1]
# Valid labels: [0, 1]
# Target names: ['benign', 'malignant']
#
# Predicted sample count per class:
# benign: 314
# malignant: 346
#
# ✅ Overall Validation Accuracy: 82.73%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       benign       0.89      0.78      0.83       360
#    malignant       0.77      0.89      0.82       300
#
#     accuracy                           0.83       660
#    macro avg       0.83      0.83      0.83       660
# weighted avg       0.84      0.83      0.83       660

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
# y_true: true labels (e.g., [0, 2, 1, 4, ...]), shape = (n_samples,)
# pred_probs: predicted probabilities, shape = (n_samples, n_classes)
# labels: class names (optional, replace with your own)
# graph_dir: directory where to save plot

n_classes = 5
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = "./plots"

# Ensure output directory exists
os.makedirs(graph_dir, exist_ok=True)

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")
# Out:
# ⚠️ Skipping ROC curve for Class 2 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 3 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 4 — no positive samples in y_true.
# Skipped ROC for classes with no positive samples: Class 2, Class 3, Class 4
# ✅ ROC curve saved to: ./plots/roc_curve.png

# %%
model.save("/content/drive/MyDrive/final_resnet152_model.keras")
