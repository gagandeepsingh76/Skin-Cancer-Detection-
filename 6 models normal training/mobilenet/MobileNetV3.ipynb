# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/d.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")
# Out:
#  Dataset extracted.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input

train_dir = "/content/dataset/d/train"
val_dir = "/content/dataset/d/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Found 2637 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

base_model = MobileNetV3Large(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

# Freeze initial layers (adjust index based on MobileNetV3 architecture depth)
for layer in base_model.layers[:150]:  # MobileNetV3Large has ~270 layers
    layer.trainable = False

# Unfreeze later layers for fine-tuning
for layer in base_model.layers[150:]:
    layer.trainable = True

x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(5, activation='softmax')(x)  # Replace 5 with your actual number of classes if needed

model = Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
from tensorflow.keras.optimizers import Nadam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Define optimizer
optimizer = Nadam(learning_rate=1e-4)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Optional: build the model (only needed if model has not been fit before)
model.build((None, 224, 224, 3))

# Callbacks — updated checkpoint filename
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_mobilenetv3large_model.keras",  # Updated filename
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# Fit the model for 51 epochs (no EarlyStopping)
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=51,
    callbacks=[checkpoint, lr_scheduler]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 647ms/step - accuracy: 0.3367 - loss: 1.8646
# Epoch 1: val_loss improved from inf to 1.42404, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 111s 970ms/step - accuracy: 0.3379 - loss: 1.8616 - val_accuracy: 0.3682 - val_loss: 1.4240 - learning_rate: 1.0000e-04
# Epoch 2/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.6298 - loss: 1.1139
# Epoch 2: val_loss improved from 1.42404 to 1.16121, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 593ms/step - accuracy: 0.6303 - loss: 1.1131 - val_accuracy: 0.6455 - val_loss: 1.1612 - learning_rate: 1.0000e-04
# Epoch 3/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.7563 - loss: 0.8113
# Epoch 3: val_loss did not improve from 1.16121
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 568ms/step - accuracy: 0.7565 - loss: 0.8109 - val_accuracy: 0.6621 - val_loss: 1.2451 - learning_rate: 1.0000e-04
# Epoch 4/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.8009 - loss: 0.6957
# Epoch 4: val_loss did not improve from 1.16121
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 572ms/step - accuracy: 0.8012 - loss: 0.6948 - val_accuracy: 0.6606 - val_loss: 1.3816 - learning_rate: 1.0000e-04
# Epoch 5/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.8401 - loss: 0.5364
# Epoch 5: val_loss did not improve from 1.16121
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 551ms/step - accuracy: 0.8402 - loss: 0.5363 - val_accuracy: 0.6788 - val_loss: 1.2333 - learning_rate: 3.0000e-05
# Epoch 6/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.8484 - loss: 0.5129
# Epoch 6: val_loss improved from 1.16121 to 1.13157, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 580ms/step - accuracy: 0.8485 - loss: 0.5126 - val_accuracy: 0.6909 - val_loss: 1.1316 - learning_rate: 3.0000e-05
# Epoch 7/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step - accuracy: 0.8570 - loss: 0.4881
# Epoch 7: val_loss improved from 1.13157 to 1.02529, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 577ms/step - accuracy: 0.8570 - loss: 0.4879 - val_accuracy: 0.7121 - val_loss: 1.0253 - learning_rate: 3.0000e-05
# Epoch 8/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.8724 - loss: 0.4388
# Epoch 8: val_loss improved from 1.02529 to 0.93920, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 597ms/step - accuracy: 0.8724 - loss: 0.4387 - val_accuracy: 0.7197 - val_loss: 0.9392 - learning_rate: 3.0000e-05
# Epoch 9/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.8826 - loss: 0.3861
# Epoch 9: val_loss improved from 0.93920 to 0.79767, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 574ms/step - accuracy: 0.8826 - loss: 0.3864 - val_accuracy: 0.7515 - val_loss: 0.7977 - learning_rate: 3.0000e-05
# Epoch 10/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.8857 - loss: 0.3893
# Epoch 10: val_loss improved from 0.79767 to 0.69732, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 582ms/step - accuracy: 0.8857 - loss: 0.3894 - val_accuracy: 0.7833 - val_loss: 0.6973 - learning_rate: 3.0000e-05
# Epoch 11/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.8857 - loss: 0.3953
# Epoch 11: val_loss improved from 0.69732 to 0.66687, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 81s 576ms/step - accuracy: 0.8857 - loss: 0.3950 - val_accuracy: 0.7879 - val_loss: 0.6669 - learning_rate: 3.0000e-05
# Epoch 12/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.8780 - loss: 0.3965
# Epoch 12: val_loss improved from 0.66687 to 0.63268, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 591ms/step - accuracy: 0.8780 - loss: 0.3964 - val_accuracy: 0.8045 - val_loss: 0.6327 - learning_rate: 3.0000e-05
# Epoch 13/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.8828 - loss: 0.3708
# Epoch 13: val_loss improved from 0.63268 to 0.56669, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 576ms/step - accuracy: 0.8829 - loss: 0.3708 - val_accuracy: 0.8242 - val_loss: 0.5667 - learning_rate: 3.0000e-05
# Epoch 14/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.8915 - loss: 0.3432
# Epoch 14: val_loss improved from 0.56669 to 0.55462, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 597ms/step - accuracy: 0.8915 - loss: 0.3432 - val_accuracy: 0.8273 - val_loss: 0.5546 - learning_rate: 3.0000e-05
# Epoch 15/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.8863 - loss: 0.3355
# Epoch 15: val_loss improved from 0.55462 to 0.51186, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 600ms/step - accuracy: 0.8863 - loss: 0.3355 - val_accuracy: 0.8303 - val_loss: 0.5119 - learning_rate: 3.0000e-05
# Epoch 16/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.8979 - loss: 0.3165
# Epoch 16: val_loss improved from 0.51186 to 0.43270, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 579ms/step - accuracy: 0.8979 - loss: 0.3165 - val_accuracy: 0.8379 - val_loss: 0.4327 - learning_rate: 3.0000e-05
# Epoch 17/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.8948 - loss: 0.3153
# Epoch 17: val_loss improved from 0.43270 to 0.42427, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 599ms/step - accuracy: 0.8948 - loss: 0.3154 - val_accuracy: 0.8455 - val_loss: 0.4243 - learning_rate: 3.0000e-05
# Epoch 18/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.9063 - loss: 0.2993
# Epoch 18: val_loss did not improve from 0.42427
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 599ms/step - accuracy: 0.9063 - loss: 0.2994 - val_accuracy: 0.8455 - val_loss: 0.4503 - learning_rate: 3.0000e-05
# Epoch 19/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.9122 - loss: 0.2854
# Epoch 19: val_loss improved from 0.42427 to 0.40496, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 575ms/step - accuracy: 0.9122 - loss: 0.2853 - val_accuracy: 0.8561 - val_loss: 0.4050 - learning_rate: 3.0000e-05
# Epoch 20/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.9010 - loss: 0.2888
# Epoch 20: val_loss improved from 0.40496 to 0.37092, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 598ms/step - accuracy: 0.9010 - loss: 0.2888 - val_accuracy: 0.8606 - val_loss: 0.3709 - learning_rate: 3.0000e-05
# Epoch 21/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.9051 - loss: 0.2993
# Epoch 21: val_loss did not improve from 0.37092
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 572ms/step - accuracy: 0.9052 - loss: 0.2990 - val_accuracy: 0.8652 - val_loss: 0.3745 - learning_rate: 3.0000e-05
# Epoch 22/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.8999 - loss: 0.2674
# Epoch 22: val_loss did not improve from 0.37092
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 581ms/step - accuracy: 0.8999 - loss: 0.2676 - val_accuracy: 0.8591 - val_loss: 0.3717 - learning_rate: 3.0000e-05
# Epoch 23/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.9152 - loss: 0.2484
# Epoch 23: val_loss did not improve from 0.37092
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 559ms/step - accuracy: 0.9152 - loss: 0.2483 - val_accuracy: 0.8530 - val_loss: 0.3848 - learning_rate: 9.0000e-06
# Epoch 24/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.9230 - loss: 0.2187
# Epoch 24: val_loss did not improve from 0.37092
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 590ms/step - accuracy: 0.9229 - loss: 0.2189 - val_accuracy: 0.8652 - val_loss: 0.3868 - learning_rate: 9.0000e-06
# Epoch 25/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.9156 - loss: 0.2443
# Epoch 25: val_loss improved from 0.37092 to 0.34473, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 569ms/step - accuracy: 0.9156 - loss: 0.2444 - val_accuracy: 0.8712 - val_loss: 0.3447 - learning_rate: 2.7000e-06
# Epoch 26/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.9286 - loss: 0.2197
# Epoch 26: val_loss did not improve from 0.34473
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 582ms/step - accuracy: 0.9285 - loss: 0.2198 - val_accuracy: 0.8742 - val_loss: 0.3648 - learning_rate: 2.7000e-06
# Epoch 27/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.9199 - loss: 0.2237
# Epoch 27: val_loss did not improve from 0.34473
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 564ms/step - accuracy: 0.9199 - loss: 0.2239 - val_accuracy: 0.8712 - val_loss: 0.3607 - learning_rate: 2.7000e-06
# Epoch 28/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.9136 - loss: 0.2651
# Epoch 28: val_loss improved from 0.34473 to 0.32251, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 590ms/step - accuracy: 0.9137 - loss: 0.2649 - val_accuracy: 0.8818 - val_loss: 0.3225 - learning_rate: 1.0000e-06
# Epoch 29/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.9171 - loss: 0.2474
# Epoch 29: val_loss did not improve from 0.32251
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 597ms/step - accuracy: 0.9170 - loss: 0.2476 - val_accuracy: 0.8667 - val_loss: 0.3393 - learning_rate: 1.0000e-06
# Epoch 30/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.9264 - loss: 0.2414
# Epoch 30: val_loss did not improve from 0.32251
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 570ms/step - accuracy: 0.9264 - loss: 0.2415 - val_accuracy: 0.8682 - val_loss: 0.3489 - learning_rate: 1.0000e-06
# Epoch 31/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.9196 - loss: 0.2563
# Epoch 31: val_loss improved from 0.32251 to 0.31378, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 592ms/step - accuracy: 0.9196 - loss: 0.2562 - val_accuracy: 0.8818 - val_loss: 0.3138 - learning_rate: 1.0000e-06
# Epoch 32/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.9167 - loss: 0.2468
# Epoch 32: val_loss did not improve from 0.31378
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 590ms/step - accuracy: 0.9167 - loss: 0.2467 - val_accuracy: 0.8818 - val_loss: 0.3188 - learning_rate: 1.0000e-06
# Epoch 33/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.9186 - loss: 0.2350
# Epoch 33: val_loss did not improve from 0.31378
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 586ms/step - accuracy: 0.9187 - loss: 0.2351 - val_accuracy: 0.8758 - val_loss: 0.3353 - learning_rate: 1.0000e-06
# Epoch 34/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.9158 - loss: 0.2415
# Epoch 34: val_loss did not improve from 0.31378
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 584ms/step - accuracy: 0.9158 - loss: 0.2415 - val_accuracy: 0.8818 - val_loss: 0.3423 - learning_rate: 1.0000e-06
# Epoch 35/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.9160 - loss: 0.2455
# Epoch 35: val_loss improved from 0.31378 to 0.30375, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 568ms/step - accuracy: 0.9161 - loss: 0.2454 - val_accuracy: 0.8864 - val_loss: 0.3038 - learning_rate: 1.0000e-06
# Epoch 36/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.9187 - loss: 0.2430
# Epoch 36: val_loss improved from 0.30375 to 0.30171, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 595ms/step - accuracy: 0.9187 - loss: 0.2431 - val_accuracy: 0.8848 - val_loss: 0.3017 - learning_rate: 1.0000e-06
# Epoch 37/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.9271 - loss: 0.2299
# Epoch 37: val_loss did not improve from 0.30171
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 569ms/step - accuracy: 0.9271 - loss: 0.2299 - val_accuracy: 0.8621 - val_loss: 0.3606 - learning_rate: 1.0000e-06
# Epoch 38/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.9253 - loss: 0.2349
# Epoch 38: val_loss did not improve from 0.30171
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 589ms/step - accuracy: 0.9254 - loss: 0.2348 - val_accuracy: 0.8788 - val_loss: 0.3052 - learning_rate: 1.0000e-06
# Epoch 39/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.9168 - loss: 0.2289
# Epoch 39: val_loss did not improve from 0.30171
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 567ms/step - accuracy: 0.9168 - loss: 0.2291 - val_accuracy: 0.8909 - val_loss: 0.3052 - learning_rate: 1.0000e-06
# Epoch 40/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.9247 - loss: 0.2533
# Epoch 40: val_loss did not improve from 0.30171
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 585ms/step - accuracy: 0.9247 - loss: 0.2532 - val_accuracy: 0.8909 - val_loss: 0.3039 - learning_rate: 1.0000e-06
# Epoch 41/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.9236 - loss: 0.2485
# Epoch 41: val_loss did not improve from 0.30171
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 46s 562ms/step - accuracy: 0.9237 - loss: 0.2484 - val_accuracy: 0.8697 - val_loss: 0.3170 - learning_rate: 1.0000e-06
# Epoch 42/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.9242 - loss: 0.2292
# Epoch 42: val_loss did not improve from 0.30171
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 587ms/step - accuracy: 0.9242 - loss: 0.2293 - val_accuracy: 0.8636 - val_loss: 0.3435 - learning_rate: 1.0000e-06
# Epoch 43/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.9290 - loss: 0.2235
# Epoch 43: val_loss did not improve from 0.30171
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 574ms/step - accuracy: 0.9290 - loss: 0.2236 - val_accuracy: 0.8894 - val_loss: 0.3165 - learning_rate: 1.0000e-06
# Epoch 44/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.9232 - loss: 0.2243
# Epoch 44: val_loss improved from 0.30171 to 0.29697, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 582ms/step - accuracy: 0.9231 - loss: 0.2245 - val_accuracy: 0.8955 - val_loss: 0.2970 - learning_rate: 1.0000e-06
# Epoch 45/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.9161 - loss: 0.2346
# Epoch 45: val_loss did not improve from 0.29697
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 596ms/step - accuracy: 0.9162 - loss: 0.2344 - val_accuracy: 0.8742 - val_loss: 0.3445 - learning_rate: 1.0000e-06
# Epoch 46/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.9148 - loss: 0.2748
# Epoch 46: val_loss did not improve from 0.29697
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 565ms/step - accuracy: 0.9149 - loss: 0.2745 - val_accuracy: 0.8773 - val_loss: 0.3324 - learning_rate: 1.0000e-06
# Epoch 47/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.9119 - loss: 0.2834
# Epoch 47: val_loss improved from 0.29697 to 0.29045, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 591ms/step - accuracy: 0.9120 - loss: 0.2831 - val_accuracy: 0.8879 - val_loss: 0.2904 - learning_rate: 1.0000e-06
# Epoch 48/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.9276 - loss: 0.2280
# Epoch 48: val_loss did not improve from 0.29045
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 48s 576ms/step - accuracy: 0.9275 - loss: 0.2281 - val_accuracy: 0.8833 - val_loss: 0.3127 - learning_rate: 1.0000e-06
# Epoch 49/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.9321 - loss: 0.2192
# Epoch 49: val_loss improved from 0.29045 to 0.27864, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 598ms/step - accuracy: 0.9319 - loss: 0.2194 - val_accuracy: 0.9000 - val_loss: 0.2786 - learning_rate: 1.0000e-06
# Epoch 50/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.9245 - loss: 0.2396
# Epoch 50: val_loss did not improve from 0.27864
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 49s 595ms/step - accuracy: 0.9245 - loss: 0.2394 - val_accuracy: 0.8818 - val_loss: 0.3087 - learning_rate: 1.0000e-06
# Epoch 51/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9083 - loss: 0.2387
# Epoch 51: val_loss did not improve from 0.27864
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 47s 570ms/step - accuracy: 0.9084 - loss: 0.2387 - val_accuracy: 0.8758 - val_loss: 0.3158 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained MobileNetV3Large model ===
model_path = "/content/drive/MyDrive/best_mobilenetv3large_model.keras"  # Updated path
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))
# Out:
# ✅ Model loaded from: /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 19s 685ms/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1]
# Valid labels: [0, 1]
# Target names: ['benign', 'malignant']
#
# Predicted sample count per class:
# benign: 365
# malignant: 295
#
# ✅ Overall Validation Accuracy: 88.33%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       benign       0.89      0.90      0.89       360
#    malignant       0.88      0.86      0.87       300
#
#     accuracy                           0.88       660
#    macro avg       0.88      0.88      0.88       660
# weighted avg       0.88      0.88      0.88       660

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
# y_true: true labels (e.g., [0, 2, 1, 4, ...]), shape = (n_samples,)
# pred_probs: predicted probabilities, shape = (n_samples, n_classes)
# labels: class names (optional, replace with your own)
# graph_dir: directory where to save plot

n_classes = 5
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = "./plots"

# Ensure output directory exists
os.makedirs(graph_dir, exist_ok=True)

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")
# Out:
# ⚠️ Skipping ROC curve for Class 2 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 3 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 4 — no positive samples in y_true.
# Skipped ROC for classes with no positive samples: Class 2, Class 3, Class 4
# ✅ ROC curve saved to: ./plots/roc_curve.png

# %%
model.save("/content/drive/MyDrive/final_resnet152_model.keras")
