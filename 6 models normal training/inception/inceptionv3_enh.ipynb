# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/d.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")
# Out:
#  Dataset extracted.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3  # 🔄 Changed from ResNet152 to InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
train_dir = "/content/dataset/d/train"
val_dir = "/content/dataset/d/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator


# === Data generators ===
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

# === Load image data ===
train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(299, 299),  # ✅ Required input size for InceptionV3
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(299, 299),  # ✅ Required input size for InceptionV3
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Found 2637 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import InceptionV3  # 🔄 Changed from ResNet152
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

# Load InceptionV3 as base model
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))  # 🔄 Updated input size

# Freeze initial layers
for layer in base_model.layers[:200]:  # 🔄 InceptionV3 has fewer layers than ResNet152
    layer.trainable = False

# Unfreeze later layers
for layer in base_model.layers[200:]:
    layer.trainable = True

# Add custom classification head
x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(5, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Define optimizer
optimizer = SGD(learning_rate=0.01,momentum=0.9,nesterov=True)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# ✅ Updated input shape for InceptionV3
model.build((None, 299, 299, 3))

# ✅ Updated checkpoint filename to reflect InceptionV3
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_inceptionv3_model.keras",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# Train the model
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=51,
    callbacks=[checkpoint, lr_scheduler]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 936ms/step - accuracy: 0.6747 - loss: 1.0373
# Epoch 1: val_loss improved from inf to 0.91147, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 134s 1s/step - accuracy: 0.6759 - loss: 1.0331 - val_accuracy: 0.7530 - val_loss: 0.9115 - learning_rate: 0.0100
# Epoch 2/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 817ms/step - accuracy: 0.8307 - loss: 0.4066
# Epoch 2: val_loss improved from 0.91147 to 0.36842, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 107s 1s/step - accuracy: 0.8309 - loss: 0.4062 - val_accuracy: 0.8470 - val_loss: 0.3684 - learning_rate: 0.0100
# Epoch 3/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 819ms/step - accuracy: 0.8503 - loss: 0.3418
# Epoch 3: val_loss improved from 0.36842 to 0.33459, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - accuracy: 0.8504 - loss: 0.3417 - val_accuracy: 0.8500 - val_loss: 0.3346 - learning_rate: 0.0100
# Epoch 4/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 844ms/step - accuracy: 0.8623 - loss: 0.3074
# Epoch 4: val_loss improved from 0.33459 to 0.30863, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.8624 - loss: 0.3072 - val_accuracy: 0.8576 - val_loss: 0.3086 - learning_rate: 0.0100
# Epoch 5/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 846ms/step - accuracy: 0.8804 - loss: 0.2844
# Epoch 5: val_loss improved from 0.30863 to 0.28792, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.8804 - loss: 0.2842 - val_accuracy: 0.8591 - val_loss: 0.2879 - learning_rate: 0.0100
# Epoch 6/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 814ms/step - accuracy: 0.8774 - loss: 0.2407
# Epoch 6: val_loss improved from 0.28792 to 0.28398, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 0.8774 - loss: 0.2409 - val_accuracy: 0.8667 - val_loss: 0.2840 - learning_rate: 0.0100
# Epoch 7/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 854ms/step - accuracy: 0.8986 - loss: 0.2374
# Epoch 7: val_loss did not improve from 0.28398
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.8985 - loss: 0.2376 - val_accuracy: 0.8500 - val_loss: 0.3697 - learning_rate: 0.0100
# Epoch 8/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 818ms/step - accuracy: 0.8952 - loss: 0.2219
# Epoch 8: val_loss did not improve from 0.28398
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0029999999329447745.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.8953 - loss: 0.2219 - val_accuracy: 0.8212 - val_loss: 0.4448 - learning_rate: 0.0100
# Epoch 9/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 819ms/step - accuracy: 0.9185 - loss: 0.1942
# Epoch 9: val_loss did not improve from 0.28398
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.9185 - loss: 0.1942 - val_accuracy: 0.8758 - val_loss: 0.2887 - learning_rate: 0.0030
# Epoch 10/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 828ms/step - accuracy: 0.9082 - loss: 0.1992
# Epoch 10: val_loss did not improve from 0.28398
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0009000000078231095.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - accuracy: 0.9082 - loss: 0.1992 - val_accuracy: 0.8652 - val_loss: 0.2907 - learning_rate: 0.0030
# Epoch 11/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.9227 - loss: 0.1771
# Epoch 11: val_loss improved from 0.28398 to 0.27003, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.9227 - loss: 0.1771 - val_accuracy: 0.8894 - val_loss: 0.2700 - learning_rate: 9.0000e-04
# Epoch 12/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 809ms/step - accuracy: 0.9233 - loss: 0.1669
# Epoch 12: val_loss did not improve from 0.27003
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.9234 - loss: 0.1668 - val_accuracy: 0.8727 - val_loss: 0.2873 - learning_rate: 9.0000e-04
# Epoch 13/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.9403 - loss: 0.1505
# Epoch 13: val_loss did not improve from 0.27003
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00026999999536201356.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9402 - loss: 0.1506 - val_accuracy: 0.8712 - val_loss: 0.2997 - learning_rate: 9.0000e-04
# Epoch 14/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 813ms/step - accuracy: 0.9404 - loss: 0.1476
# Epoch 14: val_loss did not improve from 0.27003
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9403 - loss: 0.1478 - val_accuracy: 0.8652 - val_loss: 0.2998 - learning_rate: 2.7000e-04
# Epoch 15/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 816ms/step - accuracy: 0.9281 - loss: 0.1663
# Epoch 15: val_loss did not improve from 0.27003
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 8.099999686237424e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9281 - loss: 0.1664 - val_accuracy: 0.8742 - val_loss: 0.2840 - learning_rate: 2.7000e-04
# Epoch 16/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.9412 - loss: 0.1402
# Epoch 16: val_loss did not improve from 0.27003
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9412 - loss: 0.1404 - val_accuracy: 0.8636 - val_loss: 0.3060 - learning_rate: 8.1000e-05
# Epoch 17/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 822ms/step - accuracy: 0.9364 - loss: 0.1542
# Epoch 17: val_loss improved from 0.27003 to 0.26549, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.9364 - loss: 0.1540 - val_accuracy: 0.8833 - val_loss: 0.2655 - learning_rate: 8.1000e-05
# Epoch 18/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 854ms/step - accuracy: 0.9408 - loss: 0.1384
# Epoch 18: val_loss did not improve from 0.26549
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.9408 - loss: 0.1384 - val_accuracy: 0.8788 - val_loss: 0.2765 - learning_rate: 8.1000e-05
# Epoch 19/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 825ms/step - accuracy: 0.9320 - loss: 0.1664
# Epoch 19: val_loss did not improve from 0.26549
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.9320 - loss: 0.1664 - val_accuracy: 0.8727 - val_loss: 0.2905 - learning_rate: 8.1000e-05
# Epoch 20/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 828ms/step - accuracy: 0.9286 - loss: 0.1647
# Epoch 20: val_loss did not improve from 0.26549
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - accuracy: 0.9286 - loss: 0.1645 - val_accuracy: 0.8742 - val_loss: 0.3131 - learning_rate: 2.4300e-05
# Epoch 21/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 826ms/step - accuracy: 0.9299 - loss: 0.1473
# Epoch 21: val_loss did not improve from 0.26549
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 7.289999848580919e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.9299 - loss: 0.1474 - val_accuracy: 0.8848 - val_loss: 0.2854 - learning_rate: 2.4300e-05
# Epoch 22/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 822ms/step - accuracy: 0.9400 - loss: 0.1289
# Epoch 22: val_loss did not improve from 0.26549
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9399 - loss: 0.1291 - val_accuracy: 0.8727 - val_loss: 0.2791 - learning_rate: 7.2900e-06
# Epoch 23/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 810ms/step - accuracy: 0.9410 - loss: 0.1354
# Epoch 23: val_loss did not improve from 0.26549
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 2.186999927289435e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9410 - loss: 0.1355 - val_accuracy: 0.8803 - val_loss: 0.2760 - learning_rate: 7.2900e-06
# Epoch 24/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 808ms/step - accuracy: 0.9260 - loss: 0.1800
# Epoch 24: val_loss did not improve from 0.26549
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.9261 - loss: 0.1798 - val_accuracy: 0.8727 - val_loss: 0.3073 - learning_rate: 2.1870e-06
# Epoch 25/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.9287 - loss: 0.1671
# Epoch 25: val_loss did not improve from 0.26549
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.9287 - loss: 0.1671 - val_accuracy: 0.8742 - val_loss: 0.2785 - learning_rate: 2.1870e-06
# Epoch 26/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 810ms/step - accuracy: 0.9290 - loss: 0.1723
# Epoch 26: val_loss improved from 0.26549 to 0.26195, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.9291 - loss: 0.1722 - val_accuracy: 0.8864 - val_loss: 0.2619 - learning_rate: 1.0000e-06
# Epoch 27/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.9269 - loss: 0.1638
# Epoch 27: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.9270 - loss: 0.1636 - val_accuracy: 0.8712 - val_loss: 0.2792 - learning_rate: 1.0000e-06
# Epoch 28/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 808ms/step - accuracy: 0.9390 - loss: 0.1360
# Epoch 28: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9389 - loss: 0.1361 - val_accuracy: 0.8864 - val_loss: 0.2686 - learning_rate: 1.0000e-06
# Epoch 29/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 817ms/step - accuracy: 0.9255 - loss: 0.1577
# Epoch 29: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9256 - loss: 0.1577 - val_accuracy: 0.8803 - val_loss: 0.2654 - learning_rate: 1.0000e-06
# Epoch 30/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 806ms/step - accuracy: 0.9264 - loss: 0.1596
# Epoch 30: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 999ms/step - accuracy: 0.9264 - loss: 0.1595 - val_accuracy: 0.8697 - val_loss: 0.2863 - learning_rate: 1.0000e-06
# Epoch 31/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.9419 - loss: 0.1444
# Epoch 31: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 997ms/step - accuracy: 0.9418 - loss: 0.1445 - val_accuracy: 0.8848 - val_loss: 0.2780 - learning_rate: 1.0000e-06
# Epoch 32/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 809ms/step - accuracy: 0.9308 - loss: 0.1662
# Epoch 32: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.9308 - loss: 0.1661 - val_accuracy: 0.8879 - val_loss: 0.2932 - learning_rate: 1.0000e-06
# Epoch 33/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - accuracy: 0.9368 - loss: 0.1561
# Epoch 33: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 987ms/step - accuracy: 0.9368 - loss: 0.1560 - val_accuracy: 0.8818 - val_loss: 0.2685 - learning_rate: 1.0000e-06
# Epoch 34/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 796ms/step - accuracy: 0.9432 - loss: 0.1522
# Epoch 34: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 989ms/step - accuracy: 0.9432 - loss: 0.1522 - val_accuracy: 0.8773 - val_loss: 0.2768 - learning_rate: 1.0000e-06
# Epoch 35/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - accuracy: 0.9355 - loss: 0.1502
# Epoch 35: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9355 - loss: 0.1503 - val_accuracy: 0.8833 - val_loss: 0.2807 - learning_rate: 1.0000e-06
# Epoch 36/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 806ms/step - accuracy: 0.9382 - loss: 0.1542
# Epoch 36: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.9382 - loss: 0.1542 - val_accuracy: 0.8742 - val_loss: 0.2836 - learning_rate: 1.0000e-06
# Epoch 37/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - accuracy: 0.9316 - loss: 0.1550
# Epoch 37: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 991ms/step - accuracy: 0.9315 - loss: 0.1550 - val_accuracy: 0.8742 - val_loss: 0.2853 - learning_rate: 1.0000e-06
# Epoch 38/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.9398 - loss: 0.1369
# Epoch 38: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 996ms/step - accuracy: 0.9398 - loss: 0.1370 - val_accuracy: 0.8833 - val_loss: 0.2813 - learning_rate: 1.0000e-06
# Epoch 39/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9268 - loss: 0.1600
# Epoch 39: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 997ms/step - accuracy: 0.9268 - loss: 0.1601 - val_accuracy: 0.8727 - val_loss: 0.2694 - learning_rate: 1.0000e-06
# Epoch 40/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 793ms/step - accuracy: 0.9360 - loss: 0.1570
# Epoch 40: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 996ms/step - accuracy: 0.9360 - loss: 0.1570 - val_accuracy: 0.8864 - val_loss: 0.3111 - learning_rate: 1.0000e-06
# Epoch 41/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.9309 - loss: 0.1376
# Epoch 41: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 998ms/step - accuracy: 0.9310 - loss: 0.1376 - val_accuracy: 0.8758 - val_loss: 0.2795 - learning_rate: 1.0000e-06
# Epoch 42/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.9353 - loss: 0.1540
# Epoch 42: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 997ms/step - accuracy: 0.9352 - loss: 0.1541 - val_accuracy: 0.8697 - val_loss: 0.2754 - learning_rate: 1.0000e-06
# Epoch 43/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.9305 - loss: 0.1480
# Epoch 43: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 998ms/step - accuracy: 0.9305 - loss: 0.1481 - val_accuracy: 0.8803 - val_loss: 0.2680 - learning_rate: 1.0000e-06
# Epoch 44/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - accuracy: 0.9417 - loss: 0.1350
# Epoch 44: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.9416 - loss: 0.1351 - val_accuracy: 0.8758 - val_loss: 0.2917 - learning_rate: 1.0000e-06
# Epoch 45/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.9409 - loss: 0.1393
# Epoch 45: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 997ms/step - accuracy: 0.9408 - loss: 0.1394 - val_accuracy: 0.8803 - val_loss: 0.2782 - learning_rate: 1.0000e-06
# Epoch 46/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - accuracy: 0.9474 - loss: 0.1292
# Epoch 46: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 989ms/step - accuracy: 0.9474 - loss: 0.1293 - val_accuracy: 0.8712 - val_loss: 0.2869 - learning_rate: 1.0000e-06
# Epoch 47/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9363 - loss: 0.1459
# Epoch 47: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 994ms/step - accuracy: 0.9363 - loss: 0.1460 - val_accuracy: 0.8818 - val_loss: 0.3157 - learning_rate: 1.0000e-06
# Epoch 48/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 799ms/step - accuracy: 0.9376 - loss: 0.1458
# Epoch 48: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.9376 - loss: 0.1459 - val_accuracy: 0.8788 - val_loss: 0.2779 - learning_rate: 1.0000e-06
# Epoch 49/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.9398 - loss: 0.1596
# Epoch 49: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 995ms/step - accuracy: 0.9398 - loss: 0.1595 - val_accuracy: 0.8833 - val_loss: 0.2766 - learning_rate: 1.0000e-06
# Epoch 50/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.9384 - loss: 0.1388
# Epoch 50: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 991ms/step - accuracy: 0.9384 - loss: 0.1388 - val_accuracy: 0.8773 - val_loss: 0.3036 - learning_rate: 1.0000e-06
# Epoch 51/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 806ms/step - accuracy: 0.9233 - loss: 0.1687
# Epoch 51: val_loss did not improve from 0.26195
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 997ms/step - accuracy: 0.9234 - loss: 0.1685 - val_accuracy: 0.8773 - val_loss: 0.2850 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained ResNet152 model ===
model_path = "/content/drive/MyDrive/best_inceptionv3_model.keras"
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))
# Out:
# ✅ Model loaded from: /content/drive/MyDrive/best_inceptionv3_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1]
# Valid labels: [0, 1]
# Target names: ['benign', 'malignant']
#
# Predicted sample count per class:
# benign: 362
# malignant: 298
#
# ✅ Overall Validation Accuracy: 88.79%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       benign       0.90      0.90      0.90       360
#    malignant       0.88      0.87      0.88       300
#
#     accuracy                           0.89       660
#    macro avg       0.89      0.89      0.89       660
# weighted avg       0.89      0.89      0.89       660

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
# y_true: true labels (e.g., [0, 2, 1, 4, ...]), shape = (n_samples,)
# pred_probs: predicted probabilities, shape = (n_samples, n_classes)
# labels: class names (optional, replace with your own)
# graph_dir: directory where to save plot

n_classes = 5
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = "./plots"

# Ensure output directory exists
os.makedirs(graph_dir, exist_ok=True)

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")
# Out:
# ⚠️ Skipping ROC curve for Class 2 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 3 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 4 — no positive samples in y_true.
# Skipped ROC for classes with no positive samples: Class 2, Class 3, Class 4
# ✅ ROC curve saved to: ./plots/roc_curve.png

# %%
model.save("/content/drive/MyDrive/final_resnet152_model.keras")
