# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/d.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")
# Out:
#  Dataset extracted.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
train_dir = "/content/dataset/d/train"
val_dir = "/content/dataset/d/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest')

train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Found 2637 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

base_model = ResNet152(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze initial layers
for layer in base_model.layers[:600]:
    layer.trainable = False

# Unfreeze later layers for fine-tuning
for layer in base_model.layers[600:]:
    layer.trainable = True

x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(5, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234698864/234698864 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
from tensorflow.keras.optimizers import Nadam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Define optimizer
optimizer = Nadam(learning_rate=1e-4)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.build((None, 224, 224, 3))

# Callbacks — No EarlyStopping used
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_resnet152_model.keras",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# Fit the model for all 51 epochs
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=51,
    callbacks=[checkpoint, lr_scheduler]  # early_stop removed
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 630ms/step - accuracy: 0.2878 - loss: 1.9954
# Epoch 1: val_loss improved from inf to 1.79547, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 115s 993ms/step - accuracy: 0.2891 - loss: 1.9919 - val_accuracy: 0.4545 - val_loss: 1.7955 - learning_rate: 1.0000e-04
# Epoch 2/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - accuracy: 0.5870 - loss: 1.3714
# Epoch 2: val_loss improved from 1.79547 to 1.72371, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 58s 694ms/step - accuracy: 0.5873 - loss: 1.3708 - val_accuracy: 0.4545 - val_loss: 1.7237 - learning_rate: 1.0000e-04
# Epoch 3/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - accuracy: 0.6598 - loss: 1.1918
# Epoch 3: val_loss improved from 1.72371 to 1.56731, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 70s 839ms/step - accuracy: 0.6597 - loss: 1.1917 - val_accuracy: 0.4545 - val_loss: 1.5673 - learning_rate: 1.0000e-04
# Epoch 4/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.7058 - loss: 1.0767
# Epoch 4: val_loss improved from 1.56731 to 1.33727, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 58s 701ms/step - accuracy: 0.7057 - loss: 1.0766 - val_accuracy: 0.4545 - val_loss: 1.3373 - learning_rate: 1.0000e-04
# Epoch 5/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - accuracy: 0.7172 - loss: 1.0172
# Epoch 5: val_loss improved from 1.33727 to 1.11965, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 58s 698ms/step - accuracy: 0.7172 - loss: 1.0173 - val_accuracy: 0.6273 - val_loss: 1.1197 - learning_rate: 1.0000e-04
# Epoch 6/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.7555 - loss: 0.9467
# Epoch 6: val_loss improved from 1.11965 to 0.97175, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 58s 700ms/step - accuracy: 0.7553 - loss: 0.9471 - val_accuracy: 0.7197 - val_loss: 0.9718 - learning_rate: 1.0000e-04
# Epoch 7/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.7599 - loss: 0.8795
# Epoch 7: val_loss improved from 0.97175 to 0.78875, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 61s 725ms/step - accuracy: 0.7598 - loss: 0.8799 - val_accuracy: 0.7667 - val_loss: 0.7887 - learning_rate: 1.0000e-04
# Epoch 8/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.7655 - loss: 0.8326
# Epoch 8: val_loss improved from 0.78875 to 0.71437, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 59s 707ms/step - accuracy: 0.7654 - loss: 0.8329 - val_accuracy: 0.7894 - val_loss: 0.7144 - learning_rate: 1.0000e-04
# Epoch 9/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.7694 - loss: 0.8783
# Epoch 9: val_loss improved from 0.71437 to 0.62880, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 58s 703ms/step - accuracy: 0.7694 - loss: 0.8777 - val_accuracy: 0.8167 - val_loss: 0.6288 - learning_rate: 1.0000e-04
# Epoch 10/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.7739 - loss: 0.7872
# Epoch 10: val_loss improved from 0.62880 to 0.58661, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 69s 824ms/step - accuracy: 0.7740 - loss: 0.7871 - val_accuracy: 0.8242 - val_loss: 0.5866 - learning_rate: 1.0000e-04
# Epoch 11/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.7732 - loss: 0.8051
# Epoch 11: val_loss improved from 0.58661 to 0.58337, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 59s 703ms/step - accuracy: 0.7732 - loss: 0.8047 - val_accuracy: 0.8197 - val_loss: 0.5834 - learning_rate: 1.0000e-04
# Epoch 12/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - accuracy: 0.7883 - loss: 0.7246
# Epoch 12: val_loss improved from 0.58337 to 0.54598, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 58s 702ms/step - accuracy: 0.7882 - loss: 0.7247 - val_accuracy: 0.8212 - val_loss: 0.5460 - learning_rate: 1.0000e-04
# Epoch 13/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.7826 - loss: 0.7287
# Epoch 13: val_loss improved from 0.54598 to 0.52601, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 58s 698ms/step - accuracy: 0.7826 - loss: 0.7286 - val_accuracy: 0.8152 - val_loss: 0.5260 - learning_rate: 1.0000e-04
# Epoch 14/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.7953 - loss: 0.6501
# Epoch 14: val_loss did not improve from 0.52601
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 88s 766ms/step - accuracy: 0.7953 - loss: 0.6502 - val_accuracy: 0.8318 - val_loss: 0.5370 - learning_rate: 1.0000e-04
# Epoch 15/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.7955 - loss: 0.6491
# Epoch 15: val_loss did not improve from 0.52601
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 73s 656ms/step - accuracy: 0.7954 - loss: 0.6493 - val_accuracy: 0.8273 - val_loss: 0.5323 - learning_rate: 1.0000e-04
# Epoch 16/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.7693 - loss: 0.6788
# Epoch 16: val_loss improved from 0.52601 to 0.50951, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 675ms/step - accuracy: 0.7695 - loss: 0.6784 - val_accuracy: 0.8182 - val_loss: 0.5095 - learning_rate: 3.0000e-05
# Epoch 17/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 0.7856 - loss: 0.6259
# Epoch 17: val_loss improved from 0.50951 to 0.48503, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 57s 690ms/step - accuracy: 0.7858 - loss: 0.6258 - val_accuracy: 0.8242 - val_loss: 0.4850 - learning_rate: 3.0000e-05
# Epoch 18/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.7889 - loss: 0.6266
# Epoch 18: val_loss did not improve from 0.48503
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 671ms/step - accuracy: 0.7889 - loss: 0.6267 - val_accuracy: 0.8288 - val_loss: 0.5205 - learning_rate: 3.0000e-05
# Epoch 19/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.7881 - loss: 0.5992
# Epoch 19: val_loss did not improve from 0.48503
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 54s 651ms/step - accuracy: 0.7882 - loss: 0.5995 - val_accuracy: 0.8136 - val_loss: 0.5321 - learning_rate: 3.0000e-05
# Epoch 20/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.7934 - loss: 0.6119
# Epoch 20: val_loss improved from 0.48503 to 0.47869, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 677ms/step - accuracy: 0.7934 - loss: 0.6118 - val_accuracy: 0.8333 - val_loss: 0.4787 - learning_rate: 9.0000e-06
# Epoch 21/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - accuracy: 0.7967 - loss: 0.6267
# Epoch 21: val_loss did not improve from 0.47869
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 669ms/step - accuracy: 0.7967 - loss: 0.6268 - val_accuracy: 0.8303 - val_loss: 0.5231 - learning_rate: 9.0000e-06
# Epoch 22/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.8080 - loss: 0.5885
# Epoch 22: val_loss improved from 0.47869 to 0.47770, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 57s 683ms/step - accuracy: 0.8079 - loss: 0.5886 - val_accuracy: 0.8303 - val_loss: 0.4777 - learning_rate: 9.0000e-06
# Epoch 23/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.7812 - loss: 0.6356
# Epoch 23: val_loss did not improve from 0.47770
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 55s 657ms/step - accuracy: 0.7814 - loss: 0.6353 - val_accuracy: 0.8273 - val_loss: 0.4994 - learning_rate: 9.0000e-06
# Epoch 24/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.7943 - loss: 0.6179
# Epoch 24: val_loss did not improve from 0.47770
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 53s 644ms/step - accuracy: 0.7943 - loss: 0.6178 - val_accuracy: 0.8197 - val_loss: 0.5028 - learning_rate: 9.0000e-06
# Epoch 25/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.7945 - loss: 0.5955
# Epoch 25: val_loss did not improve from 0.47770
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 54s 646ms/step - accuracy: 0.7945 - loss: 0.5955 - val_accuracy: 0.8318 - val_loss: 0.4993 - learning_rate: 2.7000e-06
# Epoch 26/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.8023 - loss: 0.5786
# Epoch 26: val_loss did not improve from 0.47770
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 54s 647ms/step - accuracy: 0.8022 - loss: 0.5787 - val_accuracy: 0.8318 - val_loss: 0.4804 - learning_rate: 2.7000e-06
# Epoch 27/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.7958 - loss: 0.5898
# Epoch 27: val_loss did not improve from 0.47770
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 54s 647ms/step - accuracy: 0.7957 - loss: 0.5901 - val_accuracy: 0.8227 - val_loss: 0.5006 - learning_rate: 1.0000e-06
# Epoch 28/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.7918 - loss: 0.5741
# Epoch 28: val_loss did not improve from 0.47770
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 53s 640ms/step - accuracy: 0.7920 - loss: 0.5741 - val_accuracy: 0.8288 - val_loss: 0.4792 - learning_rate: 1.0000e-06
# Epoch 29/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.7910 - loss: 0.6184
# Epoch 29: val_loss did not improve from 0.47770
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 53s 637ms/step - accuracy: 0.7910 - loss: 0.6183 - val_accuracy: 0.8091 - val_loss: 0.4942 - learning_rate: 1.0000e-06
# Epoch 30/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.7883 - loss: 0.6106
# Epoch 30: val_loss improved from 0.47770 to 0.46891, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 55s 665ms/step - accuracy: 0.7883 - loss: 0.6107 - val_accuracy: 0.8288 - val_loss: 0.4689 - learning_rate: 1.0000e-06
# Epoch 31/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - accuracy: 0.7836 - loss: 0.6226
# Epoch 31: val_loss did not improve from 0.46891
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 55s 657ms/step - accuracy: 0.7836 - loss: 0.6224 - val_accuracy: 0.8227 - val_loss: 0.4794 - learning_rate: 1.0000e-06
# Epoch 32/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.8120 - loss: 0.5640
# Epoch 32: val_loss improved from 0.46891 to 0.45973, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 66s 795ms/step - accuracy: 0.8119 - loss: 0.5642 - val_accuracy: 0.8394 - val_loss: 0.4597 - learning_rate: 1.0000e-06
# Epoch 33/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.7879 - loss: 0.5913
# Epoch 33: val_loss improved from 0.45973 to 0.43752, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 72s 675ms/step - accuracy: 0.7880 - loss: 0.5912 - val_accuracy: 0.8379 - val_loss: 0.4375 - learning_rate: 1.0000e-06
# Epoch 34/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.7880 - loss: 0.5990
# Epoch 34: val_loss did not improve from 0.43752
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 55s 660ms/step - accuracy: 0.7880 - loss: 0.5991 - val_accuracy: 0.8121 - val_loss: 0.4911 - learning_rate: 1.0000e-06
# Epoch 35/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.7908 - loss: 0.6315
# Epoch 35: val_loss did not improve from 0.43752
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 54s 647ms/step - accuracy: 0.7908 - loss: 0.6313 - val_accuracy: 0.8258 - val_loss: 0.5150 - learning_rate: 1.0000e-06
# Epoch 36/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.7946 - loss: 0.6108
# Epoch 36: val_loss did not improve from 0.43752
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 53s 645ms/step - accuracy: 0.7946 - loss: 0.6107 - val_accuracy: 0.8182 - val_loss: 0.4656 - learning_rate: 1.0000e-06
# Epoch 37/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.8104 - loss: 0.5622
# Epoch 37: val_loss did not improve from 0.43752
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 53s 639ms/step - accuracy: 0.8102 - loss: 0.5624 - val_accuracy: 0.8227 - val_loss: 0.4945 - learning_rate: 1.0000e-06
# Epoch 38/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.7770 - loss: 0.5978
# Epoch 38: val_loss did not improve from 0.43752
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 53s 643ms/step - accuracy: 0.7772 - loss: 0.5978 - val_accuracy: 0.8242 - val_loss: 0.4948 - learning_rate: 1.0000e-06
# Epoch 39/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.7999 - loss: 0.5828
# Epoch 39: val_loss did not improve from 0.43752
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 54s 646ms/step - accuracy: 0.7999 - loss: 0.5830 - val_accuracy: 0.8333 - val_loss: 0.4613 - learning_rate: 1.0000e-06
# Epoch 40/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.7955 - loss: 0.6064
# Epoch 40: val_loss did not improve from 0.43752
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 53s 642ms/step - accuracy: 0.7954 - loss: 0.6064 - val_accuracy: 0.8227 - val_loss: 0.4991 - learning_rate: 1.0000e-06
# Epoch 41/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.8098 - loss: 0.5791
# Epoch 41: val_loss did not improve from 0.43752
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 53s 643ms/step - accuracy: 0.8098 - loss: 0.5793 - val_accuracy: 0.8212 - val_loss: 0.5078 - learning_rate: 1.0000e-06
# Epoch 42/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.7986 - loss: 0.5998
# Epoch 42: val_loss did not improve from 0.43752
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 54s 647ms/step - accuracy: 0.7986 - loss: 0.5997 - val_accuracy: 0.8136 - val_loss: 0.4859 - learning_rate: 1.0000e-06
# Epoch 43/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.7967 - loss: 0.5815
# Epoch 43: val_loss did not improve from 0.43752
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 54s 650ms/step - accuracy: 0.7967 - loss: 0.5818 - val_accuracy: 0.8273 - val_loss: 0.4983 - learning_rate: 1.0000e-06
# Epoch 44/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.8031 - loss: 0.5663
# Epoch 44: val_loss did not improve from 0.43752
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 54s 645ms/step - accuracy: 0.8030 - loss: 0.5666 - val_accuracy: 0.8273 - val_loss: 0.4716 - learning_rate: 1.0000e-06
# Epoch 45/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.7798 - loss: 0.6206
# Epoch 45: val_loss did not improve from 0.43752
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 53s 645ms/step - accuracy: 0.7799 - loss: 0.6203 - val_accuracy: 0.8227 - val_loss: 0.5005 - learning_rate: 1.0000e-06
# Epoch 46/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.8090 - loss: 0.5705
# Epoch 46: val_loss did not improve from 0.43752
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 53s 641ms/step - accuracy: 0.8087 - loss: 0.5710 - val_accuracy: 0.8152 - val_loss: 0.4774 - learning_rate: 1.0000e-06
# Epoch 47/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.8123 - loss: 0.5633
# Epoch 47: val_loss did not improve from 0.43752
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 63s 763ms/step - accuracy: 0.8123 - loss: 0.5635 - val_accuracy: 0.8121 - val_loss: 0.4881 - learning_rate: 1.0000e-06
# Epoch 48/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.7764 - loss: 0.6438
# Epoch 48: val_loss did not improve from 0.43752
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 53s 641ms/step - accuracy: 0.7766 - loss: 0.6434 - val_accuracy: 0.8348 - val_loss: 0.4815 - learning_rate: 1.0000e-06
# Epoch 49/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.7901 - loss: 0.5926
# Epoch 49: val_loss did not improve from 0.43752
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 53s 643ms/step - accuracy: 0.7901 - loss: 0.5928 - val_accuracy: 0.8333 - val_loss: 0.4556 - learning_rate: 1.0000e-06
# Epoch 50/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.7887 - loss: 0.6192
# Epoch 50: val_loss did not improve from 0.43752
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 53s 644ms/step - accuracy: 0.7888 - loss: 0.6188 - val_accuracy: 0.8227 - val_loss: 0.5090 - learning_rate: 1.0000e-06
# Epoch 51/51
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.7927 - loss: 0.6394
# Epoch 51: val_loss did not improve from 0.43752
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 53s 641ms/step - accuracy: 0.7928 - loss: 0.6389 - val_accuracy: 0.8182 - val_loss: 0.4848 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained ResNet152 model ===
model_path = "/content/drive/MyDrive/best_resnet152_model.keras"
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))
# Out:
# ✅ Model loaded from: /content/drive/MyDrive/best_resnet152_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1 3]
# Valid labels: [0, 1]
# Target names: ['benign', 'malignant']
#
# Predicted sample count per class:
# benign: 323
# malignant: 335
#
# ✅ Overall Validation Accuracy: 82.58%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       benign       0.88      0.79      0.83       360
#    malignant       0.78      0.87      0.82       300
#
#    micro avg       0.83      0.83      0.83       660
#    macro avg       0.83      0.83      0.83       660
# weighted avg       0.83      0.83      0.83       660

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
# y_true: true labels (e.g., [0, 2, 1, 4, ...]), shape = (n_samples,)
# pred_probs: predicted probabilities, shape = (n_samples, n_classes)
# labels: class names (optional, replace with your own)
# graph_dir: directory where to save plot

n_classes = 5
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = "./plots"

# Ensure output directory exists
os.makedirs(graph_dir, exist_ok=True)

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")
# Out:
# ⚠️ Skipping ROC curve for Class 2 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 3 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 4 — no positive samples in y_true.
# Skipped ROC for classes with no positive samples: Class 2, Class 3, Class 4
# ✅ ROC curve saved to: ./plots/roc_curve.png

# %%
model.save("/content/drive/MyDrive/final_resnet152_model.keras")
